# %%
# %%bash
# # Check if Terraform is installed
# if ! command -v terraform &> /dev/null
# then
#     echo "Installing Terraform..."
#     wget https://releases.hashicorp.com/terraform/1.13.0/terraform_1.13.0_linux_amd64.zip
#     unzip terraform_1.13.0_linux_amd64.zip
#     sudo mv terraform /usr/local/bin/
#     rm terraform_1.13.0_linux_amd64.zip
# else
#     echo "Terraform is already installed."
# fi
# terraform --version
# Out:
# Terraform is already installed.
# Terraform v1.13.0
# on linux_amd64
# + provider registry.terraform.io/hashicorp/aws v5.100.0

# %%
# %%writefile variables.tf
# variable "region" {
#   default = "us-east-1"
# }
#
# variable "vpc_cidr" {
#   default = "10.0.0.0/16"
# }
#
# variable "public_subnet_cidr" {
#   default = "10.0.0.0/24"
# }
#
# variable "private_subnet_1_cidr" {
#   default = "10.0.1.0/24"
# }
#
# variable "private_subnet_2_cidr" {
#   default = "10.0.2.0/24"
# }
#
# variable "az1" {
#   default = "us-east-1a"
# }
#
# variable "az2" {
#   default = "us-east-1b"
# }
#
# variable "mongodb_port" {
#   default = 3307
# }
# Out:
# Writing variables.tf

# %%
# %%writefile provider.tf
# terraform {
#   required_providers {
#     aws = {
#       source  = "hashicorp/aws"
#       version = "~> 5.0"
#     }
#   }
# }
#
# provider "aws" {
#   region = var.region
# }
# Out:
# Writing provider.tf

# %%
# %%writefile outputs.tf
# output "vpc_id" {
#   value = aws_vpc.my_vpc.id
# }
# Out:
# Writing outputs.tf

# %%
# %%writefile vpc.tf
# # VPC
# resource "aws_vpc" "my_vpc" {
#   cidr_block = var.vpc_cidr
#   tags = {
#     Name = "my-vpc"
#   }
# }
#
# # Public Subnet
# resource "aws_subnet" "public_subnet" {
#   vpc_id            = aws_vpc.my_vpc.id
#   cidr_block        = var.public_subnet_cidr
#   availability_zone = var.az1
#   tags = {
#     Name = "public-subnet"
#   }
# }
#
# # Private Subnet 1
# resource "aws_subnet" "private_subnet_1" {
#   vpc_id            = aws_vpc.my_vpc.id
#   cidr_block        = var.private_subnet_1_cidr
#   availability_zone = var.az1
#   tags = {
#     Name = "private-subnet-1"
#   }
# }
#
# # Private Subnet 2
# resource "aws_subnet" "private_subnet_2" {
#   vpc_id            = aws_vpc.my_vpc.id
#   cidr_block        = var.private_subnet_2_cidr
#   availability_zone = var.az2
#   tags = {
#     Name = "private-subnet-2"
#   }
# }
#
# # Internet Gateway
# resource "aws_internet_gateway" "my_igw" {
#   vpc_id = aws_vpc.my_vpc.id
#   tags = {
#     Name = "my-igw"
#   }
# }
#
# # Elastic IP for NAT
# resource "aws_eip" "nat_eip" {
#   domain = "vpc"
# }
#
# # NAT Gateway in Public Subnet
# resource "aws_nat_gateway" "my_nat" {
#   allocation_id = aws_eip.nat_eip.id
#   subnet_id     = aws_subnet.public_subnet.id
#   tags = {
#     Name = "my-nat"
#   }
#   depends_on = [aws_internet_gateway.my_igw]
# }
#
# # Public Route Table
# resource "aws_route_table" "public_rt" {
#   vpc_id = aws_vpc.my_vpc.id
#   tags = {
#     Name = "public-rt"
#   }
# }
#
# resource "aws_route" "public_internet" {
#   route_table_id         = aws_route_table.public_rt.id
#   destination_cidr_block = "0.0.0.0/0"
#   gateway_id             = aws_internet_gateway.my_igw.id
# }
#
# resource "aws_route_table_association" "public_assoc" {
#   subnet_id      = aws_subnet.public_subnet.id
#   route_table_id = aws_route_table.public_rt.id
# }
#
# # Private Route Table
# resource "aws_route_table" "private_rt" {
#   vpc_id = aws_vpc.my_vpc.id
#   tags = {
#     Name = "private-rt"
#   }
# }
#
# resource "aws_route" "private_nat" {
#   route_table_id         = aws_route_table.private_rt.id
#   destination_cidr_block = "0.0.0.0/0"
#   nat_gateway_id         = aws_nat_gateway.my_nat.id
# }
#
# resource "aws_route_table_association" "private_assoc_1" {
#   subnet_id      = aws_subnet.private_subnet_1.id
#   route_table_id = aws_route_table.private_rt.id
# }
#
# resource "aws_route_table_association" "private_assoc_2" {
#   subnet_id      = aws_subnet.private_subnet_2.id
#   route_table_id = aws_route_table.private_rt.id
# }
# Out:
# Writing vpc.tf

# %%
# %%bash
# terraform init
# Out:
# Initializing the backend...
# Initializing provider plugins...
# - Reusing previous version of hashicorp/aws from the dependency lock file
# - Using previously-installed hashicorp/aws v5.100.0
#
# Terraform has been successfully initialized!
#
# You may now begin working with Terraform. Try running "terraform plan" to see
# any changes that are required for your infrastructure. All Terraform commands
# should now work.
#
# If you ever set or change modules or backend configuration for Terraform,
# rerun this command to reinitialize your working directory. If you forget, other
# commands will detect it and remind you to do so if necessary.

# %%
# %%bash
# terraform plan
# Out:
# Terraform used the selected providers to generate the following execution
# plan. Resource actions are indicated with the following symbols:
#   + create
#
# Terraform will perform the following actions:
#
#   # aws_eip.nat_eip will be created
#   + resource "aws_eip" "nat_eip" {
#       + allocation_id        = (known after apply)
#       + arn                  = (known after apply)
#       + association_id       = (known after apply)
#       + carrier_ip           = (known after apply)
#       + customer_owned_ip    = (known after apply)
#       + domain               = "vpc"
#       + id                   = (known after apply)
#       + instance             = (known after apply)
#       + ipam_pool_id         = (known after apply)
#       + network_border_group = (known after apply)
#       + network_interface    = (known after apply)
#       + private_dns          = (known after apply)
#       + private_ip           = (known after apply)
#       + ptr_record           = (known after apply)
#       + public_dns           = (known after apply)
#       + public_ip            = (known after apply)
#       + public_ipv4_pool     = (known after apply)
#       + tags_all             = (known after apply)
#       + vpc                  = (known after apply)
#     }
#
#   # aws_internet_gateway.my_igw will be created
#   + resource "aws_internet_gateway" "my_igw" {
#       + arn      = (known after apply)
#       + id       = (known after apply)
#       + owner_id = (known after apply)
#       + tags     = {
#           + "Name" = "my-igw"
#         }
#       + tags_all = {
#           + "Name" = "my-igw"
#         }
#       + vpc_id   = (known after apply)
#     }
#
#   # aws_nat_gateway.my_nat will be created
#   + resource "aws_nat_gateway" "my_nat" {
#       + allocation_id                      = (known after apply)
#       + association_id                     = (known after apply)
#       + connectivity_type                  = "public"
#       + id                                 = (known after apply)
#       + network_interface_id               = (known after apply)
#       + private_ip                         = (known after apply)
#       + public_ip                          = (known after apply)
#       + secondary_private_ip_address_count = (known after apply)
#       + secondary_private_ip_addresses     = (known after apply)
#       + subnet_id                          = (known after apply)
#       + tags                               = {
#           + "Name" = "my-nat"
#         }
#       + tags_all                           = {
#           + "Name" = "my-nat"
#         }
#     }
#
#   # aws_route.private_nat will be created
#   + resource "aws_route" "private_nat" {
#       + destination_cidr_block = "0.0.0.0/0"
#       + id                     = (known after apply)
#       + instance_id            = (known after apply)
#       + instance_owner_id      = (known after apply)
#       + nat_gateway_id         = (known after apply)
#       + network_interface_id   = (known after apply)
#       + origin                 = (known after apply)
#       + route_table_id         = (known after apply)
#       + state                  = (known after apply)
#     }
#
#   # aws_route.public_internet will be created
#   + resource "aws_route" "public_internet" {
#       + destination_cidr_block = "0.0.0.0/0"
#       + gateway_id             = (known after apply)
#       + id                     = (known after apply)
#       + instance_id            = (known after apply)
#       + instance_owner_id      = (known after apply)
#       + network_interface_id   = (known after apply)
#       + origin                 = (known after apply)
#       + route_table_id         = (known after apply)
#       + state                  = (known after apply)
#     }
#
#   # aws_route_table.private_rt will be created
#   + resource "aws_route_table" "private_rt" {
#       + arn              = (known after apply)
#       + id               = (known after apply)
#       + owner_id         = (known after apply)
#       + propagating_vgws = (known after apply)
#       + route            = (known after apply)
#       + tags             = {
#           + "Name" = "private-rt"
#         }
#       + tags_all         = {
#           + "Name" = "private-rt"
#         }
#       + vpc_id           = (known after apply)
#     }
#
#   # aws_route_table.public_rt will be created
#   + resource "aws_route_table" "public_rt" {
#       + arn              = (known after apply)
#       + id               = (known after apply)
#       + owner_id         = (known after apply)
#       + propagating_vgws = (known after apply)
#       + route            = (known after apply)
#       + tags             = {
#           + "Name" = "public-rt"
#         }
#       + tags_all         = {
#           + "Name" = "public-rt"
#         }
#       + vpc_id           = (known after apply)
#     }
#
#   # aws_route_table_association.private_assoc_1 will be created
#   + resource "aws_route_table_association" "private_assoc_1" {
#       + id             = (known after apply)
#       + route_table_id = (known after apply)
#       + subnet_id      = (known after apply)
#     }
#
#   # aws_route_table_association.private_assoc_2 will be created
#   + resource "aws_route_table_association" "private_assoc_2" {
#       + id             = (known after apply)
#       + route_table_id = (known after apply)
#       + subnet_id      = (known after apply)
#     }
#
#   # aws_route_table_association.public_assoc will be created
#   + resource "aws_route_table_association" "public_assoc" {
#       + id             = (known after apply)
#       + route_table_id = (known after apply)
#       + subnet_id      = (known after apply)
#     }
#
#   # aws_subnet.private_subnet_1 will be created
#   + resource "aws_subnet" "private_subnet_1" {
#       + arn                                            = (known after apply)
#       + assign_ipv6_address_on_creation                = false
#       + availability_zone                              = "us-east-1a"
#       + availability_zone_id                           = (known after apply)
#       + cidr_block                                     = "10.0.1.0/24"
#       + enable_dns64                                   = false
#       + enable_resource_name_dns_a_record_on_launch    = false
#       + enable_resource_name_dns_aaaa_record_on_launch = false
#       + id                                             = (known after apply)
#       + ipv6_cidr_block_association_id                 = (known after apply)
#       + ipv6_native                                    = false
#       + map_public_ip_on_launch                        = false
#       + owner_id                                       = (known after apply)
#       + private_dns_hostname_type_on_launch            = (known after apply)
#       + tags                                           = {
#           + "Name" = "private-subnet-1"
#         }
#       + tags_all                                       = {
#           + "Name" = "private-subnet-1"
#         }
#       + vpc_id                                         = (known after apply)
#     }
#
#   # aws_subnet.private_subnet_2 will be created
#   + resource "aws_subnet" "private_subnet_2" {
#       + arn                                            = (known after apply)
#       + assign_ipv6_address_on_creation                = false
#       + availability_zone                              = "us-east-1b"
#       + availability_zone_id                           = (known after apply)
#       + cidr_block                                     = "10.0.2.0/24"
#       + enable_dns64                                   = false
#       + enable_resource_name_dns_a_record_on_launch    = false
#       + enable_resource_name_dns_aaaa_record_on_launch = false
#       + id                                             = (known after apply)
#       + ipv6_cidr_block_association_id                 = (known after apply)
#       + ipv6_native                                    = false
#       + map_public_ip_on_launch                        = false
#       + owner_id                                       = (known after apply)
#       + private_dns_hostname_type_on_launch            = (known after apply)
#       + tags                                           = {
#           + "Name" = "private-subnet-2"
#         }
#       + tags_all                                       = {
#           + "Name" = "private-subnet-2"
#         }
#       + vpc_id                                         = (known after apply)
#     }
#
#   # aws_subnet.public_subnet will be created
#   + resource "aws_subnet" "public_subnet" {
#       + arn                                            = (known after apply)
#       + assign_ipv6_address_on_creation                = false
#       + availability_zone                              = "us-east-1a"
#       + availability_zone_id                           = (known after apply)
#       + cidr_block                                     = "10.0.0.0/24"
#       + enable_dns64                                   = false
#       + enable_resource_name_dns_a_record_on_launch    = false
#       + enable_resource_name_dns_aaaa_record_on_launch = false
#       + id                                             = (known after apply)
#       + ipv6_cidr_block_association_id                 = (known after apply)
#       + ipv6_native                                    = false
#       + map_public_ip_on_launch                        = false
#       + owner_id                                       = (known after apply)
#       + private_dns_hostname_type_on_launch            = (known after apply)
#       + tags                                           = {
#           + "Name" = "public-subnet"
#         }
#       + tags_all                                       = {
#           + "Name" = "public-subnet"
#         }
#       + vpc_id                                         = (known after apply)
#     }
#
#   # aws_vpc.my_vpc will be created
#   + resource "aws_vpc" "my_vpc" {
#       + arn                                  = (known after apply)
#       + cidr_block                           = "10.0.0.0/16"
#       + default_network_acl_id               = (known after apply)
#       + default_route_table_id               = (known after apply)
#       + default_security_group_id            = (known after apply)
#       + dhcp_options_id                      = (known after apply)
#       + enable_dns_hostnames                 = (known after apply)
#       + enable_dns_support                   = true
#       + enable_network_address_usage_metrics = (known after apply)
#       + id                                   = (known after apply)
#       + instance_tenancy                     = "default"
#       + ipv6_association_id                  = (known after apply)
#       + ipv6_cidr_block                      = (known after apply)
#       + ipv6_cidr_block_network_border_group = (known after apply)
#       + main_route_table_id                  = (known after apply)
#       + owner_id                             = (known after apply)
#       + tags                                 = {
#           + "Name" = "my-vpc"
#         }
#       + tags_all                             = {
#           + "Name" = "my-vpc"
#         }
#     }
#
# Plan: 14 to add, 0 to change, 0 to destroy.
#
# Changes to Outputs:
#   + vpc_id = (known after apply)
#
# ─────────────────────────────────────────────────────────────────────────────
#
# Note: You didn't use the -out option to save this plan, so Terraform can't
# guarantee to take exactly these actions if you run "terraform apply" now.

# %%
# %%bash
# terraform apply -auto-approve
# Out:
# Terraform used the selected providers to generate the following execution
# plan. Resource actions are indicated with the following symbols:
#   + create
#
# Terraform will perform the following actions:
#
#   # aws_eip.nat_eip will be created
#   + resource "aws_eip" "nat_eip" {
#       + allocation_id        = (known after apply)
#       + arn                  = (known after apply)
#       + association_id       = (known after apply)
#       + carrier_ip           = (known after apply)
#       + customer_owned_ip    = (known after apply)
#       + domain               = "vpc"
#       + id                   = (known after apply)
#       + instance             = (known after apply)
#       + ipam_pool_id         = (known after apply)
#       + network_border_group = (known after apply)
#       + network_interface    = (known after apply)
#       + private_dns          = (known after apply)
#       + private_ip           = (known after apply)
#       + ptr_record           = (known after apply)
#       + public_dns           = (known after apply)
#       + public_ip            = (known after apply)
#       + public_ipv4_pool     = (known after apply)
#       + tags_all             = (known after apply)
#       + vpc                  = (known after apply)
#     }
#
#   # aws_internet_gateway.my_igw will be created
#   + resource "aws_internet_gateway" "my_igw" {
#       + arn      = (known after apply)
#       + id       = (known after apply)
#       + owner_id = (known after apply)
#       + tags     = {
#           + "Name" = "my-igw"
#         }
#       + tags_all = {
#           + "Name" = "my-igw"
#         }
#       + vpc_id   = (known after apply)
#     }
#
#   # aws_nat_gateway.my_nat will be created
#   + resource "aws_nat_gateway" "my_nat" {
#       + allocation_id                      = (known after apply)
#       + association_id                     = (known after apply)
#       + connectivity_type                  = "public"
#       + id                                 = (known after apply)
#       + network_interface_id               = (known after apply)
#       + private_ip                         = (known after apply)
#       + public_ip                          = (known after apply)
#       + secondary_private_ip_address_count = (known after apply)
#       + secondary_private_ip_addresses     = (known after apply)
#       + subnet_id                          = (known after apply)
#       + tags                               = {
#           + "Name" = "my-nat"
#         }
#       + tags_all                           = {
#           + "Name" = "my-nat"
#         }
#     }
#
#   # aws_route.private_nat will be created
#   + resource "aws_route" "private_nat" {
#       + destination_cidr_block = "0.0.0.0/0"
#       + id                     = (known after apply)
#       + instance_id            = (known after apply)
#       + instance_owner_id      = (known after apply)
#       + nat_gateway_id         = (known after apply)
#       + network_interface_id   = (known after apply)
#       + origin                 = (known after apply)
#       + route_table_id         = (known after apply)
#       + state                  = (known after apply)
#     }
#
#   # aws_route.public_internet will be created
#   + resource "aws_route" "public_internet" {
#       + destination_cidr_block = "0.0.0.0/0"
#       + gateway_id             = (known after apply)
#       + id                     = (known after apply)
#       + instance_id            = (known after apply)
#       + instance_owner_id      = (known after apply)
#       + network_interface_id   = (known after apply)
#       + origin                 = (known after apply)
#       + route_table_id         = (known after apply)
#       + state                  = (known after apply)
#     }
#
#   # aws_route_table.private_rt will be created
#   + resource "aws_route_table" "private_rt" {
#       + arn              = (known after apply)
#       + id               = (known after apply)
#       + owner_id         = (known after apply)
#       + propagating_vgws = (known after apply)
#       + route            = (known after apply)
#       + tags             = {
#           + "Name" = "private-rt"
#         }
#       + tags_all         = {
#           + "Name" = "private-rt"
#         }
#       + vpc_id           = (known after apply)
#     }
#
#   # aws_route_table.public_rt will be created
#   + resource "aws_route_table" "public_rt" {
#       + arn              = (known after apply)
#       + id               = (known after apply)
#       + owner_id         = (known after apply)
#       + propagating_vgws = (known after apply)
#       + route            = (known after apply)
#       + tags             = {
#           + "Name" = "public-rt"
#         }
#       + tags_all         = {
#           + "Name" = "public-rt"
#         }
#       + vpc_id           = (known after apply)
#     }
#
#   # aws_route_table_association.private_assoc_1 will be created
#   + resource "aws_route_table_association" "private_assoc_1" {
#       + id             = (known after apply)
#       + route_table_id = (known after apply)
#       + subnet_id      = (known after apply)
#     }
#
#   # aws_route_table_association.private_assoc_2 will be created
#   + resource "aws_route_table_association" "private_assoc_2" {
#       + id             = (known after apply)
#       + route_table_id = (known after apply)
#       + subnet_id      = (known after apply)
#     }
#
#   # aws_route_table_association.public_assoc will be created
#   + resource "aws_route_table_association" "public_assoc" {
#       + id             = (known after apply)
#       + route_table_id = (known after apply)
#       + subnet_id      = (known after apply)
#     }
#
#   # aws_subnet.private_subnet_1 will be created
#   + resource "aws_subnet" "private_subnet_1" {
#       + arn                                            = (known after apply)
#       + assign_ipv6_address_on_creation                = false
#       + availability_zone                              = "us-east-1a"
#       + availability_zone_id                           = (known after apply)
#       + cidr_block                                     = "10.0.1.0/24"
#       + enable_dns64                                   = false
#       + enable_resource_name_dns_a_record_on_launch    = false
#       + enable_resource_name_dns_aaaa_record_on_launch = false
#       + id                                             = (known after apply)
#       + ipv6_cidr_block_association_id                 = (known after apply)
#       + ipv6_native                                    = false
#       + map_public_ip_on_launch                        = false
#       + owner_id                                       = (known after apply)
#       + private_dns_hostname_type_on_launch            = (known after apply)
#       + tags                                           = {
#           + "Name" = "private-subnet-1"
#         }
#       + tags_all                                       = {
#           + "Name" = "private-subnet-1"
#         }
#       + vpc_id                                         = (known after apply)
#     }
#
#   # aws_subnet.private_subnet_2 will be created
#   + resource "aws_subnet" "private_subnet_2" {
#       + arn                                            = (known after apply)
#       + assign_ipv6_address_on_creation                = false
#       + availability_zone                              = "us-east-1b"
#       + availability_zone_id                           = (known after apply)
#       + cidr_block                                     = "10.0.2.0/24"
#       + enable_dns64                                   = false
#       + enable_resource_name_dns_a_record_on_launch    = false
#       + enable_resource_name_dns_aaaa_record_on_launch = false
#       + id                                             = (known after apply)
#       + ipv6_cidr_block_association_id                 = (known after apply)
#       + ipv6_native                                    = false
#       + map_public_ip_on_launch                        = false
#       + owner_id                                       = (known after apply)
#       + private_dns_hostname_type_on_launch            = (known after apply)
#       + tags                                           = {
#           + "Name" = "private-subnet-2"
#         }
#       + tags_all                                       = {
#           + "Name" = "private-subnet-2"
#         }
#       + vpc_id                                         = (known after apply)
#     }
#
#   # aws_subnet.public_subnet will be created
#   + resource "aws_subnet" "public_subnet" {
#       + arn                                            = (known after apply)
#       + assign_ipv6_address_on_creation                = false
#       + availability_zone                              = "us-east-1a"
#       + availability_zone_id                           = (known after apply)
#       + cidr_block                                     = "10.0.0.0/24"
#       + enable_dns64                                   = false
#       + enable_resource_name_dns_a_record_on_launch    = false
#       + enable_resource_name_dns_aaaa_record_on_launch = false
#       + id                                             = (known after apply)
#       + ipv6_cidr_block_association_id                 = (known after apply)
#       + ipv6_native                                    = false
#       + map_public_ip_on_launch                        = false
#       + owner_id                                       = (known after apply)
#       + private_dns_hostname_type_on_launch            = (known after apply)
#       + tags                                           = {
#           + "Name" = "public-subnet"
#         }
#       + tags_all                                       = {
#           + "Name" = "public-subnet"
#         }
#       + vpc_id                                         = (known after apply)
#     }
#
#   # aws_vpc.my_vpc will be created
#   + resource "aws_vpc" "my_vpc" {
#       + arn                                  = (known after apply)
#       + cidr_block                           = "10.0.0.0/16"
#       + default_network_acl_id               = (known after apply)
#       + default_route_table_id               = (known after apply)
#       + default_security_group_id            = (known after apply)
#       + dhcp_options_id                      = (known after apply)
#       + enable_dns_hostnames                 = (known after apply)
#       + enable_dns_support                   = true
#       + enable_network_address_usage_metrics = (known after apply)
#       + id                                   = (known after apply)
#       + instance_tenancy                     = "default"
#       + ipv6_association_id                  = (known after apply)
#       + ipv6_cidr_block                      = (known after apply)
#       + ipv6_cidr_block_network_border_group = (known after apply)
#       + main_route_table_id                  = (known after apply)
#       + owner_id                             = (known after apply)
#       + tags                                 = {
#           + "Name" = "my-vpc"
#         }
#       + tags_all                             = {
#           + "Name" = "my-vpc"
#         }
#     }
#
# Plan: 14 to add, 0 to change, 0 to destroy.
#
# Changes to Outputs:
#   + vpc_id = (known after apply)
# aws_vpc.my_vpc: Creating...
# aws_eip.nat_eip: Creating...
# aws_eip.nat_eip: Creation complete after 0s [id=eipalloc-01a7c8f7772f11809]
# aws_vpc.my_vpc: Creation complete after 1s [id=vpc-09d06141d745ce35f]
# aws_subnet.private_subnet_1: Creating...
# aws_route_table.private_rt: Creating...
# aws_subnet.private_subnet_2: Creating...
# aws_internet_gateway.my_igw: Creating...
# aws_subnet.public_subnet: Creating...
# aws_route_table.public_rt: Creating...
# aws_route_table.public_rt: Creation complete after 0s [id=rtb-0c35f0d2e95f8b3ee]
# aws_subnet.private_subnet_1: Creation complete after 1s [id=subnet-0a9ddef84ff975a4b]
# aws_route_table.private_rt: Creation complete after 1s [id=rtb-0d592d6d93b2b0981]
# aws_route_table_association.private_assoc_1: Creating...
# aws_subnet.private_subnet_2: Creation complete after 1s [id=subnet-0e0f1ec3d6fa55ba1]
# aws_subnet.public_subnet: Creation complete after 1s [id=subnet-0122da2129d691098]
# aws_route_table_association.private_assoc_2: Creating...
# aws_route_table_association.public_assoc: Creating...
# aws_internet_gateway.my_igw: Creation complete after 1s [id=igw-06334980ce938c2a0]
# aws_nat_gateway.my_nat: Creating...
# aws_route.public_internet: Creating...
# aws_route_table_association.private_assoc_1: Creation complete after 0s [id=rtbassoc-09354b98ef22e6b5d]
# aws_route_table_association.private_assoc_2: Creation complete after 0s [id=rtbassoc-0369cf17e84ad5dd2]
# aws_route_table_association.public_assoc: Creation complete after 0s [id=rtbassoc-01f7b02613d758fff]
# aws_route.public_internet: Creation complete after 0s [id=r-rtb-0c35f0d2e95f8b3ee1080289494]
# aws_nat_gateway.my_nat: Still creating... 10s elapsed]
# aws_nat_gateway.my_nat: Still creating... 20s elapsed]
# aws_nat_gateway.my_nat: Still creating... 30s elapsed]
# aws_nat_gateway.my_nat: Still creating... 40s elapsed]
# aws_nat_gateway.my_nat: Still creating... 50s elapsed]
# aws_nat_gateway.my_nat: Still creating... 00s elapsed]
# aws_nat_gateway.my_nat: Still creating... 10s elapsed]
# aws_nat_gateway.my_nat: Still creating... 20s elapsed]
# aws_nat_gateway.my_nat: Still creating... 30s elapsed]
# aws_nat_gateway.my_nat: Still creating... 40s elapsed]
# aws_nat_gateway.my_nat: Creation complete after 1m43s [id=nat-07b8255225e45e0b0]
# aws_route.private_nat: Creating...
# aws_route.private_nat: Creation complete after 1s [id=r-rtb-0d592d6d93b2b09811080289494]
#
# Apply complete! Resources: 14 added, 0 changed, 0 destroyed.
#
# Outputs:
#
# vpc_id = "vpc-09d06141d745ce35f"

# %%
# %%bash
# # Get VPC ID from output
# VPC_ID=$(terraform output -raw vpc_id)
#
# # Verify VPC
# aws ec2 describe-vpcs --vpc-ids $VPC_ID
#
# # Verify Subnets
# aws ec2 describe-subnets --filters "Name=vpc-id,Values=$VPC_ID"
#
# # Verify Route Tables
# aws ec2 describe-route-tables --filters "Name=vpc-id,Values=$VPC_ID"
#
# # Verify IGW
# aws ec2 describe-internet-gateways --filters "Name=attachment.vpc-id,Values=$VPC_ID"
#
# # Verify NAT (should be 'available')
# aws ec2 describe-nat-gateways --filter "Name=vpc-id,Values=$VPC_ID"
# Out:
# {
#     "Vpcs": [
#         {
#             "OwnerId": "609009159737",
#             "InstanceTenancy": "default",
#             "CidrBlockAssociationSet": [
#                 {
#                     "AssociationId": "vpc-cidr-assoc-01e8aa64001bccd0f",
#                     "CidrBlock": "10.0.0.0/16",
#                     "CidrBlockState": {
#                         "State": "associated"
#                     }
#                 }
#             ],
#             "IsDefault": false,
#             "Tags": [
#                 {
#                     "Key": "Name",
#                     "Value": "my-vpc"
#                 }
#             ],
#             "BlockPublicAccessStates": {
#                 "InternetGatewayBlockMode": "off"
#             },
#             "VpcId": "vpc-09d06141d745ce35f",
#             "State": "available",
#             "CidrBlock": "10.0.0.0/16",
#             "DhcpOptionsId": "dopt-0bf15e3dedd5548e4"
#         }
#     ]
# }
# {
#     "Subnets": [
#         {
#             "AvailabilityZoneId": "use1-az6",
#             "MapCustomerOwnedIpOnLaunch": false,
#             "OwnerId": "609009159737",
#             "AssignIpv6AddressOnCreation": false,
#             "Ipv6CidrBlockAssociationSet": [],
#             "Tags": [
#                 {
#                     "Key": "Name",
#                     "Value": "private-subnet-2"
#                 }
#             ],
#             "SubnetArn": "arn:aws:ec2:us-east-1:609009159737:subnet/subnet-0e0f1ec3d6fa55ba1",
#             "EnableDns64": false,
#             "Ipv6Native": false,
#             "PrivateDnsNameOptionsOnLaunch": {
#                 "HostnameType": "ip-name",
#                 "EnableResourceNameDnsARecord": false,
#                 "EnableResourceNameDnsAAAARecord": false
#             },
#             "BlockPublicAccessStates": {
#                 "InternetGatewayBlockMode": "off"
#             },
#             "SubnetId": "subnet-0e0f1ec3d6fa55ba1",
#             "State": "available",
#             "VpcId": "vpc-09d06141d745ce35f",
#             "CidrBlock": "10.0.2.0/24",
#             "AvailableIpAddressCount": 251,
#             "AvailabilityZone": "us-east-1b",
#             "DefaultForAz": false,
#             "MapPublicIpOnLaunch": false
#         },
#         {
#             "AvailabilityZoneId": "use1-az4",
#             "MapCustomerOwnedIpOnLaunch": false,
#             "OwnerId": "609009159737",
#             "AssignIpv6AddressOnCreation": false,
#             "Ipv6CidrBlockAssociationSet": [],
#             "Tags": [
#                 {
#                     "Key": "Name",
#                     "Value": "public-subnet"
#                 }
#             ],
#             "SubnetArn": "arn:aws:ec2:us-east-1:609009159737:subnet/subnet-0122da2129d691098",
#             "EnableDns64": false,
#             "Ipv6Native": false,
#             "PrivateDnsNameOptionsOnLaunch": {
#                 "HostnameType": "ip-name",
#                 "EnableResourceNameDnsARecord": false,
#                 "EnableResourceNameDnsAAAARecord": false
#             },
#             "BlockPublicAccessStates": {
#                 "InternetGatewayBlockMode": "off"
#             },
#             "SubnetId": "subnet-0122da2129d691098",
#             "State": "available",
#             "VpcId": "vpc-09d06141d745ce35f",
#             "CidrBlock": "10.0.0.0/24",
#             "AvailableIpAddressCount": 250,
#             "AvailabilityZone": "us-east-1a",
#             "DefaultForAz": false,
#             "MapPublicIpOnLaunch": false
#         },
#         {
#             "AvailabilityZoneId": "use1-az4",
#             "MapCustomerOwnedIpOnLaunch": false,
#             "OwnerId": "609009159737",
#             "AssignIpv6AddressOnCreation": false,
#             "Ipv6CidrBlockAssociationSet": [],
#             "Tags": [
#                 {
#                     "Key": "Name",
#                     "Value": "private-subnet-1"
#                 }
#             ],
#             "SubnetArn": "arn:aws:ec2:us-east-1:609009159737:subnet/subnet-0a9ddef84ff975a4b",
#             "EnableDns64": false,
#             "Ipv6Native": false,
#             "PrivateDnsNameOptionsOnLaunch": {
#                 "HostnameType": "ip-name",
#                 "EnableResourceNameDnsARecord": false,
#                 "EnableResourceNameDnsAAAARecord": false
#             },
#             "BlockPublicAccessStates": {
#                 "InternetGatewayBlockMode": "off"
#             },
#             "SubnetId": "subnet-0a9ddef84ff975a4b",
#             "State": "available",
#             "VpcId": "vpc-09d06141d745ce35f",
#             "CidrBlock": "10.0.1.0/24",
#             "AvailableIpAddressCount": 251,
#             "AvailabilityZone": "us-east-1a",
#             "DefaultForAz": false,
#             "MapPublicIpOnLaunch": false
#         }
#     ]
# }
# {
#     "RouteTables": [
#         {
#             "Associations": [
#                 {
#                     "Main": false,
#                     "RouteTableAssociationId": "rtbassoc-0369cf17e84ad5dd2",
#                     "RouteTableId": "rtb-0d592d6d93b2b0981",
#                     "SubnetId": "subnet-0e0f1ec3d6fa55ba1",
#                     "AssociationState": {
#                         "State": "associated"
#                     }
#                 },
#                 {
#                     "Main": false,
#                     "RouteTableAssociationId": "rtbassoc-09354b98ef22e6b5d",
#                     "RouteTableId": "rtb-0d592d6d93b2b0981",
#                     "SubnetId": "subnet-0a9ddef84ff975a4b",
#                     "AssociationState": {
#                         "State": "associated"
#                     }
#                 }
#             ],
#             "PropagatingVgws": [],
#             "RouteTableId": "rtb-0d592d6d93b2b0981",
#             "Routes": [
#                 {
#                     "DestinationCidrBlock": "10.0.0.0/16",
#                     "GatewayId": "local",
#                     "Origin": "CreateRouteTable",
#                     "State": "active"
#                 },
#                 {
#                     "DestinationCidrBlock": "0.0.0.0/0",
#                     "NatGatewayId": "nat-07b8255225e45e0b0",
#                     "Origin": "CreateRoute",
#                     "State": "active"
#                 }
#             ],
#             "Tags": [
#                 {
#                     "Key": "Name",
#                     "Value": "private-rt"
#                 }
#             ],
#             "VpcId": "vpc-09d06141d745ce35f",
#             "OwnerId": "609009159737"
#         },
#         {
#             "Associations": [
#                 {
#                     "Main": true,
#                     "RouteTableAssociationId": "rtbassoc-06109bf38b75bf0b8",
#                     "RouteTableId": "rtb-0ca1006226e7c0188",
#                     "AssociationState": {
#                         "State": "associated"
#                     }
#                 }
#             ],
#             "PropagatingVgws": [],
#             "RouteTableId": "rtb-0ca1006226e7c0188",
#             "Routes": [
#                 {
#                     "DestinationCidrBlock": "10.0.0.0/16",
#                     "GatewayId": "local",
#                     "Origin": "CreateRouteTable",
#                     "State": "active"
#                 }
#             ],
#             "Tags": [],
#             "VpcId": "vpc-09d06141d745ce35f",
#             "OwnerId": "609009159737"
#         },
#         {
#             "Associations": [
#                 {
#                     "Main": false,
#                     "RouteTableAssociationId": "rtbassoc-01f7b02613d758fff",
#                     "RouteTableId": "rtb-0c35f0d2e95f8b3ee",
#                     "SubnetId": "subnet-0122da2129d691098",
#                     "AssociationState": {
#                         "State": "associated"
#                     }
#                 }
#             ],
#             "PropagatingVgws": [],
#             "RouteTableId": "rtb-0c35f0d2e95f8b3ee",
#             "Routes": [
#                 {
#                     "DestinationCidrBlock": "10.0.0.0/16",
#                     "GatewayId": "local",
#                     "Origin": "CreateRouteTable",
#                     "State": "active"
#                 },
#                 {
#                     "DestinationCidrBlock": "0.0.0.0/0",
#                     "GatewayId": "igw-06334980ce938c2a0",
#                     "Origin": "CreateRoute",
#                     "State": "active"
#                 }
#             ],
#             "Tags": [
#                 {
#                     "Key": "Name",
#                     "Value": "public-rt"
#                 }
#             ],
#             "VpcId": "vpc-09d06141d745ce35f",
#             "OwnerId": "609009159737"
#         }
#     ]
# }
# {
#     "InternetGateways": [
#         {
#             "Attachments": [
#                 {
#                     "State": "available",
#                     "VpcId": "vpc-09d06141d745ce35f"
#                 }
#             ],
#             "InternetGatewayId": "igw-06334980ce938c2a0",
#             "OwnerId": "609009159737",
#             "Tags": [
#                 {
#                     "Key": "Name",
#                     "Value": "my-igw"
#                 }
#             ]
#         }
#     ]
# }
# {
#     "NatGateways": [
#         {
#             "CreateTime": "2025-08-25T22:51:37.000Z",
#             "NatGatewayAddresses": [
#                 {
#                     "AllocationId": "eipalloc-01a7c8f7772f11809",
#                     "NetworkInterfaceId": "eni-0b4217017d2cf1cb0",
#                     "PrivateIp": "10.0.0.151",
#                     "PublicIp": "44.193.132.177",
#                     "AssociationId": "eipassoc-08ea10c22c56609b3",
#                     "IsPrimary": true,
#                     "Status": "succeeded"
#                 }
#             ],
#             "NatGatewayId": "nat-07b8255225e45e0b0",
#             "State": "available",
#             "SubnetId": "subnet-0122da2129d691098",
#             "VpcId": "vpc-09d06141d745ce35f",
#             "Tags": [
#                 {
#                     "Key": "Name",
#                     "Value": "my-nat"
#                 }
#             ],
#             "ConnectivityType": "public"
#         }
#     ]
# }

# %%
# %%writefile nacl.tf
# resource "aws_network_acl" "my_nacl" {
#   vpc_id = aws_vpc.my_vpc.id
#   tags = {
#     Name = "my-nacl"
#   }
# }
#
# # Inbound Allow All
# resource "aws_network_acl_rule" "inbound_allow_all" {
#   network_acl_id = aws_network_acl.my_nacl.id
#   rule_number    = 100
#   egress         = false
#   protocol       = "-1"
#   rule_action    = "allow"
#   cidr_block     = "0.0.0.0/0"
# }
#
# # Outbound Allow All
# resource "aws_network_acl_rule" "outbound_allow_all" {
#   network_acl_id = aws_network_acl.my_nacl.id
#   rule_number    = 100
#   egress         = true
#   protocol       = "-1"
#   rule_action    = "allow"
#   cidr_block     = "0.0.0.0/0"
# }
#
# # Associations
# resource "aws_network_acl_association" "public_nacl_assoc" {
#   subnet_id      = aws_subnet.public_subnet.id
#   network_acl_id = aws_network_acl.my_nacl.id
# }
#
# resource "aws_network_acl_association" "private_1_nacl_assoc" {
#   subnet_id      = aws_subnet.private_subnet_1.id
#   network_acl_id = aws_network_acl.my_nacl.id
# }
#
# resource "aws_network_acl_association" "private_2_nacl_assoc" {
#   subnet_id      = aws_subnet.private_subnet_2.id
#   network_acl_id = aws_network_acl.my_nacl.id
# }
# Out:
# Writing nacl.tf

# %%
# !terraform plan
# Out:
# aws_vpc.my_vpc: Refreshing state... [id=vpc-09d06141d745ce35f]
# aws_eip.nat_eip: Refreshing state... [id=eipalloc-01a7c8f7772f11809]
# aws_subnet.private_subnet_2: Refreshing state... [id=subnet-0e0f1ec3d6fa55ba1]
# aws_subnet.private_subnet_1: Refreshing state... [id=subnet-0a9ddef84ff975a4b]
# aws_subnet.public_subnet: Refreshing state... [id=subnet-0122da2129d691098]
# aws_internet_gateway.my_igw: Refreshing state... [id=igw-06334980ce938c2a0]
# aws_route_table.public_rt: Refreshing state... [id=rtb-0c35f0d2e95f8b3ee]
# aws_route_table.private_rt: Refreshing state... [id=rtb-0d592d6d93b2b0981]
# aws_route.public_internet: Refreshing state... [id=r-rtb-0c35f0d2e95f8b3ee1080289494]
# aws_route_table_association.private_assoc_2: Refreshing state... [id=rtbassoc-0369cf17e84ad5dd2]
# aws_route_table_association.private_assoc_1: Refreshing state... [id=rtbassoc-09354b98ef22e6b5d]
# aws_route_table_association.public_assoc: Refreshing state... [id=rtbassoc-01f7b02613d758fff]
# aws_nat_gateway.my_nat: Refreshing state... [id=nat-07b8255225e45e0b0]
# aws_route.private_nat: Refreshing state... [id=r-rtb-0d592d6d93b2b09811080289494]
#
# Terraform used the selected providers to generate the following execution plan.
# Resource actions are indicated with the following symbols:
#   + create
#
# Terraform will perform the following actions:
#
#   # aws_network_acl.my_nacl will be created
#   + resource "aws_network_acl" "my_nacl" {
#       + arn        = (known after apply)
#       + egress     = (known after apply)
#       + id         = (known after apply)
#       + ingress    = (known after apply)
#       + owner_id   = (known after apply)
#       + subnet_ids = (known after apply)
#       + tags       = {
#           + "Name" = "my-nacl"
#         }
#       + tags_all   = {
#           + "Name" = "my-nacl"
#         }
#       + vpc_id     = "vpc-09d06141d745ce35f"
#     }
#
#   # aws_network_acl_association.private_1_nacl_assoc will be created
#   + resource "aws_network_acl_association" "private_1_nacl_assoc" {
#       + id             = (known after apply)
#       + network_acl_id = (known after apply)
#       + subnet_id      = "subnet-0a9ddef84ff975a4b"
#     }
#
#   # aws_network_acl_association.private_2_nacl_assoc will be created
#   + resource "aws_network_acl_association" "private_2_nacl_assoc" {
#       + id             = (known after apply)
#       + network_acl_id = (known after apply)
#       + subnet_id      = "subnet-0e0f1ec3d6fa55ba1"
#     }
#
#   # aws_network_acl_association.public_nacl_assoc will be created
#   + resource "aws_network_acl_association" "public_nacl_assoc" {
#       + id             = (known after apply)
#       + network_acl_id = (known after apply)
#       + subnet_id      = "subnet-0122da2129d691098"
#     }
#
#   # aws_network_acl_rule.inbound_allow_all will be created
#   + resource "aws_network_acl_rule" "inbound_allow_all" {
#       + cidr_block     = "0.0.0.0/0"
#       + egress         = false
#       + id             = (known after apply)
#       + network_acl_id = (known after apply)
#       + protocol       = "-1"
#       + rule_action    = "allow"
#       + rule_number    = 100
#     }
#
#   # aws_network_acl_rule.outbound_allow_all will be created
#   + resource "aws_network_acl_rule" "outbound_allow_all" {
#       + cidr_block     = "0.0.0.0/0"
#       + egress         = true
#       + id             = (known after apply)
#       + network_acl_id = (known after apply)
#       + protocol       = "-1"
#       + rule_action    = "allow"
#       + rule_number    = 100
#     }
#
# Plan: 6 to add, 0 to change, 0 to destroy.
#
# ───────────────────────────────────────────────────────────────────────────────
#
# Note: You didn't use the -out option to save this plan, so Terraform can't
# guarantee to take exactly these actions if you run "terraform apply" now.

# %%
# !terraform apply --auto-approve
# Out:
# aws_eip.nat_eip: Refreshing state... [id=eipalloc-01a7c8f7772f11809]
# aws_vpc.my_vpc: Refreshing state... [id=vpc-09d06141d745ce35f]
# aws_internet_gateway.my_igw: Refreshing state... [id=igw-06334980ce938c2a0]
# aws_route_table.private_rt: Refreshing state... [id=rtb-0d592d6d93b2b0981]
# aws_subnet.public_subnet: Refreshing state... [id=subnet-0122da2129d691098]
# aws_subnet.private_subnet_2: Refreshing state... [id=subnet-0e0f1ec3d6fa55ba1]
# aws_route_table.public_rt: Refreshing state... [id=rtb-0c35f0d2e95f8b3ee]
# aws_subnet.private_subnet_1: Refreshing state... [id=subnet-0a9ddef84ff975a4b]
# aws_route_table_association.private_assoc_1: Refreshing state... [id=rtbassoc-09354b98ef22e6b5d]
# aws_route.public_internet: Refreshing state... [id=r-rtb-0c35f0d2e95f8b3ee1080289494]
# aws_route_table_association.private_assoc_2: Refreshing state... [id=rtbassoc-0369cf17e84ad5dd2]
# aws_nat_gateway.my_nat: Refreshing state... [id=nat-07b8255225e45e0b0]
# aws_route_table_association.public_assoc: Refreshing state... [id=rtbassoc-01f7b02613d758fff]
# aws_route.private_nat: Refreshing state... [id=r-rtb-0d592d6d93b2b09811080289494]
#
# Terraform used the selected providers to generate the following execution plan.
# Resource actions are indicated with the following symbols:
#   + create
#
# Terraform will perform the following actions:
#
#   # aws_network_acl.my_nacl will be created
#   + resource "aws_network_acl" "my_nacl" {
#       + arn        = (known after apply)
#       + egress     = (known after apply)
#       + id         = (known after apply)
#       + ingress    = (known after apply)
#       + owner_id   = (known after apply)
#       + subnet_ids = (known after apply)
#       + tags       = {
#           + "Name" = "my-nacl"
#         }
#       + tags_all   = {
#           + "Name" = "my-nacl"
#         }
#       + vpc_id     = "vpc-09d06141d745ce35f"
#     }
#
#   # aws_network_acl_association.private_1_nacl_assoc will be created
#   + resource "aws_network_acl_association" "private_1_nacl_assoc" {
#       + id             = (known after apply)
#       + network_acl_id = (known after apply)
#       + subnet_id      = "subnet-0a9ddef84ff975a4b"
#     }
#
#   # aws_network_acl_association.private_2_nacl_assoc will be created
#   + resource "aws_network_acl_association" "private_2_nacl_assoc" {
#       + id             = (known after apply)
#       + network_acl_id = (known after apply)
#       + subnet_id      = "subnet-0e0f1ec3d6fa55ba1"
#     }
#
#   # aws_network_acl_association.public_nacl_assoc will be created
#   + resource "aws_network_acl_association" "public_nacl_assoc" {
#       + id             = (known after apply)
#       + network_acl_id = (known after apply)
#       + subnet_id      = "subnet-0122da2129d691098"
#     }
#
#   # aws_network_acl_rule.inbound_allow_all will be created
#   + resource "aws_network_acl_rule" "inbound_allow_all" {
#       + cidr_block     = "0.0.0.0/0"
#       + egress         = false
#       + id             = (known after apply)
#       + network_acl_id = (known after apply)
#       + protocol       = "-1"
#       + rule_action    = "allow"
#       + rule_number    = 100
#     }
#
#   # aws_network_acl_rule.outbound_allow_all will be created
#   + resource "aws_network_acl_rule" "outbound_allow_all" {
#       + cidr_block     = "0.0.0.0/0"
#       + egress         = true
#       + id             = (known after apply)
#       + network_acl_id = (known after apply)
#       + protocol       = "-1"
#       + rule_action    = "allow"
#       + rule_number    = 100
#     }
#
# Plan: 6 to add, 0 to change, 0 to destroy.
# aws_network_acl.my_nacl: Creating...
# aws_network_acl.my_nacl: Creation complete after 0s [id=acl-044a1c4ecc41bc076]
# aws_network_acl_association.private_2_nacl_assoc: Creating...
# aws_network_acl_rule.outbound_allow_all: Creating...
# aws_network_acl_association.private_1_nacl_assoc: Creating...
# aws_network_acl_rule.inbound_allow_all: Creating...
# aws_network_acl_association.public_nacl_assoc: Creating...
# aws_network_acl_rule.inbound_allow_all: Creation complete after 0s [id=nacl-1847467266]
# aws_network_acl_association.private_1_nacl_assoc: Creation complete after 1s [id=aclassoc-04ea4662a4bd8450a]
# aws_network_acl_association.private_2_nacl_assoc: Creation complete after 1s [id=aclassoc-0387ab3f5d00dc778]
# aws_network_acl_association.public_nacl_assoc: Creation complete after 1s [id=aclassoc-033cf7be9b70f2539]
# aws_network_acl_rule.outbound_allow_all: Creation complete after 1s [id=nacl-1970693416]
#
# Apply complete! Resources: 6 added, 0 changed, 0 destroyed.
#
# Outputs:
#
# vpc_id = "vpc-09d06141d745ce35f"

# %%
# %%bash
# VPC_ID=$(terraform output -raw vpc_id)
#
# # Get NACL ID (filter by tag)
# NACL_ID=$(aws ec2 describe-network-acls --filters "Name=vpc-id,Values=$VPC_ID" "Name=tag:Name,Values=my-nacl" --query "NetworkAcls[0].NetworkAclId" --output text)
#
# # Verify NACL
# aws ec2 describe-network-acls --network-acl-ids $NACL_ID
# Out:
# {
#     "NetworkAcls": [
#         {
#             "Associations": [
#                 {
#                     "NetworkAclAssociationId": "aclassoc-0387ab3f5d00dc778",
#                     "NetworkAclId": "acl-044a1c4ecc41bc076",
#                     "SubnetId": "subnet-0e0f1ec3d6fa55ba1"
#                 },
#                 {
#                     "NetworkAclAssociationId": "aclassoc-04ea4662a4bd8450a",
#                     "NetworkAclId": "acl-044a1c4ecc41bc076",
#                     "SubnetId": "subnet-0a9ddef84ff975a4b"
#                 },
#                 {
#                     "NetworkAclAssociationId": "aclassoc-033cf7be9b70f2539",
#                     "NetworkAclId": "acl-044a1c4ecc41bc076",
#                     "SubnetId": "subnet-0122da2129d691098"
#                 }
#             ],
#             "Entries": [
#                 {
#                     "CidrBlock": "0.0.0.0/0",
#                     "Egress": true,
#                     "Protocol": "-1",
#                     "RuleAction": "allow",
#                     "RuleNumber": 100
#                 },
#                 {
#                     "CidrBlock": "0.0.0.0/0",
#                     "Egress": true,
#                     "Protocol": "-1",
#                     "RuleAction": "deny",
#                     "RuleNumber": 32767
#                 },
#                 {
#                     "CidrBlock": "0.0.0.0/0",
#                     "Egress": false,
#                     "Protocol": "-1",
#                     "RuleAction": "allow",
#                     "RuleNumber": 100
#                 },
#                 {
#                     "CidrBlock": "0.0.0.0/0",
#                     "Egress": false,
#                     "Protocol": "-1",
#                     "RuleAction": "deny",
#                     "RuleNumber": 32767
#                 }
#             ],
#             "IsDefault": false,
#             "NetworkAclId": "acl-044a1c4ecc41bc076",
#             "Tags": [
#                 {
#                     "Key": "Name",
#                     "Value": "my-nacl"
#                 }
#             ],
#             "VpcId": "vpc-09d06141d745ce35f",
#             "OwnerId": "609009159737"
#         }
#     ]
# }

# %%
# %%writefile security_groups.tf
# # SageMaker Security Group
# resource "aws_security_group" "sagemaker_sg" {
#   name        = "sagemaker-sg"
#   description = "For SageMaker"
#   vpc_id      = aws_vpc.my_vpc.id
#
#   egress {
#     from_port   = 0
#     to_port     = 0
#     protocol    = "-1"
#     cidr_blocks = ["0.0.0.0/0"]
#   }
#
#   tags = {
#     Name = "sagemaker-sg"
#   }
# }
#
# # EC2 Security Group
# resource "aws_security_group" "ec2_sg" {
#   name        = "ec2-sg"
#   description = "For EC2 MongoDB"
#   vpc_id      = aws_vpc.my_vpc.id
#
#   ingress {
#     from_port       = var.mongodb_port
#     to_port         = var.mongodb_port
#     protocol        = "tcp"
#     security_groups = [aws_security_group.sagemaker_sg.id]
#   }
#
#   egress {
#     from_port   = 0
#     to_port     = 0
#     protocol    = "-1"
#     cidr_blocks = ["0.0.0.0/0"]
#   }
#
#   tags = {
#     Name = "ec2-sg"
#   }
# }
# Out:
# Writing security_groups.tf

# %%
# %%bash
# terraform plan
# Out:
# aws_eip.nat_eip: Refreshing state... [id=eipalloc-01a7c8f7772f11809]
# aws_vpc.my_vpc: Refreshing state... [id=vpc-09d06141d745ce35f]
# aws_subnet.public_subnet: Refreshing state... [id=subnet-0122da2129d691098]
# aws_subnet.private_subnet_1: Refreshing state... [id=subnet-0a9ddef84ff975a4b]
# aws_route_table.private_rt: Refreshing state... [id=rtb-0d592d6d93b2b0981]
# aws_subnet.private_subnet_2: Refreshing state... [id=subnet-0e0f1ec3d6fa55ba1]
# aws_route_table.public_rt: Refreshing state... [id=rtb-0c35f0d2e95f8b3ee]
# aws_internet_gateway.my_igw: Refreshing state... [id=igw-06334980ce938c2a0]
# aws_network_acl.my_nacl: Refreshing state... [id=acl-044a1c4ecc41bc076]
# aws_route.public_internet: Refreshing state... [id=r-rtb-0c35f0d2e95f8b3ee1080289494]
# aws_network_acl_rule.outbound_allow_all: Refreshing state... [id=nacl-1970693416]
# aws_network_acl_rule.inbound_allow_all: Refreshing state... [id=nacl-1847467266]
# aws_network_acl_association.private_2_nacl_assoc: Refreshing state... [id=aclassoc-0387ab3f5d00dc778]
# aws_route_table_association.private_assoc_2: Refreshing state... [id=rtbassoc-0369cf17e84ad5dd2]
# aws_network_acl_association.private_1_nacl_assoc: Refreshing state... [id=aclassoc-04ea4662a4bd8450a]
# aws_route_table_association.private_assoc_1: Refreshing state... [id=rtbassoc-09354b98ef22e6b5d]
# aws_nat_gateway.my_nat: Refreshing state... [id=nat-07b8255225e45e0b0]
# aws_network_acl_association.public_nacl_assoc: Refreshing state... [id=aclassoc-033cf7be9b70f2539]
# aws_route_table_association.public_assoc: Refreshing state... [id=rtbassoc-01f7b02613d758fff]
# aws_route.private_nat: Refreshing state... [id=r-rtb-0d592d6d93b2b09811080289494]
#
# Terraform used the selected providers to generate the following execution
# plan. Resource actions are indicated with the following symbols:
#   + create
#
# Terraform will perform the following actions:
#
#   # aws_security_group.ec2_sg will be created
#   + resource "aws_security_group" "ec2_sg" {
#       + arn                    = (known after apply)
#       + description            = "For EC2 MongoDB"
#       + egress                 = [
#           + {
#               + cidr_blocks      = [
#                   + "0.0.0.0/0",
#                 ]
#               + from_port        = 0
#               + ipv6_cidr_blocks = []
#               + prefix_list_ids  = []
#               + protocol         = "-1"
#               + security_groups  = []
#               + self             = false
#               + to_port          = 0
#                 # (1 unchanged attribute hidden)
#             },
#         ]
#       + id                     = (known after apply)
#       + ingress                = [
#           + {
#               + cidr_blocks      = []
#               + from_port        = 3307
#               + ipv6_cidr_blocks = []
#               + prefix_list_ids  = []
#               + protocol         = "tcp"
#               + security_groups  = (known after apply)
#               + self             = false
#               + to_port          = 3307
#                 # (1 unchanged attribute hidden)
#             },
#         ]
#       + name                   = "ec2-sg"
#       + name_prefix            = (known after apply)
#       + owner_id               = (known after apply)
#       + revoke_rules_on_delete = false
#       + tags                   = {
#           + "Name" = "ec2-sg"
#         }
#       + tags_all               = {
#           + "Name" = "ec2-sg"
#         }
#       + vpc_id                 = "vpc-09d06141d745ce35f"
#     }
#
#   # aws_security_group.sagemaker_sg will be created
#   + resource "aws_security_group" "sagemaker_sg" {
#       + arn                    = (known after apply)
#       + description            = "For SageMaker"
#       + egress                 = [
#           + {
#               + cidr_blocks      = [
#                   + "0.0.0.0/0",
#                 ]
#               + from_port        = 0
#               + ipv6_cidr_blocks = []
#               + prefix_list_ids  = []
#               + protocol         = "-1"
#               + security_groups  = []
#               + self             = false
#               + to_port          = 0
#                 # (1 unchanged attribute hidden)
#             },
#         ]
#       + id                     = (known after apply)
#       + ingress                = (known after apply)
#       + name                   = "sagemaker-sg"
#       + name_prefix            = (known after apply)
#       + owner_id               = (known after apply)
#       + revoke_rules_on_delete = false
#       + tags                   = {
#           + "Name" = "sagemaker-sg"
#         }
#       + tags_all               = {
#           + "Name" = "sagemaker-sg"
#         }
#       + vpc_id                 = "vpc-09d06141d745ce35f"
#     }
#
# Plan: 2 to add, 0 to change, 0 to destroy.
#
# ─────────────────────────────────────────────────────────────────────────────
#
# Note: You didn't use the -out option to save this plan, so Terraform can't
# guarantee to take exactly these actions if you run "terraform apply" now.

# %%
# %%bash
# terraform apply -auto-approve
# Out:
# aws_vpc.my_vpc: Refreshing state... [id=vpc-09d06141d745ce35f]
# aws_eip.nat_eip: Refreshing state... [id=eipalloc-01a7c8f7772f11809]
# aws_route_table.public_rt: Refreshing state... [id=rtb-0c35f0d2e95f8b3ee]
# aws_route_table.private_rt: Refreshing state... [id=rtb-0d592d6d93b2b0981]
# aws_network_acl.my_nacl: Refreshing state... [id=acl-044a1c4ecc41bc076]
# aws_subnet.private_subnet_1: Refreshing state... [id=subnet-0a9ddef84ff975a4b]
# aws_subnet.public_subnet: Refreshing state... [id=subnet-0122da2129d691098]
# aws_subnet.private_subnet_2: Refreshing state... [id=subnet-0e0f1ec3d6fa55ba1]
# aws_internet_gateway.my_igw: Refreshing state... [id=igw-06334980ce938c2a0]
# aws_network_acl_rule.outbound_allow_all: Refreshing state... [id=nacl-1970693416]
# aws_network_acl_rule.inbound_allow_all: Refreshing state... [id=nacl-1847467266]
# aws_route.public_internet: Refreshing state... [id=r-rtb-0c35f0d2e95f8b3ee1080289494]
# aws_route_table_association.private_assoc_2: Refreshing state... [id=rtbassoc-0369cf17e84ad5dd2]
# aws_network_acl_association.private_2_nacl_assoc: Refreshing state... [id=aclassoc-0387ab3f5d00dc778]
# aws_route_table_association.private_assoc_1: Refreshing state... [id=rtbassoc-09354b98ef22e6b5d]
# aws_route_table_association.public_assoc: Refreshing state... [id=rtbassoc-01f7b02613d758fff]
# aws_network_acl_association.private_1_nacl_assoc: Refreshing state... [id=aclassoc-04ea4662a4bd8450a]
# aws_network_acl_association.public_nacl_assoc: Refreshing state... [id=aclassoc-033cf7be9b70f2539]
# aws_nat_gateway.my_nat: Refreshing state... [id=nat-07b8255225e45e0b0]
# aws_route.private_nat: Refreshing state... [id=r-rtb-0d592d6d93b2b09811080289494]
#
# Terraform used the selected providers to generate the following execution
# plan. Resource actions are indicated with the following symbols:
#   + create
#
# Terraform will perform the following actions:
#
#   # aws_security_group.ec2_sg will be created
#   + resource "aws_security_group" "ec2_sg" {
#       + arn                    = (known after apply)
#       + description            = "For EC2 MongoDB"
#       + egress                 = [
#           + {
#               + cidr_blocks      = [
#                   + "0.0.0.0/0",
#                 ]
#               + from_port        = 0
#               + ipv6_cidr_blocks = []
#               + prefix_list_ids  = []
#               + protocol         = "-1"
#               + security_groups  = []
#               + self             = false
#               + to_port          = 0
#                 # (1 unchanged attribute hidden)
#             },
#         ]
#       + id                     = (known after apply)
#       + ingress                = [
#           + {
#               + cidr_blocks      = []
#               + from_port        = 3307
#               + ipv6_cidr_blocks = []
#               + prefix_list_ids  = []
#               + protocol         = "tcp"
#               + security_groups  = (known after apply)
#               + self             = false
#               + to_port          = 3307
#                 # (1 unchanged attribute hidden)
#             },
#         ]
#       + name                   = "ec2-sg"
#       + name_prefix            = (known after apply)
#       + owner_id               = (known after apply)
#       + revoke_rules_on_delete = false
#       + tags                   = {
#           + "Name" = "ec2-sg"
#         }
#       + tags_all               = {
#           + "Name" = "ec2-sg"
#         }
#       + vpc_id                 = "vpc-09d06141d745ce35f"
#     }
#
#   # aws_security_group.sagemaker_sg will be created
#   + resource "aws_security_group" "sagemaker_sg" {
#       + arn                    = (known after apply)
#       + description            = "For SageMaker"
#       + egress                 = [
#           + {
#               + cidr_blocks      = [
#                   + "0.0.0.0/0",
#                 ]
#               + from_port        = 0
#               + ipv6_cidr_blocks = []
#               + prefix_list_ids  = []
#               + protocol         = "-1"
#               + security_groups  = []
#               + self             = false
#               + to_port          = 0
#                 # (1 unchanged attribute hidden)
#             },
#         ]
#       + id                     = (known after apply)
#       + ingress                = (known after apply)
#       + name                   = "sagemaker-sg"
#       + name_prefix            = (known after apply)
#       + owner_id               = (known after apply)
#       + revoke_rules_on_delete = false
#       + tags                   = {
#           + "Name" = "sagemaker-sg"
#         }
#       + tags_all               = {
#           + "Name" = "sagemaker-sg"
#         }
#       + vpc_id                 = "vpc-09d06141d745ce35f"
#     }
#
# Plan: 2 to add, 0 to change, 0 to destroy.
# aws_security_group.sagemaker_sg: Creating...
# aws_security_group.sagemaker_sg: Creation complete after 2s [id=sg-0485562c610ce365f]
# aws_security_group.ec2_sg: Creating...
# aws_security_group.ec2_sg: Creation complete after 1s [id=sg-08d3bc7e3f0057d80]
#
# Apply complete! Resources: 2 added, 0 changed, 0 destroyed.
#
# Outputs:
#
# vpc_id = "vpc-09d06141d745ce35f"

# %%
# %%bash
# VPC_ID=$(terraform output -raw vpc_id)
#
# # Describe all SGs in VPC
# aws ec2 describe-security-groups --filters "Name=vpc-id,Values=$VPC_ID"
# Out:
# {
#     "SecurityGroups": [
#         {
#             "GroupId": "sg-08d3bc7e3f0057d80",
#             "IpPermissionsEgress": [
#                 {
#                     "IpProtocol": "-1",
#                     "UserIdGroupPairs": [],
#                     "IpRanges": [
#                         {
#                             "CidrIp": "0.0.0.0/0"
#                         }
#                     ],
#                     "Ipv6Ranges": [],
#                     "PrefixListIds": []
#                 }
#             ],
#             "Tags": [
#                 {
#                     "Key": "Name",
#                     "Value": "ec2-sg"
#                 }
#             ],
#             "VpcId": "vpc-09d06141d745ce35f",
#             "SecurityGroupArn": "arn:aws:ec2:us-east-1:609009159737:security-group/sg-08d3bc7e3f0057d80",
#             "OwnerId": "609009159737",
#             "GroupName": "ec2-sg",
#             "Description": "For EC2 MongoDB",
#             "IpPermissions": [
#                 {
#                     "IpProtocol": "tcp",
#                     "FromPort": 3307,
#                     "ToPort": 3307,
#                     "UserIdGroupPairs": [
#                         {
#                             "UserId": "609009159737",
#                             "GroupId": "sg-0485562c610ce365f"
#                         }
#                     ],
#                     "IpRanges": [],
#                     "Ipv6Ranges": [],
#                     "PrefixListIds": []
#                 }
#             ]
#         },
#         {
#             "GroupId": "sg-06b4b4e67118e00da",
#             "IpPermissionsEgress": [
#                 {
#                     "IpProtocol": "-1",
#                     "UserIdGroupPairs": [],
#                     "IpRanges": [
#                         {
#                             "CidrIp": "0.0.0.0/0"
#                         }
#                     ],
#                     "Ipv6Ranges": [],
#                     "PrefixListIds": []
#                 }
#             ],
#             "VpcId": "vpc-09d06141d745ce35f",
#             "SecurityGroupArn": "arn:aws:ec2:us-east-1:609009159737:security-group/sg-06b4b4e67118e00da",
#             "OwnerId": "609009159737",
#             "GroupName": "default",
#             "Description": "default VPC security group",
#             "IpPermissions": [
#                 {
#                     "IpProtocol": "-1",
#                     "UserIdGroupPairs": [
#                         {
#                             "UserId": "609009159737",
#                             "GroupId": "sg-06b4b4e67118e00da"
#                         }
#                     ],
#                     "IpRanges": [],
#                     "Ipv6Ranges": [],
#                     "PrefixListIds": []
#                 }
#             ]
#         },
#         {
#             "GroupId": "sg-0485562c610ce365f",
#             "IpPermissionsEgress": [
#                 {
#                     "IpProtocol": "-1",
#                     "UserIdGroupPairs": [],
#                     "IpRanges": [
#                         {
#                             "CidrIp": "0.0.0.0/0"
#                         }
#                     ],
#                     "Ipv6Ranges": [],
#                     "PrefixListIds": []
#                 }
#             ],
#             "Tags": [
#                 {
#                     "Key": "Name",
#                     "Value": "sagemaker-sg"
#                 }
#             ],
#             "VpcId": "vpc-09d06141d745ce35f",
#             "SecurityGroupArn": "arn:aws:ec2:us-east-1:609009159737:security-group/sg-0485562c610ce365f",
#             "OwnerId": "609009159737",
#             "GroupName": "sagemaker-sg",
#             "Description": "For SageMaker",
#             "IpPermissions": []
#         }
#     ]
# }

# %%
# %%writefile iam.tf
# # SageMaker Execution Role
# resource "aws_iam_role" "sagemaker_role" {
#   name = "SageMakerRole"
#   assume_role_policy = jsonencode({
#     Version = "2012-10-17"
#     Statement = [
#       {
#         Action = "sts:AssumeRole"
#         Effect = "Allow"
#         Principal = {
#           Service = "sagemaker.amazonaws.com"
#         }
#       },
#     ]
#   })
# }
#
# resource "aws_iam_role_policy_attachment" "sagemaker_full_access" {
#   role       = aws_iam_role.sagemaker_role.name
#   policy_arn = "arn:aws:iam::aws:policy/AmazonSageMakerFullAccess"
# }
#
# # EC2 SSM Role
# resource "aws_iam_role" "ec2_ssm_role" {
#   name = "EC2SSMRole"
#   assume_role_policy = jsonencode({
#     Version = "2012-10-17"
#     Statement = [
#       {
#         Action = "sts:AssumeRole"
#         Effect = "Allow"
#         Principal = {
#           Service = "ec2.amazonaws.com"
#         }
#       },
#     ]
#   })
# }
#
# resource "aws_iam_role_policy_attachment" "ec2_ssm_access" {
#   role       = aws_iam_role.ec2_ssm_role.name
#   policy_arn = "arn:aws:iam::aws:policy/AmazonSSMManagedInstanceCore"
# }
#
# resource "aws_iam_instance_profile" "ec2_ssm_profile" {
#   name = "EC2SSMProfile"
#   role = aws_iam_role.ec2_ssm_role.name
# }
# Out:
# Writing iam.tf

# %%
# %%bash
# terraform plan
# Out:
# aws_eip.nat_eip: Refreshing state... [id=eipalloc-01a7c8f7772f11809]
# aws_vpc.my_vpc: Refreshing state... [id=vpc-09d06141d745ce35f]
# aws_network_acl.my_nacl: Refreshing state... [id=acl-044a1c4ecc41bc076]
# aws_subnet.public_subnet: Refreshing state... [id=subnet-0122da2129d691098]
# aws_internet_gateway.my_igw: Refreshing state... [id=igw-06334980ce938c2a0]
# aws_subnet.private_subnet_2: Refreshing state... [id=subnet-0e0f1ec3d6fa55ba1]
# aws_subnet.private_subnet_1: Refreshing state... [id=subnet-0a9ddef84ff975a4b]
# aws_route_table.public_rt: Refreshing state... [id=rtb-0c35f0d2e95f8b3ee]
# aws_security_group.sagemaker_sg: Refreshing state... [id=sg-0485562c610ce365f]
# aws_route_table.private_rt: Refreshing state... [id=rtb-0d592d6d93b2b0981]
# aws_network_acl_rule.inbound_allow_all: Refreshing state... [id=nacl-1847467266]
# aws_network_acl_rule.outbound_allow_all: Refreshing state... [id=nacl-1970693416]
# aws_route.public_internet: Refreshing state... [id=r-rtb-0c35f0d2e95f8b3ee1080289494]
# aws_security_group.ec2_sg: Refreshing state... [id=sg-08d3bc7e3f0057d80]
# aws_route_table_association.private_assoc_1: Refreshing state... [id=rtbassoc-09354b98ef22e6b5d]
# aws_network_acl_association.private_1_nacl_assoc: Refreshing state... [id=aclassoc-04ea4662a4bd8450a]
# aws_route_table_association.public_assoc: Refreshing state... [id=rtbassoc-01f7b02613d758fff]
# aws_network_acl_association.public_nacl_assoc: Refreshing state... [id=aclassoc-033cf7be9b70f2539]
# aws_nat_gateway.my_nat: Refreshing state... [id=nat-07b8255225e45e0b0]
# aws_route_table_association.private_assoc_2: Refreshing state... [id=rtbassoc-0369cf17e84ad5dd2]
# aws_network_acl_association.private_2_nacl_assoc: Refreshing state... [id=aclassoc-0387ab3f5d00dc778]
# aws_route.private_nat: Refreshing state... [id=r-rtb-0d592d6d93b2b09811080289494]
#
# Terraform used the selected providers to generate the following execution
# plan. Resource actions are indicated with the following symbols:
#   + create
#
# Terraform will perform the following actions:
#
#   # aws_iam_instance_profile.ec2_ssm_profile will be created
#   + resource "aws_iam_instance_profile" "ec2_ssm_profile" {
#       + arn         = (known after apply)
#       + create_date = (known after apply)
#       + id          = (known after apply)
#       + name        = "EC2SSMProfile"
#       + name_prefix = (known after apply)
#       + path        = "/"
#       + role        = "EC2SSMRole"
#       + tags_all    = (known after apply)
#       + unique_id   = (known after apply)
#     }
#
#   # aws_iam_role.ec2_ssm_role will be created
#   + resource "aws_iam_role" "ec2_ssm_role" {
#       + arn                   = (known after apply)
#       + assume_role_policy    = jsonencode(
#             {
#               + Statement = [
#                   + {
#                       + Action    = "sts:AssumeRole"
#                       + Effect    = "Allow"
#                       + Principal = {
#                           + Service = "ec2.amazonaws.com"
#                         }
#                     },
#                 ]
#               + Version   = "2012-10-17"
#             }
#         )
#       + create_date           = (known after apply)
#       + force_detach_policies = false
#       + id                    = (known after apply)
#       + managed_policy_arns   = (known after apply)
#       + max_session_duration  = 3600
#       + name                  = "EC2SSMRole"
#       + name_prefix           = (known after apply)
#       + path                  = "/"
#       + tags_all              = (known after apply)
#       + unique_id             = (known after apply)
#
#       + inline_policy (known after apply)
#     }
#
#   # aws_iam_role.sagemaker_role will be created
#   + resource "aws_iam_role" "sagemaker_role" {
#       + arn                   = (known after apply)
#       + assume_role_policy    = jsonencode(
#             {
#               + Statement = [
#                   + {
#                       + Action    = "sts:AssumeRole"
#                       + Effect    = "Allow"
#                       + Principal = {
#                           + Service = "sagemaker.amazonaws.com"
#                         }
#                     },
#                 ]
#               + Version   = "2012-10-17"
#             }
#         )
#       + create_date           = (known after apply)
#       + force_detach_policies = false
#       + id                    = (known after apply)
#       + managed_policy_arns   = (known after apply)
#       + max_session_duration  = 3600
#       + name                  = "SageMakerRole"
#       + name_prefix           = (known after apply)
#       + path                  = "/"
#       + tags_all              = (known after apply)
#       + unique_id             = (known after apply)
#
#       + inline_policy (known after apply)
#     }
#
#   # aws_iam_role_policy_attachment.ec2_ssm_access will be created
#   + resource "aws_iam_role_policy_attachment" "ec2_ssm_access" {
#       + id         = (known after apply)
#       + policy_arn = "arn:aws:iam::aws:policy/AmazonSSMManagedInstanceCore"
#       + role       = "EC2SSMRole"
#     }
#
#   # aws_iam_role_policy_attachment.sagemaker_full_access will be created
#   + resource "aws_iam_role_policy_attachment" "sagemaker_full_access" {
#       + id         = (known after apply)
#       + policy_arn = "arn:aws:iam::aws:policy/AmazonSageMakerFullAccess"
#       + role       = "SageMakerRole"
#     }
#
# Plan: 5 to add, 0 to change, 0 to destroy.
#
# ─────────────────────────────────────────────────────────────────────────────
#
# Note: You didn't use the -out option to save this plan, so Terraform can't
# guarantee to take exactly these actions if you run "terraform apply" now.

# %%
# %%bash
# terraform apply -auto-approve
# Out:
# aws_vpc.my_vpc: Refreshing state... [id=vpc-09d06141d745ce35f]
# aws_eip.nat_eip: Refreshing state... [id=eipalloc-01a7c8f7772f11809]
# aws_internet_gateway.my_igw: Refreshing state... [id=igw-06334980ce938c2a0]
# aws_route_table.private_rt: Refreshing state... [id=rtb-0d592d6d93b2b0981]
# aws_network_acl.my_nacl: Refreshing state... [id=acl-044a1c4ecc41bc076]
# aws_route_table.public_rt: Refreshing state... [id=rtb-0c35f0d2e95f8b3ee]
# aws_subnet.private_subnet_1: Refreshing state... [id=subnet-0a9ddef84ff975a4b]
# aws_subnet.public_subnet: Refreshing state... [id=subnet-0122da2129d691098]
# aws_subnet.private_subnet_2: Refreshing state... [id=subnet-0e0f1ec3d6fa55ba1]
# aws_security_group.sagemaker_sg: Refreshing state... [id=sg-0485562c610ce365f]
# aws_nat_gateway.my_nat: Refreshing state... [id=nat-07b8255225e45e0b0]
# aws_network_acl_association.public_nacl_assoc: Refreshing state... [id=aclassoc-033cf7be9b70f2539]
# aws_route.public_internet: Refreshing state... [id=r-rtb-0c35f0d2e95f8b3ee1080289494]
# aws_route_table_association.public_assoc: Refreshing state... [id=rtbassoc-01f7b02613d758fff]
# aws_network_acl_rule.inbound_allow_all: Refreshing state... [id=nacl-1847467266]
# aws_network_acl_rule.outbound_allow_all: Refreshing state... [id=nacl-1970693416]
# aws_network_acl_association.private_2_nacl_assoc: Refreshing state... [id=aclassoc-0387ab3f5d00dc778]
# aws_route_table_association.private_assoc_2: Refreshing state... [id=rtbassoc-0369cf17e84ad5dd2]
# aws_route.private_nat: Refreshing state... [id=r-rtb-0d592d6d93b2b09811080289494]
# aws_network_acl_association.private_1_nacl_assoc: Refreshing state... [id=aclassoc-04ea4662a4bd8450a]
# aws_security_group.ec2_sg: Refreshing state... [id=sg-08d3bc7e3f0057d80]
# aws_route_table_association.private_assoc_1: Refreshing state... [id=rtbassoc-09354b98ef22e6b5d]
#
# Terraform used the selected providers to generate the following execution
# plan. Resource actions are indicated with the following symbols:
#   + create
#
# Terraform will perform the following actions:
#
#   # aws_iam_instance_profile.ec2_ssm_profile will be created
#   + resource "aws_iam_instance_profile" "ec2_ssm_profile" {
#       + arn         = (known after apply)
#       + create_date = (known after apply)
#       + id          = (known after apply)
#       + name        = "EC2SSMProfile"
#       + name_prefix = (known after apply)
#       + path        = "/"
#       + role        = "EC2SSMRole"
#       + tags_all    = (known after apply)
#       + unique_id   = (known after apply)
#     }
#
#   # aws_iam_role.ec2_ssm_role will be created
#   + resource "aws_iam_role" "ec2_ssm_role" {
#       + arn                   = (known after apply)
#       + assume_role_policy    = jsonencode(
#             {
#               + Statement = [
#                   + {
#                       + Action    = "sts:AssumeRole"
#                       + Effect    = "Allow"
#                       + Principal = {
#                           + Service = "ec2.amazonaws.com"
#                         }
#                     },
#                 ]
#               + Version   = "2012-10-17"
#             }
#         )
#       + create_date           = (known after apply)
#       + force_detach_policies = false
#       + id                    = (known after apply)
#       + managed_policy_arns   = (known after apply)
#       + max_session_duration  = 3600
#       + name                  = "EC2SSMRole"
#       + name_prefix           = (known after apply)
#       + path                  = "/"
#       + tags_all              = (known after apply)
#       + unique_id             = (known after apply)
#
#       + inline_policy (known after apply)
#     }
#
#   # aws_iam_role.sagemaker_role will be created
#   + resource "aws_iam_role" "sagemaker_role" {
#       + arn                   = (known after apply)
#       + assume_role_policy    = jsonencode(
#             {
#               + Statement = [
#                   + {
#                       + Action    = "sts:AssumeRole"
#                       + Effect    = "Allow"
#                       + Principal = {
#                           + Service = "sagemaker.amazonaws.com"
#                         }
#                     },
#                 ]
#               + Version   = "2012-10-17"
#             }
#         )
#       + create_date           = (known after apply)
#       + force_detach_policies = false
#       + id                    = (known after apply)
#       + managed_policy_arns   = (known after apply)
#       + max_session_duration  = 3600
#       + name                  = "SageMakerRole"
#       + name_prefix           = (known after apply)
#       + path                  = "/"
#       + tags_all              = (known after apply)
#       + unique_id             = (known after apply)
#
#       + inline_policy (known after apply)
#     }
#
#   # aws_iam_role_policy_attachment.ec2_ssm_access will be created
#   + resource "aws_iam_role_policy_attachment" "ec2_ssm_access" {
#       + id         = (known after apply)
#       + policy_arn = "arn:aws:iam::aws:policy/AmazonSSMManagedInstanceCore"
#       + role       = "EC2SSMRole"
#     }
#
#   # aws_iam_role_policy_attachment.sagemaker_full_access will be created
#   + resource "aws_iam_role_policy_attachment" "sagemaker_full_access" {
#       + id         = (known after apply)
#       + policy_arn = "arn:aws:iam::aws:policy/AmazonSageMakerFullAccess"
#       + role       = "SageMakerRole"
#     }
#
# Plan: 5 to add, 0 to change, 0 to destroy.
# aws_iam_role.sagemaker_role: Creating...
# aws_iam_role.ec2_ssm_role: Creating...
# aws_iam_role.sagemaker_role: Creation complete after 0s [id=SageMakerRole]
# aws_iam_role_policy_attachment.sagemaker_full_access: Creating...
# aws_iam_role.ec2_ssm_role: Creation complete after 1s [id=EC2SSMRole]
# aws_iam_instance_profile.ec2_ssm_profile: Creating...
# aws_iam_role_policy_attachment.ec2_ssm_access: Creating...
# aws_iam_role_policy_attachment.sagemaker_full_access: Creation complete after 1s [id=SageMakerRole-20250825230712552900000001]
# aws_iam_role_policy_attachment.ec2_ssm_access: Creation complete after 0s [id=EC2SSMRole-20250825230712598600000002]
# aws_iam_instance_profile.ec2_ssm_profile: Creation complete after 5s [id=EC2SSMProfile]
#
# Apply complete! Resources: 5 added, 0 changed, 0 destroyed.
#
# Outputs:
#
# vpc_id = "vpc-09d06141d745ce35f"

# %%
# %%bash
# # Verify SageMaker Role
# aws iam get-role --role-name SageMakerRole
#
# # Verify EC2 SSM Role
# aws iam get-role --role-name EC2SSMRole
#
# # Verify Instance Profile
# aws iam get-instance-profile --instance-profile-name EC2SSMProfile
# Out:
# {
#     "Role": {
#         "Path": "/",
#         "RoleName": "SageMakerRole",
#         "RoleId": "AROAY3S6GJY4TEOLB5OLW",
#         "Arn": "arn:aws:iam::609009159737:role/SageMakerRole",
#         "CreateDate": "2025-08-25T23:07:12Z",
#         "AssumeRolePolicyDocument": {
#             "Version": "2012-10-17",
#             "Statement": [
#                 {
#                     "Effect": "Allow",
#                     "Principal": {
#                         "Service": "sagemaker.amazonaws.com"
#                     },
#                     "Action": "sts:AssumeRole"
#                 }
#             ]
#         },
#         "MaxSessionDuration": 3600,
#         "RoleLastUsed": {}
#     }
# }
# {
#     "Role": {
#         "Path": "/",
#         "RoleName": "EC2SSMRole",
#         "RoleId": "AROAY3S6GJY4UXSERF2FW",
#         "Arn": "arn:aws:iam::609009159737:role/EC2SSMRole",
#         "CreateDate": "2025-08-25T23:07:12Z",
#         "AssumeRolePolicyDocument": {
#             "Version": "2012-10-17",
#             "Statement": [
#                 {
#                     "Effect": "Allow",
#                     "Principal": {
#                         "Service": "ec2.amazonaws.com"
#                     },
#                     "Action": "sts:AssumeRole"
#                 }
#             ]
#         },
#         "MaxSessionDuration": 3600,
#         "RoleLastUsed": {}
#     }
# }
# {
#     "InstanceProfile": {
#         "Path": "/",
#         "InstanceProfileName": "EC2SSMProfile",
#         "InstanceProfileId": "AIPAY3S6GJY4Z3OMT5B3L",
#         "Arn": "arn:aws:iam::609009159737:instance-profile/EC2SSMProfile",
#         "CreateDate": "2025-08-25T23:07:12Z",
#         "Roles": [
#             {
#                 "Path": "/",
#                 "RoleName": "EC2SSMRole",
#                 "RoleId": "AROAY3S6GJY4UXSERF2FW",
#                 "Arn": "arn:aws:iam::609009159737:role/EC2SSMRole",
#                 "CreateDate": "2025-08-25T23:07:12Z",
#                 "AssumeRolePolicyDocument": {
#                     "Version": "2012-10-17",
#                     "Statement": [
#                         {
#                             "Effect": "Allow",
#                             "Principal": {
#                                 "Service": "ec2.amazonaws.com"
#                             },
#                             "Action": "sts:AssumeRole"
#                         }
#                     ]
#                 }
#             }
#         ],
#         "Tags": []
#     }
# }

# %%
# %%writefile sagemaker.tf
# resource "aws_sagemaker_domain" "my_domain" {
#   domain_name = "my-domain"
#   auth_mode   = "IAM"
#   vpc_id      = aws_vpc.my_vpc.id
#   subnet_ids  = [aws_subnet.private_subnet_1.id, aws_subnet.private_subnet_2.id]
#
#   default_user_settings {
#     execution_role  = aws_iam_role.sagemaker_role.arn
#     security_groups = [aws_security_group.sagemaker_sg.id]
#   }
#   default_space_settings {
#     execution_role  = aws_iam_role.sagemaker_role.arn
#     security_groups = [aws_security_group.sagemaker_sg.id]
#   }
#   app_network_access_type = "VpcOnly"
# }
# Out:
# Overwriting sagemaker.tf

# %%
# %%writefile -a outputs.tf
#
# output "sagemaker_domain_id" {
#   value = aws_sagemaker_domain.my_domain.id
# }
# Out:
# Appending to outputs.tf

# %%
# %%bash
# terraform plan
# Out:
# data.aws_ami.amazon_linux: Reading...
# aws_eip.nat_eip: Refreshing state... [id=eipalloc-01a7c8f7772f11809]
# aws_iam_role.ec2_ssm_role: Refreshing state... [id=EC2SSMRole]
# aws_vpc.my_vpc: Refreshing state... [id=vpc-09d06141d745ce35f]
# aws_iam_role.sagemaker_role: Refreshing state... [id=SageMakerRole]
# aws_iam_instance_profile.ec2_ssm_profile: Refreshing state... [id=EC2SSMProfile]
# aws_iam_role_policy_attachment.ec2_ssm_access: Refreshing state... [id=EC2SSMRole-20250825230712598600000002]
# aws_iam_role_policy_attachment.sagemaker_full_access: Refreshing state... [id=SageMakerRole-20250825230712552900000001]
# aws_route_table.public_rt: Refreshing state... [id=rtb-0c35f0d2e95f8b3ee]
# aws_subnet.private_subnet_1: Refreshing state... [id=subnet-0a9ddef84ff975a4b]
# aws_route_table.private_rt: Refreshing state... [id=rtb-0d592d6d93b2b0981]
# aws_network_acl.my_nacl: Refreshing state... [id=acl-044a1c4ecc41bc076]
# aws_subnet.public_subnet: Refreshing state... [id=subnet-0122da2129d691098]
# aws_internet_gateway.my_igw: Refreshing state... [id=igw-06334980ce938c2a0]
# aws_security_group.sagemaker_sg: Refreshing state... [id=sg-0485562c610ce365f]
# aws_subnet.private_subnet_2: Refreshing state... [id=subnet-0e0f1ec3d6fa55ba1]
# aws_security_group.ec2_sg: Refreshing state... [id=sg-08d3bc7e3f0057d80]
# aws_route.public_internet: Refreshing state... [id=r-rtb-0c35f0d2e95f8b3ee1080289494]
# data.aws_ami.amazon_linux: Read complete after 0s [id=ami-0309908417d7ea2d0]
# aws_network_acl_rule.inbound_allow_all: Refreshing state... [id=nacl-1847467266]
# aws_network_acl_rule.outbound_allow_all: Refreshing state... [id=nacl-1970693416]
# aws_route_table_association.private_assoc_2: Refreshing state... [id=rtbassoc-0369cf17e84ad5dd2]
# aws_network_acl_association.private_2_nacl_assoc: Refreshing state... [id=aclassoc-0387ab3f5d00dc778]
# aws_nat_gateway.my_nat: Refreshing state... [id=nat-07b8255225e45e0b0]
# aws_route_table_association.public_assoc: Refreshing state... [id=rtbassoc-01f7b02613d758fff]
# aws_network_acl_association.public_nacl_assoc: Refreshing state... [id=aclassoc-033cf7be9b70f2539]
# aws_route_table_association.private_assoc_1: Refreshing state... [id=rtbassoc-09354b98ef22e6b5d]
# aws_network_acl_association.private_1_nacl_assoc: Refreshing state... [id=aclassoc-04ea4662a4bd8450a]
# aws_sagemaker_domain.my_domain: Refreshing state... [id=d-jccm2rxiyrfp]
# aws_instance.my_ec2: Refreshing state... [id=i-095fa9c0420ad953d]
# aws_route.private_nat: Refreshing state... [id=r-rtb-0d592d6d93b2b09811080289494]
# aws_sagemaker_user_profile.ai_user: Refreshing state... [id=arn:aws:sagemaker:us-east-1:609009159737:user-profile/d-jccm2rxiyrfp/ai-user]
# aws_sagemaker_space.private_space: Refreshing state... [id=arn:aws:sagemaker:us-east-1:609009159737:space/d-jccm2rxiyrfp/private-notebook]
#
# Terraform used the selected providers to generate the following execution
# plan. Resource actions are indicated with the following symbols:
#   + create
#   ~ update in-place
#
# Terraform will perform the following actions:
#
#   # aws_sagemaker_domain.my_domain will be updated in-place
#   ~ resource "aws_sagemaker_domain" "my_domain" {
#         id                                             = "d-jccm2rxiyrfp"
#         tags                                           = {}
#         # (15 unchanged attributes hidden)
#
#       + default_space_settings {
#           + execution_role  = "arn:aws:iam::609009159737:role/SageMakerRole"
#           + security_groups = [
#               + "sg-0485562c610ce365f",
#             ]
#
#           + space_storage_settings (known after apply)
#         }
#
#         # (1 unchanged block hidden)
#     }
#
#   # aws_sagemaker_space.shared_space will be created
#   + resource "aws_sagemaker_space" "shared_space" {
#       + arn                      = (known after apply)
#       + domain_id                = "d-jccm2rxiyrfp"
#       + home_efs_file_system_uid = (known after apply)
#       + id                       = (known after apply)
#       + space_name               = "shared-notebook"
#       + tags_all                 = (known after apply)
#       + url                      = (known after apply)
#
#       + ownership_settings {
#           + owner_user_profile_name = "ai-user"
#         }
#
#       + space_settings {
#           + app_type = "JupyterLab"
#
#           + jupyter_lab_app_settings {
#               + default_resource_spec {
#                   + instance_type = "ml.t3.medium"
#                 }
#             }
#
#           + space_storage_settings (known after apply)
#         }
#
#       + space_sharing_settings {
#           + sharing_type = "Shared"
#         }
#     }
#
# Plan: 1 to add, 1 to change, 0 to destroy.
#
# ─────────────────────────────────────────────────────────────────────────────
#
# Note: You didn't use the -out option to save this plan, so Terraform can't
# guarantee to take exactly these actions if you run "terraform apply" now.

# %%
# %%bash
# terraform apply -auto-approve
# Out:
# data.aws_ami.amazon_linux: Reading...
# aws_iam_role.ec2_ssm_role: Refreshing state... [id=EC2SSMRole]
# aws_iam_role.sagemaker_role: Refreshing state... [id=SageMakerRole]
# aws_eip.nat_eip: Refreshing state... [id=eipalloc-01a7c8f7772f11809]
# aws_vpc.my_vpc: Refreshing state... [id=vpc-09d06141d745ce35f]
# aws_iam_role_policy_attachment.sagemaker_full_access: Refreshing state... [id=SageMakerRole-20250825230712552900000001]
# aws_iam_role_policy_attachment.ec2_ssm_access: Refreshing state... [id=EC2SSMRole-20250825230712598600000002]
# aws_iam_instance_profile.ec2_ssm_profile: Refreshing state... [id=EC2SSMProfile]
# data.aws_ami.amazon_linux: Read complete after 0s [id=ami-0309908417d7ea2d0]
# aws_subnet.private_subnet_1: Refreshing state... [id=subnet-0a9ddef84ff975a4b]
# aws_route_table.public_rt: Refreshing state... [id=rtb-0c35f0d2e95f8b3ee]
# aws_subnet.private_subnet_2: Refreshing state... [id=subnet-0e0f1ec3d6fa55ba1]
# aws_route_table.private_rt: Refreshing state... [id=rtb-0d592d6d93b2b0981]
# aws_network_acl.my_nacl: Refreshing state... [id=acl-044a1c4ecc41bc076]
# aws_security_group.sagemaker_sg: Refreshing state... [id=sg-0485562c610ce365f]
# aws_internet_gateway.my_igw: Refreshing state... [id=igw-06334980ce938c2a0]
# aws_subnet.public_subnet: Refreshing state... [id=subnet-0122da2129d691098]
# aws_route.public_internet: Refreshing state... [id=r-rtb-0c35f0d2e95f8b3ee1080289494]
# aws_network_acl_rule.outbound_allow_all: Refreshing state... [id=nacl-1970693416]
# aws_network_acl_rule.inbound_allow_all: Refreshing state... [id=nacl-1847467266]
# aws_route_table_association.private_assoc_1: Refreshing state... [id=rtbassoc-09354b98ef22e6b5d]
# aws_network_acl_association.private_1_nacl_assoc: Refreshing state... [id=aclassoc-04ea4662a4bd8450a]
# aws_network_acl_association.private_2_nacl_assoc: Refreshing state... [id=aclassoc-0387ab3f5d00dc778]
# aws_route_table_association.public_assoc: Refreshing state... [id=rtbassoc-01f7b02613d758fff]
# aws_network_acl_association.public_nacl_assoc: Refreshing state... [id=aclassoc-033cf7be9b70f2539]
# aws_nat_gateway.my_nat: Refreshing state... [id=nat-07b8255225e45e0b0]
# aws_route_table_association.private_assoc_2: Refreshing state... [id=rtbassoc-0369cf17e84ad5dd2]
# aws_security_group.ec2_sg: Refreshing state... [id=sg-08d3bc7e3f0057d80]
# aws_sagemaker_domain.my_domain: Refreshing state... [id=d-jccm2rxiyrfp]
# aws_route.private_nat: Refreshing state... [id=r-rtb-0d592d6d93b2b09811080289494]
# aws_instance.my_ec2: Refreshing state... [id=i-095fa9c0420ad953d]
# aws_sagemaker_user_profile.ai_user: Refreshing state... [id=arn:aws:sagemaker:us-east-1:609009159737:user-profile/d-jccm2rxiyrfp/ai-user]
# aws_sagemaker_space.private_space: Refreshing state... [id=arn:aws:sagemaker:us-east-1:609009159737:space/d-jccm2rxiyrfp/private-notebook]
#
# Terraform used the selected providers to generate the following execution
# plan. Resource actions are indicated with the following symbols:
#   + create
#   ~ update in-place
#
# Terraform will perform the following actions:
#
#   # aws_sagemaker_domain.my_domain will be updated in-place
#   ~ resource "aws_sagemaker_domain" "my_domain" {
#         id                                             = "d-jccm2rxiyrfp"
#         tags                                           = {}
#         # (15 unchanged attributes hidden)
#
#       + default_space_settings {
#           + execution_role  = "arn:aws:iam::609009159737:role/SageMakerRole"
#           + security_groups = [
#               + "sg-0485562c610ce365f",
#             ]
#
#           + space_storage_settings (known after apply)
#         }
#
#         # (1 unchanged block hidden)
#     }
#
#   # aws_sagemaker_space.shared_space will be created
#   + resource "aws_sagemaker_space" "shared_space" {
#       + arn                      = (known after apply)
#       + domain_id                = "d-jccm2rxiyrfp"
#       + home_efs_file_system_uid = (known after apply)
#       + id                       = (known after apply)
#       + space_name               = "shared-notebook"
#       + tags_all                 = (known after apply)
#       + url                      = (known after apply)
#
#       + ownership_settings {
#           + owner_user_profile_name = "ai-user"
#         }
#
#       + space_settings {
#           + app_type = "JupyterLab"
#
#           + jupyter_lab_app_settings {
#               + default_resource_spec {
#                   + instance_type = "ml.t3.medium"
#                 }
#             }
#
#           + space_storage_settings (known after apply)
#         }
#
#       + space_sharing_settings {
#           + sharing_type = "Shared"
#         }
#     }
#
# Plan: 1 to add, 1 to change, 0 to destroy.
# aws_sagemaker_domain.my_domain: Modifying... [id=d-jccm2rxiyrfp]
# aws_sagemaker_domain.my_domain: Modifications complete after 2s [id=d-jccm2rxiyrfp]
# aws_sagemaker_space.shared_space: Creating...
# aws_sagemaker_space.shared_space: Still creating... 10s elapsed]
# aws_sagemaker_space.shared_space: Creation complete after 13s [id=arn:aws:sagemaker:us-east-1:609009159737:space/d-jccm2rxiyrfp/shared-notebook]
#
# Apply complete! Resources: 1 added, 1 changed, 0 destroyed.
#
# Outputs:
#
# ec2_private_ip = "10.0.1.12"
# mongodb_port = 3307
# private_space_name = "private-notebook"
# sagemaker_domain_id = "d-jccm2rxiyrfp"
# shared_space_name = "shared-notebook"
# user_profile_name = "ai-user"
# vpc_id = "vpc-09d06141d745ce35f"

# %%
# %%writefile ec2.tf
# data "aws_ami" "amazon_linux" {
#   most_recent = true
#   owners      = ["amazon"]
#
#   filter {
#     name   = "name"
#     values = ["al2023-ami-*-x86_64"]
#   }
# }
#
# resource "aws_instance" "my_ec2" {
#   ami           = data.aws_ami.amazon_linux.id
#   instance_type = "t2.micro"
#   subnet_id     = aws_subnet.private_subnet_1.id
#   vpc_security_group_ids = [aws_security_group.ec2_sg.id]
#   iam_instance_profile   = aws_iam_instance_profile.ec2_ssm_profile.name
#   associate_public_ip_address = false
#
#   user_data = base64encode(<<-EOF
#               #!/bin/bash
#               yum update -y
#               sudo tee /etc/yum.repos.d/mongodb-org-8.0.repo <<EOT
#               [mongodb-org-8.0]
#               name=MongoDB Repository
#               baseurl=https://repo.mongodb.org/yum/amazon/2023/mongodb-org/8.0/x86_64/
#               gpgcheck=1
#               enabled=1
#               gpgkey=https://pgp.mongodb.com/server-8.0.asc
#               EOT
#               sudo yum install -y mongodb-org
#               sudo sed -i "s/port: 27017/port: ${var.mongodb_port}/" /etc/mongod.conf
#               sudo sed -i "s/bindIp: 127.0.0.1/bindIp: 0.0.0.0/" /etc/mongod.conf
#               sudo systemctl daemon-reload
#               sudo systemctl start mongod
#               sudo systemctl enable mongod
#               EOF
#   )
#
#   tags = {
#     Name = "my-ec2"
#   }
# }
# Out:
# Writing ec2.tf

# %%
# %%writefile -a outputs.tf
#
# output "ec2_private_ip" {
#   value = aws_instance.my_ec2.private_ip
# }
#
# output "mongodb_port" {
#   value = var.mongodb_port
# }
# Out:
# Appending to outputs.tf

# %%
# %%bash
# terraform plan
# Out:
# aws_eip.nat_eip: Refreshing state... [id=eipalloc-01a7c8f7772f11809]
# aws_iam_role.ec2_ssm_role: Refreshing state... [id=EC2SSMRole]
# aws_vpc.my_vpc: Refreshing state... [id=vpc-09d06141d745ce35f]
# aws_iam_role.sagemaker_role: Refreshing state... [id=SageMakerRole]
# data.aws_ami.amazon_linux: Reading...
# aws_iam_role_policy_attachment.ec2_ssm_access: Refreshing state... [id=EC2SSMRole-20250825230712598600000002]
# aws_iam_instance_profile.ec2_ssm_profile: Refreshing state... [id=EC2SSMProfile]
# aws_iam_role_policy_attachment.sagemaker_full_access: Refreshing state... [id=SageMakerRole-20250825230712552900000001]
# aws_subnet.private_subnet_1: Refreshing state... [id=subnet-0a9ddef84ff975a4b]
# aws_security_group.sagemaker_sg: Refreshing state... [id=sg-0485562c610ce365f]
# aws_internet_gateway.my_igw: Refreshing state... [id=igw-06334980ce938c2a0]
# data.aws_ami.amazon_linux: Read complete after 1s [id=ami-0309908417d7ea2d0]
# aws_route_table.public_rt: Refreshing state... [id=rtb-0c35f0d2e95f8b3ee]
# aws_network_acl.my_nacl: Refreshing state... [id=acl-044a1c4ecc41bc076]
# aws_subnet.public_subnet: Refreshing state... [id=subnet-0122da2129d691098]
# aws_subnet.private_subnet_2: Refreshing state... [id=subnet-0e0f1ec3d6fa55ba1]
# aws_route_table.private_rt: Refreshing state... [id=rtb-0d592d6d93b2b0981]
# aws_route_table_association.private_assoc_1: Refreshing state... [id=rtbassoc-09354b98ef22e6b5d]
# aws_security_group.ec2_sg: Refreshing state... [id=sg-08d3bc7e3f0057d80]
# aws_route.public_internet: Refreshing state... [id=r-rtb-0c35f0d2e95f8b3ee1080289494]
# aws_network_acl_association.private_1_nacl_assoc: Refreshing state... [id=aclassoc-04ea4662a4bd8450a]
# aws_network_acl_rule.inbound_allow_all: Refreshing state... [id=nacl-1847467266]
# aws_network_acl_rule.outbound_allow_all: Refreshing state... [id=nacl-1970693416]
# aws_network_acl_association.private_2_nacl_assoc: Refreshing state... [id=aclassoc-0387ab3f5d00dc778]
# aws_route_table_association.private_assoc_2: Refreshing state... [id=rtbassoc-0369cf17e84ad5dd2]
# aws_sagemaker_domain.my_domain: Refreshing state... [id=d-jccm2rxiyrfp]
# aws_network_acl_association.public_nacl_assoc: Refreshing state... [id=aclassoc-033cf7be9b70f2539]
# aws_nat_gateway.my_nat: Refreshing state... [id=nat-07b8255225e45e0b0]
# aws_route_table_association.public_assoc: Refreshing state... [id=rtbassoc-01f7b02613d758fff]
# aws_route.private_nat: Refreshing state... [id=r-rtb-0d592d6d93b2b09811080289494]
#
# Terraform used the selected providers to generate the following execution
# plan. Resource actions are indicated with the following symbols:
#   + create
#
# Terraform will perform the following actions:
#
#   # aws_instance.my_ec2 will be created
#   + resource "aws_instance" "my_ec2" {
#       + ami                                  = "ami-0309908417d7ea2d0"
#       + arn                                  = (known after apply)
#       + associate_public_ip_address          = false
#       + availability_zone                    = (known after apply)
#       + cpu_core_count                       = (known after apply)
#       + cpu_threads_per_core                 = (known after apply)
#       + disable_api_stop                     = (known after apply)
#       + disable_api_termination              = (known after apply)
#       + ebs_optimized                        = (known after apply)
#       + enable_primary_ipv6                  = (known after apply)
#       + get_password_data                    = false
#       + host_id                              = (known after apply)
#       + host_resource_group_arn              = (known after apply)
#       + iam_instance_profile                 = "EC2SSMProfile"
#       + id                                   = (known after apply)
#       + instance_initiated_shutdown_behavior = (known after apply)
#       + instance_lifecycle                   = (known after apply)
#       + instance_state                       = (known after apply)
#       + instance_type                        = "t2.micro"
#       + ipv6_address_count                   = (known after apply)
#       + ipv6_addresses                       = (known after apply)
#       + key_name                             = (known after apply)
#       + monitoring                           = (known after apply)
#       + outpost_arn                          = (known after apply)
#       + password_data                        = (known after apply)
#       + placement_group                      = (known after apply)
#       + placement_partition_number           = (known after apply)
#       + primary_network_interface_id         = (known after apply)
#       + private_dns                          = (known after apply)
#       + private_ip                           = (known after apply)
#       + public_dns                           = (known after apply)
#       + public_ip                            = (known after apply)
#       + secondary_private_ips                = (known after apply)
#       + security_groups                      = (known after apply)
#       + source_dest_check                    = true
#       + spot_instance_request_id             = (known after apply)
#       + subnet_id                            = "subnet-0a9ddef84ff975a4b"
#       + tags                                 = {
#           + "Name" = "my-ec2"
#         }
#       + tags_all                             = {
#           + "Name" = "my-ec2"
#         }
#       + tenancy                              = (known after apply)
#       + user_data                            = "4eccd0c8fd4ebe33b7e3f557709750a2c7ff18e9"
#       + user_data_base64                     = (known after apply)
#       + user_data_replace_on_change          = false
#       + vpc_security_group_ids               = [
#           + "sg-08d3bc7e3f0057d80",
#         ]
#
#       + capacity_reservation_specification (known after apply)
#
#       + cpu_options (known after apply)
#
#       + ebs_block_device (known after apply)
#
#       + enclave_options (known after apply)
#
#       + ephemeral_block_device (known after apply)
#
#       + instance_market_options (known after apply)
#
#       + maintenance_options (known after apply)
#
#       + metadata_options (known after apply)
#
#       + network_interface (known after apply)
#
#       + private_dns_name_options (known after apply)
#
#       + root_block_device (known after apply)
#     }
#
# Plan: 1 to add, 0 to change, 0 to destroy.
#
# Changes to Outputs:
#   + ec2_private_ip      = (known after apply)
#   + mongodb_port        = 3307
#
# ─────────────────────────────────────────────────────────────────────────────
#
# Note: You didn't use the -out option to save this plan, so Terraform can't
# guarantee to take exactly these actions if you run "terraform apply" now.

# %%
# %%bash
# terraform apply -auto-approve
# Out:
# data.aws_ami.amazon_linux: Reading...
# aws_iam_role.sagemaker_role: Refreshing state... [id=SageMakerRole]
# aws_eip.nat_eip: Refreshing state... [id=eipalloc-01a7c8f7772f11809]
# aws_vpc.my_vpc: Refreshing state... [id=vpc-09d06141d745ce35f]
# aws_iam_role.ec2_ssm_role: Refreshing state... [id=EC2SSMRole]
# aws_iam_role_policy_attachment.ec2_ssm_access: Refreshing state... [id=EC2SSMRole-20250825230712598600000002]
# aws_iam_instance_profile.ec2_ssm_profile: Refreshing state... [id=EC2SSMProfile]
# aws_iam_role_policy_attachment.sagemaker_full_access: Refreshing state... [id=SageMakerRole-20250825230712552900000001]
# data.aws_ami.amazon_linux: Read complete after 0s [id=ami-0309908417d7ea2d0]
# aws_route_table.private_rt: Refreshing state... [id=rtb-0d592d6d93b2b0981]
# aws_route_table.public_rt: Refreshing state... [id=rtb-0c35f0d2e95f8b3ee]
# aws_subnet.public_subnet: Refreshing state... [id=subnet-0122da2129d691098]
# aws_internet_gateway.my_igw: Refreshing state... [id=igw-06334980ce938c2a0]
# aws_network_acl.my_nacl: Refreshing state... [id=acl-044a1c4ecc41bc076]
# aws_security_group.sagemaker_sg: Refreshing state... [id=sg-0485562c610ce365f]
# aws_subnet.private_subnet_2: Refreshing state... [id=subnet-0e0f1ec3d6fa55ba1]
# aws_subnet.private_subnet_1: Refreshing state... [id=subnet-0a9ddef84ff975a4b]
# aws_security_group.ec2_sg: Refreshing state... [id=sg-08d3bc7e3f0057d80]
# aws_network_acl_rule.inbound_allow_all: Refreshing state... [id=nacl-1847467266]
# aws_network_acl_rule.outbound_allow_all: Refreshing state... [id=nacl-1970693416]
# aws_route.public_internet: Refreshing state... [id=r-rtb-0c35f0d2e95f8b3ee1080289494]
# aws_network_acl_association.private_1_nacl_assoc: Refreshing state... [id=aclassoc-04ea4662a4bd8450a]
# aws_network_acl_association.private_2_nacl_assoc: Refreshing state... [id=aclassoc-0387ab3f5d00dc778]
# aws_sagemaker_domain.my_domain: Refreshing state... [id=d-jccm2rxiyrfp]
# aws_network_acl_association.public_nacl_assoc: Refreshing state... [id=aclassoc-033cf7be9b70f2539]
# aws_route_table_association.public_assoc: Refreshing state... [id=rtbassoc-01f7b02613d758fff]
# aws_nat_gateway.my_nat: Refreshing state... [id=nat-07b8255225e45e0b0]
# aws_route_table_association.private_assoc_1: Refreshing state... [id=rtbassoc-09354b98ef22e6b5d]
# aws_route_table_association.private_assoc_2: Refreshing state... [id=rtbassoc-0369cf17e84ad5dd2]
# aws_route.private_nat: Refreshing state... [id=r-rtb-0d592d6d93b2b09811080289494]
#
# Terraform used the selected providers to generate the following execution
# plan. Resource actions are indicated with the following symbols:
#   + create
#
# Terraform will perform the following actions:
#
#   # aws_instance.my_ec2 will be created
#   + resource "aws_instance" "my_ec2" {
#       + ami                                  = "ami-0309908417d7ea2d0"
#       + arn                                  = (known after apply)
#       + associate_public_ip_address          = false
#       + availability_zone                    = (known after apply)
#       + cpu_core_count                       = (known after apply)
#       + cpu_threads_per_core                 = (known after apply)
#       + disable_api_stop                     = (known after apply)
#       + disable_api_termination              = (known after apply)
#       + ebs_optimized                        = (known after apply)
#       + enable_primary_ipv6                  = (known after apply)
#       + get_password_data                    = false
#       + host_id                              = (known after apply)
#       + host_resource_group_arn              = (known after apply)
#       + iam_instance_profile                 = "EC2SSMProfile"
#       + id                                   = (known after apply)
#       + instance_initiated_shutdown_behavior = (known after apply)
#       + instance_lifecycle                   = (known after apply)
#       + instance_state                       = (known after apply)
#       + instance_type                        = "t2.micro"
#       + ipv6_address_count                   = (known after apply)
#       + ipv6_addresses                       = (known after apply)
#       + key_name                             = (known after apply)
#       + monitoring                           = (known after apply)
#       + outpost_arn                          = (known after apply)
#       + password_data                        = (known after apply)
#       + placement_group                      = (known after apply)
#       + placement_partition_number           = (known after apply)
#       + primary_network_interface_id         = (known after apply)
#       + private_dns                          = (known after apply)
#       + private_ip                           = (known after apply)
#       + public_dns                           = (known after apply)
#       + public_ip                            = (known after apply)
#       + secondary_private_ips                = (known after apply)
#       + security_groups                      = (known after apply)
#       + source_dest_check                    = true
#       + spot_instance_request_id             = (known after apply)
#       + subnet_id                            = "subnet-0a9ddef84ff975a4b"
#       + tags                                 = {
#           + "Name" = "my-ec2"
#         }
#       + tags_all                             = {
#           + "Name" = "my-ec2"
#         }
#       + tenancy                              = (known after apply)
#       + user_data                            = "4eccd0c8fd4ebe33b7e3f557709750a2c7ff18e9"
#       + user_data_base64                     = (known after apply)
#       + user_data_replace_on_change          = false
#       + vpc_security_group_ids               = [
#           + "sg-08d3bc7e3f0057d80",
#         ]
#
#       + capacity_reservation_specification (known after apply)
#
#       + cpu_options (known after apply)
#
#       + ebs_block_device (known after apply)
#
#       + enclave_options (known after apply)
#
#       + ephemeral_block_device (known after apply)
#
#       + instance_market_options (known after apply)
#
#       + maintenance_options (known after apply)
#
#       + metadata_options (known after apply)
#
#       + network_interface (known after apply)
#
#       + private_dns_name_options (known after apply)
#
#       + root_block_device (known after apply)
#     }
#
# Plan: 1 to add, 0 to change, 0 to destroy.
#
# Changes to Outputs:
#   + ec2_private_ip      = (known after apply)
#   + mongodb_port        = 3307
# aws_instance.my_ec2: Creating...
# aws_instance.my_ec2: Still creating... 10s elapsed]
# aws_instance.my_ec2: Creation complete after 13s [id=i-095fa9c0420ad953d]
#
# Apply complete! Resources: 1 added, 0 changed, 0 destroyed.
#
# Outputs:
#
# ec2_private_ip = "10.0.1.12"
# mongodb_port = 3307
# sagemaker_domain_id = "d-jccm2rxiyrfp"
# vpc_id = "vpc-09d06141d745ce35f"

# %%
# %%bash
# # Get Instance ID (filter by tag)
# INSTANCE_ID=$(aws ec2 describe-instances --filters "Name=tag:Name,Values=my-ec2" "Name=instance-state-name,Values=running" --query "Reservations[0].Instances[0].InstanceId" --output text)
#
# # Describe Instance
# aws ec2 describe-instances --instance-ids $INSTANCE_ID
#
# # To check MongoDB (optional: use SSM to run command)
# # First, ensure instance is registered in SSM: aws ssm describe-instance-information
# # Then: aws ssm send-command --instance-ids $INSTANCE_ID --document-name "AWS-RunShellScript" --parameters '{"commands":["netstat -tuln | grep 3307"]}'
# # Wait and get output: aws ssm list-command-invocations --command-id <command-id> --details
# Out:
# {
#     "Reservations": [
#         {
#             "ReservationId": "r-04f7fdecea1f65852",
#             "OwnerId": "609009159737",
#             "Groups": [],
#             "Instances": [
#                 {
#                     "Architecture": "x86_64",
#                     "BlockDeviceMappings": [
#                         {
#                             "DeviceName": "/dev/xvda",
#                             "Ebs": {
#                                 "AttachTime": "2025-08-25T23:15:49.000Z",
#                                 "DeleteOnTermination": true,
#                                 "Status": "attached",
#                                 "VolumeId": "vol-0297271ff40c2fb5c"
#                             }
#                         }
#                     ],
#                     "ClientToken": "terraform-20250825231547313000000001",
#                     "EbsOptimized": false,
#                     "EnaSupport": true,
#                     "Hypervisor": "xen",
#                     "IamInstanceProfile": {
#                         "Arn": "arn:aws:iam::609009159737:instance-profile/EC2SSMProfile",
#                         "Id": "AIPAY3S6GJY4Z3OMT5B3L"
#                     },
#                     "NetworkInterfaces": [
#                         {
#                             "Attachment": {
#                                 "AttachTime": "2025-08-25T23:15:48.000Z",
#                                 "AttachmentId": "eni-attach-0fd3bc150e6833f89",
#                                 "DeleteOnTermination": true,
#                                 "DeviceIndex": 0,
#                                 "Status": "attached",
#                                 "NetworkCardIndex": 0
#                             },
#                             "Description": "",
#                             "Groups": [
#                                 {
#                                     "GroupId": "sg-08d3bc7e3f0057d80",
#                                     "GroupName": "ec2-sg"
#                                 }
#                             ],
#                             "Ipv6Addresses": [],
#                             "MacAddress": "0a:ff:c0:1a:0b:89",
#                             "NetworkInterfaceId": "eni-000a62a4b3ea7fd05",
#                             "OwnerId": "609009159737",
#                             "PrivateIpAddress": "10.0.1.12",
#                             "PrivateIpAddresses": [
#                                 {
#                                     "Primary": true,
#                                     "PrivateIpAddress": "10.0.1.12"
#                                 }
#                             ],
#                             "SourceDestCheck": true,
#                             "Status": "in-use",
#                             "SubnetId": "subnet-0a9ddef84ff975a4b",
#                             "VpcId": "vpc-09d06141d745ce35f",
#                             "InterfaceType": "interface",
#                             "Operator": {
#                                 "Managed": false
#                             }
#                         }
#                     ],
#                     "RootDeviceName": "/dev/xvda",
#                     "RootDeviceType": "ebs",
#                     "SecurityGroups": [
#                         {
#                             "GroupId": "sg-08d3bc7e3f0057d80",
#                             "GroupName": "ec2-sg"
#                         }
#                     ],
#                     "SourceDestCheck": true,
#                     "Tags": [
#                         {
#                             "Key": "Name",
#                             "Value": "my-ec2"
#                         }
#                     ],
#                     "VirtualizationType": "hvm",
#                     "CpuOptions": {
#                         "CoreCount": 1,
#                         "ThreadsPerCore": 1
#                     },
#                     "CapacityReservationSpecification": {
#                         "CapacityReservationPreference": "open"
#                     },
#                     "HibernationOptions": {
#                         "Configured": false
#                     },
#                     "MetadataOptions": {
#                         "State": "applied",
#                         "HttpTokens": "required",
#                         "HttpPutResponseHopLimit": 2,
#                         "HttpEndpoint": "enabled",
#                         "HttpProtocolIpv6": "disabled",
#                         "InstanceMetadataTags": "disabled"
#                     },
#                     "EnclaveOptions": {
#                         "Enabled": false
#                     },
#                     "BootMode": "uefi-preferred",
#                     "PlatformDetails": "Linux/UNIX",
#                     "UsageOperation": "RunInstances",
#                     "UsageOperationUpdateTime": "2025-08-25T23:15:48.000Z",
#                     "PrivateDnsNameOptions": {
#                         "HostnameType": "ip-name",
#                         "EnableResourceNameDnsARecord": false,
#                         "EnableResourceNameDnsAAAARecord": false
#                     },
#                     "MaintenanceOptions": {
#                         "AutoRecovery": "default",
#                         "RebootMigration": "default"
#                     },
#                     "CurrentInstanceBootMode": "legacy-bios",
#                     "NetworkPerformanceOptions": {
#                         "BandwidthWeighting": "default"
#                     },
#                     "Operator": {
#                         "Managed": false
#                     },
#                     "InstanceId": "i-095fa9c0420ad953d",
#                     "ImageId": "ami-0309908417d7ea2d0",
#                     "State": {
#                         "Code": 16,
#                         "Name": "running"
#                     },
#                     "PrivateDnsName": "ip-10-0-1-12.ec2.internal",
#                     "PublicDnsName": "",
#                     "StateTransitionReason": "",
#                     "AmiLaunchIndex": 0,
#                     "ProductCodes": [],
#                     "InstanceType": "t2.micro",
#                     "LaunchTime": "2025-08-25T23:15:48.000Z",
#                     "Placement": {
#                         "GroupName": "",
#                         "Tenancy": "default",
#                         "AvailabilityZone": "us-east-1a"
#                     },
#                     "Monitoring": {
#                         "State": "disabled"
#                     },
#                     "SubnetId": "subnet-0a9ddef84ff975a4b",
#                     "VpcId": "vpc-09d06141d745ce35f",
#                     "PrivateIpAddress": "10.0.1.12"
#                 }
#             ]
#         }
#     ]
# }

# %%
# %%bash
# terraform output
# Out:
# ec2_private_ip = "10.0.1.12"
# mongodb_port = 3307
# sagemaker_domain_id = "d-jccm2rxiyrfp"
# vpc_id = "vpc-09d06141d745ce35f"

# %%
# %%writefile sagemaker_user.tf
# resource "aws_sagemaker_user_profile" "ai_user" {
#   domain_id         = aws_sagemaker_domain.my_domain.id
#   user_profile_name = "ai-user"
#   user_settings {
#     execution_role = aws_iam_role.sagemaker_role.arn
#     security_groups = [aws_security_group.sagemaker_sg.id]
#   }
# }
# Out:
# Writing sagemaker_user.tf

# %%
# %%writefile -a outputs.tf
#
# output "user_profile_name" {
#   value = aws_sagemaker_user_profile.ai_user.user_profile_name
# }
# Out:
# Appending to outputs.tf

# %%
# %%bash
# terraform plan
# Out:
# data.aws_ami.amazon_linux: Reading...
# aws_eip.nat_eip: Refreshing state... [id=eipalloc-01a7c8f7772f11809]
# aws_iam_role.sagemaker_role: Refreshing state... [id=SageMakerRole]
# aws_vpc.my_vpc: Refreshing state... [id=vpc-09d06141d745ce35f]
# aws_iam_role.ec2_ssm_role: Refreshing state... [id=EC2SSMRole]
# aws_iam_role_policy_attachment.ec2_ssm_access: Refreshing state... [id=EC2SSMRole-20250825230712598600000002]
# aws_iam_instance_profile.ec2_ssm_profile: Refreshing state... [id=EC2SSMProfile]
# aws_iam_role_policy_attachment.sagemaker_full_access: Refreshing state... [id=SageMakerRole-20250825230712552900000001]
# data.aws_ami.amazon_linux: Read complete after 1s [id=ami-0309908417d7ea2d0]
# aws_route_table.public_rt: Refreshing state... [id=rtb-0c35f0d2e95f8b3ee]
# aws_network_acl.my_nacl: Refreshing state... [id=acl-044a1c4ecc41bc076]
# aws_subnet.private_subnet_2: Refreshing state... [id=subnet-0e0f1ec3d6fa55ba1]
# aws_subnet.public_subnet: Refreshing state... [id=subnet-0122da2129d691098]
# aws_internet_gateway.my_igw: Refreshing state... [id=igw-06334980ce938c2a0]
# aws_subnet.private_subnet_1: Refreshing state... [id=subnet-0a9ddef84ff975a4b]
# aws_route_table.private_rt: Refreshing state... [id=rtb-0d592d6d93b2b0981]
# aws_security_group.sagemaker_sg: Refreshing state... [id=sg-0485562c610ce365f]
# aws_network_acl_rule.inbound_allow_all: Refreshing state... [id=nacl-1847467266]
# aws_network_acl_rule.outbound_allow_all: Refreshing state... [id=nacl-1970693416]
# aws_route.public_internet: Refreshing state... [id=r-rtb-0c35f0d2e95f8b3ee1080289494]
# aws_security_group.ec2_sg: Refreshing state... [id=sg-08d3bc7e3f0057d80]
# aws_route_table_association.private_assoc_1: Refreshing state... [id=rtbassoc-09354b98ef22e6b5d]
# aws_network_acl_association.private_1_nacl_assoc: Refreshing state... [id=aclassoc-04ea4662a4bd8450a]
# aws_network_acl_association.public_nacl_assoc: Refreshing state... [id=aclassoc-033cf7be9b70f2539]
# aws_nat_gateway.my_nat: Refreshing state... [id=nat-07b8255225e45e0b0]
# aws_route_table_association.public_assoc: Refreshing state... [id=rtbassoc-01f7b02613d758fff]
# aws_sagemaker_domain.my_domain: Refreshing state... [id=d-jccm2rxiyrfp]
# aws_network_acl_association.private_2_nacl_assoc: Refreshing state... [id=aclassoc-0387ab3f5d00dc778]
# aws_route_table_association.private_assoc_2: Refreshing state... [id=rtbassoc-0369cf17e84ad5dd2]
# aws_instance.my_ec2: Refreshing state... [id=i-095fa9c0420ad953d]
# aws_route.private_nat: Refreshing state... [id=r-rtb-0d592d6d93b2b09811080289494]
#
# Terraform used the selected providers to generate the following execution
# plan. Resource actions are indicated with the following symbols:
#   + create
#
# Terraform will perform the following actions:
#
#   # aws_sagemaker_user_profile.ai_user will be created
#   + resource "aws_sagemaker_user_profile" "ai_user" {
#       + arn                      = (known after apply)
#       + domain_id                = "d-jccm2rxiyrfp"
#       + home_efs_file_system_uid = (known after apply)
#       + id                       = (known after apply)
#       + tags_all                 = (known after apply)
#       + user_profile_name        = "ai-user"
#
#       + user_settings {
#           + auto_mount_home_efs = (known after apply)
#           + execution_role      = "arn:aws:iam::609009159737:role/SageMakerRole"
#           + security_groups     = [
#               + "sg-0485562c610ce365f",
#             ]
#           + studio_web_portal   = (known after apply)
#
#           + space_storage_settings (known after apply)
#         }
#     }
#
# Plan: 1 to add, 0 to change, 0 to destroy.
#
# Changes to Outputs:
#   + user_profile_name   = "ai-user"
#
# ─────────────────────────────────────────────────────────────────────────────
#
# Note: You didn't use the -out option to save this plan, so Terraform can't
# guarantee to take exactly these actions if you run "terraform apply" now.

# %%
# %%bash
# terraform apply -auto-approve
# Out:
# data.aws_ami.amazon_linux: Reading...
# aws_iam_role.sagemaker_role: Refreshing state... [id=SageMakerRole]
# aws_vpc.my_vpc: Refreshing state... [id=vpc-09d06141d745ce35f]
# aws_eip.nat_eip: Refreshing state... [id=eipalloc-01a7c8f7772f11809]
# aws_iam_role.ec2_ssm_role: Refreshing state... [id=EC2SSMRole]
# aws_iam_role_policy_attachment.sagemaker_full_access: Refreshing state... [id=SageMakerRole-20250825230712552900000001]
# aws_iam_role_policy_attachment.ec2_ssm_access: Refreshing state... [id=EC2SSMRole-20250825230712598600000002]
# aws_iam_instance_profile.ec2_ssm_profile: Refreshing state... [id=EC2SSMProfile]
# aws_subnet.private_subnet_1: Refreshing state... [id=subnet-0a9ddef84ff975a4b]
# aws_subnet.private_subnet_2: Refreshing state... [id=subnet-0e0f1ec3d6fa55ba1]
# aws_internet_gateway.my_igw: Refreshing state... [id=igw-06334980ce938c2a0]
# aws_network_acl.my_nacl: Refreshing state... [id=acl-044a1c4ecc41bc076]
# aws_route_table.public_rt: Refreshing state... [id=rtb-0c35f0d2e95f8b3ee]
# aws_subnet.public_subnet: Refreshing state... [id=subnet-0122da2129d691098]
# aws_security_group.sagemaker_sg: Refreshing state... [id=sg-0485562c610ce365f]
# aws_route_table.private_rt: Refreshing state... [id=rtb-0d592d6d93b2b0981]
# data.aws_ami.amazon_linux: Read complete after 0s [id=ami-0309908417d7ea2d0]
# aws_network_acl_rule.inbound_allow_all: Refreshing state... [id=nacl-1847467266]
# aws_network_acl_rule.outbound_allow_all: Refreshing state... [id=nacl-1970693416]
# aws_network_acl_association.private_2_nacl_assoc: Refreshing state... [id=aclassoc-0387ab3f5d00dc778]
# aws_route_table_association.private_assoc_2: Refreshing state... [id=rtbassoc-0369cf17e84ad5dd2]
# aws_security_group.ec2_sg: Refreshing state... [id=sg-08d3bc7e3f0057d80]
# aws_route.public_internet: Refreshing state... [id=r-rtb-0c35f0d2e95f8b3ee1080289494]
# aws_network_acl_association.public_nacl_assoc: Refreshing state... [id=aclassoc-033cf7be9b70f2539]
# aws_route_table_association.public_assoc: Refreshing state... [id=rtbassoc-01f7b02613d758fff]
# aws_nat_gateway.my_nat: Refreshing state... [id=nat-07b8255225e45e0b0]
# aws_network_acl_association.private_1_nacl_assoc: Refreshing state... [id=aclassoc-04ea4662a4bd8450a]
# aws_sagemaker_domain.my_domain: Refreshing state... [id=d-jccm2rxiyrfp]
# aws_route_table_association.private_assoc_1: Refreshing state... [id=rtbassoc-09354b98ef22e6b5d]
# aws_route.private_nat: Refreshing state... [id=r-rtb-0d592d6d93b2b09811080289494]
# aws_instance.my_ec2: Refreshing state... [id=i-095fa9c0420ad953d]
#
# Terraform used the selected providers to generate the following execution
# plan. Resource actions are indicated with the following symbols:
#   + create
#
# Terraform will perform the following actions:
#
#   # aws_sagemaker_user_profile.ai_user will be created
#   + resource "aws_sagemaker_user_profile" "ai_user" {
#       + arn                      = (known after apply)
#       + domain_id                = "d-jccm2rxiyrfp"
#       + home_efs_file_system_uid = (known after apply)
#       + id                       = (known after apply)
#       + tags_all                 = (known after apply)
#       + user_profile_name        = "ai-user"
#
#       + user_settings {
#           + auto_mount_home_efs = (known after apply)
#           + execution_role      = "arn:aws:iam::609009159737:role/SageMakerRole"
#           + security_groups     = [
#               + "sg-0485562c610ce365f",
#             ]
#           + studio_web_portal   = (known after apply)
#
#           + space_storage_settings (known after apply)
#         }
#     }
#
# Plan: 1 to add, 0 to change, 0 to destroy.
#
# Changes to Outputs:
#   + user_profile_name   = "ai-user"
# aws_sagemaker_user_profile.ai_user: Creating...
# aws_sagemaker_user_profile.ai_user: Creation complete after 7s [id=arn:aws:sagemaker:us-east-1:609009159737:user-profile/d-jccm2rxiyrfp/ai-user]
#
# Apply complete! Resources: 1 added, 0 changed, 0 destroyed.
#
# Outputs:
#
# ec2_private_ip = "10.0.1.12"
# mongodb_port = 3307
# sagemaker_domain_id = "d-jccm2rxiyrfp"
# user_profile_name = "ai-user"
# vpc_id = "vpc-09d06141d745ce35f"

# %%
# %%writefile sagemaker_spaces.tf
# # Private Space
# resource "aws_sagemaker_space" "private_space" {
#   domain_id  = aws_sagemaker_domain.my_domain.id
#   space_name = "private-notebook"
#
#   ownership_settings {
#     owner_user_profile_name = aws_sagemaker_user_profile.ai_user.user_profile_name
#   }
#
#   space_settings {
#     app_type = "JupyterLab"
#
#     jupyter_lab_app_settings {
#       default_resource_spec {
#         instance_type = "ml.t3.medium"
#       }
#     }
#   }
#
#   space_sharing_settings {
#     sharing_type = "Private"
#   }
# }
#
# # Shared Space
# resource "aws_sagemaker_space" "shared_space" {
#   domain_id  = aws_sagemaker_domain.my_domain.id
#   space_name = "shared-notebook"
#
#   ownership_settings {
#     owner_user_profile_name = aws_sagemaker_user_profile.ai_user.user_profile_name
#   }
#
#   space_settings {
#     app_type = "JupyterLab"
#
#     jupyter_lab_app_settings {
#       default_resource_spec {
#         instance_type = "ml.t3.medium"
#       }
#     }
#   }
#
#   space_sharing_settings {
#     sharing_type = "Shared"
#   }
# }
# Out:
# Overwriting sagemaker_spaces.tf

# %%
# %%writefile -a outputs.tf
#
# output "private_space_name" {
#   value = aws_sagemaker_space.private_space.space_name
# }
#
# output "shared_space_name" {
#   value = aws_sagemaker_space.shared_space.space_name
# }
# Out:
# Appending to outputs.tf

# %%
# %%bash
# terraform plan
# Out:
# aws_eip.nat_eip: Refreshing state... [id=eipalloc-01a7c8f7772f11809]
# aws_vpc.my_vpc: Refreshing state... [id=vpc-09d06141d745ce35f]
# data.aws_ami.amazon_linux: Reading...
# aws_iam_role.sagemaker_role: Refreshing state... [id=SageMakerRole]
# aws_iam_role.ec2_ssm_role: Refreshing state... [id=EC2SSMRole]
# aws_iam_role_policy_attachment.ec2_ssm_access: Refreshing state... [id=EC2SSMRole-20250825230712598600000002]
# aws_iam_instance_profile.ec2_ssm_profile: Refreshing state... [id=EC2SSMProfile]
# aws_iam_role_policy_attachment.sagemaker_full_access: Refreshing state... [id=SageMakerRole-20250825230712552900000001]
# aws_subnet.private_subnet_1: Refreshing state... [id=subnet-0a9ddef84ff975a4b]
# aws_subnet.public_subnet: Refreshing state... [id=subnet-0122da2129d691098]
# aws_route_table.public_rt: Refreshing state... [id=rtb-0c35f0d2e95f8b3ee]
# aws_security_group.sagemaker_sg: Refreshing state... [id=sg-0485562c610ce365f]
# aws_internet_gateway.my_igw: Refreshing state... [id=igw-06334980ce938c2a0]
# aws_network_acl.my_nacl: Refreshing state... [id=acl-044a1c4ecc41bc076]
# aws_route_table.private_rt: Refreshing state... [id=rtb-0d592d6d93b2b0981]
# aws_subnet.private_subnet_2: Refreshing state... [id=subnet-0e0f1ec3d6fa55ba1]
# data.aws_ami.amazon_linux: Read complete after 0s [id=ami-0309908417d7ea2d0]
# aws_nat_gateway.my_nat: Refreshing state... [id=nat-07b8255225e45e0b0]
# aws_network_acl_rule.inbound_allow_all: Refreshing state... [id=nacl-1847467266]
# aws_network_acl_association.public_nacl_assoc: Refreshing state... [id=aclassoc-033cf7be9b70f2539]
# aws_network_acl_association.private_2_nacl_assoc: Refreshing state... [id=aclassoc-0387ab3f5d00dc778]
# aws_network_acl_rule.outbound_allow_all: Refreshing state... [id=nacl-1970693416]
# aws_route_table_association.public_assoc: Refreshing state... [id=rtbassoc-01f7b02613d758fff]
# aws_route.public_internet: Refreshing state... [id=r-rtb-0c35f0d2e95f8b3ee1080289494]
# aws_security_group.ec2_sg: Refreshing state... [id=sg-08d3bc7e3f0057d80]
# aws_network_acl_association.private_1_nacl_assoc: Refreshing state... [id=aclassoc-04ea4662a4bd8450a]
# aws_route_table_association.private_assoc_2: Refreshing state... [id=rtbassoc-0369cf17e84ad5dd2]
# aws_route_table_association.private_assoc_1: Refreshing state... [id=rtbassoc-09354b98ef22e6b5d]
# aws_route.private_nat: Refreshing state... [id=r-rtb-0d592d6d93b2b09811080289494]
# aws_sagemaker_domain.my_domain: Refreshing state... [id=d-jccm2rxiyrfp]
# aws_instance.my_ec2: Refreshing state... [id=i-095fa9c0420ad953d]
# aws_sagemaker_user_profile.ai_user: Refreshing state... [id=arn:aws:sagemaker:us-east-1:609009159737:user-profile/d-jccm2rxiyrfp/ai-user]
# aws_sagemaker_space.shared_space: Refreshing state... [id=arn:aws:sagemaker:us-east-1:609009159737:space/d-jccm2rxiyrfp/shared-notebook]
# aws_sagemaker_space.private_space: Refreshing state... [id=arn:aws:sagemaker:us-east-1:609009159737:space/d-jccm2rxiyrfp/private-notebook]
#
# No changes. Your infrastructure matches the configuration.
#
# Terraform has compared your real infrastructure against your configuration
# and found no differences, so no changes are needed.

# %%
# %%bash
# terraform apply -auto-approve
# Out:
# data.aws_ami.amazon_linux: Reading...
# aws_eip.nat_eip: Refreshing state... [id=eipalloc-01a7c8f7772f11809]
# aws_iam_role.sagemaker_role: Refreshing state... [id=SageMakerRole]
# aws_iam_role.ec2_ssm_role: Refreshing state... [id=EC2SSMRole]
# aws_vpc.my_vpc: Refreshing state... [id=vpc-09d06141d745ce35f]
# aws_iam_role_policy_attachment.sagemaker_full_access: Refreshing state... [id=SageMakerRole-20250825230712552900000001]
# aws_iam_role_policy_attachment.ec2_ssm_access: Refreshing state... [id=EC2SSMRole-20250825230712598600000002]
# aws_iam_instance_profile.ec2_ssm_profile: Refreshing state... [id=EC2SSMProfile]
# data.aws_ami.amazon_linux: Read complete after 0s [id=ami-0309908417d7ea2d0]
# aws_subnet.private_subnet_2: Refreshing state... [id=subnet-0e0f1ec3d6fa55ba1]
# aws_route_table.public_rt: Refreshing state... [id=rtb-0c35f0d2e95f8b3ee]
# aws_network_acl.my_nacl: Refreshing state... [id=acl-044a1c4ecc41bc076]
# aws_security_group.sagemaker_sg: Refreshing state... [id=sg-0485562c610ce365f]
# aws_route_table.private_rt: Refreshing state... [id=rtb-0d592d6d93b2b0981]
# aws_subnet.public_subnet: Refreshing state... [id=subnet-0122da2129d691098]
# aws_subnet.private_subnet_1: Refreshing state... [id=subnet-0a9ddef84ff975a4b]
# aws_internet_gateway.my_igw: Refreshing state... [id=igw-06334980ce938c2a0]
# aws_network_acl_rule.inbound_allow_all: Refreshing state... [id=nacl-1847467266]
# aws_network_acl_association.private_2_nacl_assoc: Refreshing state... [id=aclassoc-0387ab3f5d00dc778]
# aws_network_acl_rule.outbound_allow_all: Refreshing state... [id=nacl-1970693416]
# aws_route_table_association.private_assoc_2: Refreshing state... [id=rtbassoc-0369cf17e84ad5dd2]
# aws_route.public_internet: Refreshing state... [id=r-rtb-0c35f0d2e95f8b3ee1080289494]
# aws_nat_gateway.my_nat: Refreshing state... [id=nat-07b8255225e45e0b0]
# aws_network_acl_association.public_nacl_assoc: Refreshing state... [id=aclassoc-033cf7be9b70f2539]
# aws_security_group.ec2_sg: Refreshing state... [id=sg-08d3bc7e3f0057d80]
# aws_route_table_association.private_assoc_1: Refreshing state... [id=rtbassoc-09354b98ef22e6b5d]
# aws_route_table_association.public_assoc: Refreshing state... [id=rtbassoc-01f7b02613d758fff]
# aws_network_acl_association.private_1_nacl_assoc: Refreshing state... [id=aclassoc-04ea4662a4bd8450a]
# aws_sagemaker_domain.my_domain: Refreshing state... [id=d-jccm2rxiyrfp]
# aws_route.private_nat: Refreshing state... [id=r-rtb-0d592d6d93b2b09811080289494]
# aws_instance.my_ec2: Refreshing state... [id=i-095fa9c0420ad953d]
# aws_sagemaker_user_profile.ai_user: Refreshing state... [id=arn:aws:sagemaker:us-east-1:609009159737:user-profile/d-jccm2rxiyrfp/ai-user]
# aws_sagemaker_space.shared_space: Refreshing state... [id=arn:aws:sagemaker:us-east-1:609009159737:space/d-jccm2rxiyrfp/shared-notebook]
# aws_sagemaker_space.private_space: Refreshing state... [id=arn:aws:sagemaker:us-east-1:609009159737:space/d-jccm2rxiyrfp/private-notebook]
#
# No changes. Your infrastructure matches the configuration.
#
# Terraform has compared your real infrastructure against your configuration
# and found no differences, so no changes are needed.
#
# Apply complete! Resources: 0 added, 0 changed, 0 destroyed.
#
# Outputs:
#
# ec2_private_ip = "10.0.1.12"
# mongodb_port = 3307
# private_space_name = "private-notebook"
# sagemaker_domain_id = "d-jccm2rxiyrfp"
# shared_space_name = "shared-notebook"
# user_profile_name = "ai-user"
# vpc_id = "vpc-09d06141d745ce35f"
