# %%
# %%bash
# # Check if Terraform is installed
# if ! command -v terraform &> /dev/null
# then
#     echo "Installing Terraform..."
#     wget https://releases.hashicorp.com/terraform/1.13.0/terraform_1.13.0_linux_amd64.zip
#     unzip terraform_1.13.0_linux_amd64.zip
#     sudo mv terraform /usr/local/bin/
#     rm terraform_1.13.0_linux_amd64.zip
# else
#     echo "Terraform is already installed."
# fi
# terraform --version
# Out:
# Terraform is already installed.
# Terraform v1.13.0
# on linux_amd64
# + provider registry.terraform.io/hashicorp/aws v5.100.0

# %%
# !terraform init
# Out:
# Initializing the backend...
# Initializing provider plugins...
# - Reusing previous version of hashicorp/aws from the dependency lock file
# - Using previously-installed hashicorp/aws v5.100.0
#
# Terraform has been successfully initialized!
#
# You may now begin working with Terraform. Try running "terraform plan" to see
# any changes that are required for your infrastructure. All Terraform commands
# should now work.
#
# If you ever set or change modules or backend configuration for Terraform,
# rerun this command to reinitialize your working directory. If you forget, other
# commands will detect it and remind you to do so if necessary.

# %%
# !terraform plan
# Out:
# aws_vpc.my_vpc: Refreshing state... [id=vpc-09d06141d745ce35f]
# aws_eip.nat_eip: Refreshing state... [id=eipalloc-01a7c8f7772f11809]
# data.aws_ami.amazon_linux: Reading...
# aws_iam_role.ec2_ssm_role: Refreshing state... [id=EC2SSMRole]
# aws_iam_role.sagemaker_role: Refreshing state... [id=SageMakerRole]
# aws_subnet.private_subnet_2: Refreshing state... [id=subnet-0e0f1ec3d6fa55ba1]
# aws_internet_gateway.my_igw: Refreshing state... [id=igw-06334980ce938c2a0]
# aws_network_acl.my_nacl: Refreshing state... [id=acl-044a1c4ecc41bc076]
# aws_security_group.sagemaker_sg: Refreshing state... [id=sg-0485562c610ce365f]
# aws_subnet.public_subnet: Refreshing state... [id=subnet-0122da2129d691098]
# aws_subnet.private_subnet_1: Refreshing state... [id=subnet-0a9ddef84ff975a4b]
# aws_route_table.public_rt: Refreshing state... [id=rtb-0c35f0d2e95f8b3ee]
# aws_route_table.private_rt: Refreshing state... [id=rtb-0d592d6d93b2b0981]
# aws_iam_role_policy_attachment.ec2_ssm_access: Refreshing state... [id=EC2SSMRole-20250825230712598600000002]
# aws_iam_instance_profile.ec2_ssm_profile: Refreshing state... [id=EC2SSMProfile]
# aws_network_acl_rule.outbound_allow_all: Refreshing state... [id=nacl-1970693416]
# aws_network_acl_association.private_2_nacl_assoc: Refreshing state... [id=aclassoc-0387ab3f5d00dc778]
# aws_network_acl_rule.inbound_allow_all: Refreshing state... [id=nacl-1847467266]
# aws_network_acl_association.private_1_nacl_assoc: Refreshing state... [id=aclassoc-04ea4662a4bd8450a]
# aws_route.public_internet: Refreshing state... [id=r-rtb-0c35f0d2e95f8b3ee1080289494]
# aws_security_group.ec2_sg: Refreshing state... [id=sg-08d3bc7e3f0057d80]
# aws_network_acl_association.public_nacl_assoc: Refreshing state... [id=aclassoc-033cf7be9b70f2539]
# aws_nat_gateway.my_nat: Refreshing state... [id=nat-07b8255225e45e0b0]
# aws_route_table_association.public_assoc: Refreshing state... [id=rtbassoc-01f7b02613d758fff]
# aws_iam_role_policy_attachment.sagemaker_full_access: Refreshing state... [id=SageMakerRole-20250825230712552900000001]
# aws_sagemaker_domain.my_domain: Refreshing state... [id=d-jccm2rxiyrfp]
# aws_route_table_association.private_assoc_2: Refreshing state... [id=rtbassoc-0369cf17e84ad5dd2]
# aws_route_table_association.private_assoc_1: Refreshing state... [id=rtbassoc-09354b98ef22e6b5d]
# aws_route.private_nat: Refreshing state... [id=r-rtb-0d592d6d93b2b09811080289494]
# aws_sagemaker_user_profile.ai_user: Refreshing state... [id=arn:aws:sagemaker:us-east-1:609009159737:user-profile/d-jccm2rxiyrfp/ai-user]
# aws_sagemaker_space.shared_space: Refreshing state... [id=arn:aws:sagemaker:us-east-1:609009159737:space/d-jccm2rxiyrfp/shared-notebook]
# aws_sagemaker_space.private_space: Refreshing state... [id=arn:aws:sagemaker:us-east-1:609009159737:space/d-jccm2rxiyrfp/private-notebook]
# data.aws_ami.amazon_linux: Read complete after 1s [id=ami-0309908417d7ea2d0]
# aws_instance.my_ec2: Refreshing state... [id=i-095fa9c0420ad953d]
#
# Note: Objects have changed outside of Terraform
#
# Terraform detected the following changes made outside of Terraform since the
# last "terraform apply" which may have affected this plan:
#
#   # aws_instance.my_ec2 has been deleted
#   - resource "aws_instance" "my_ec2" {
#         id                                   = "i-095fa9c0420ad953d"
#       - private_ip                           = "10.0.1.12" -> null
#         tags                                 = {
#             "Name" = "my-ec2"
#         }
#         # (39 unchanged attributes hidden)
#
#         # (8 unchanged blocks hidden)
#     }
#
#   # aws_internet_gateway.my_igw has been deleted
#   - resource "aws_internet_gateway" "my_igw" {
#       - id       = "igw-06334980ce938c2a0" -> null
#         tags     = {
#             "Name" = "my-igw"
#         }
#         # (4 unchanged attributes hidden)
#     }
#
#   # aws_nat_gateway.my_nat has been deleted
#   - resource "aws_nat_gateway" "my_nat" {
#       - id                                 = "nat-07b8255225e45e0b0" -> null
#         tags                               = {
#             "Name" = "my-nat"
#         }
#         # (11 unchanged attributes hidden)
#     }
#
#   # aws_network_acl.my_nacl has been deleted
#   - resource "aws_network_acl" "my_nacl" {
#       - id         = "acl-044a1c4ecc41bc076" -> null
#         tags       = {
#             "Name" = "my-nacl"
#         }
#         # (7 unchanged attributes hidden)
#     }
#
#   # aws_route_table.private_rt has been deleted
#   - resource "aws_route_table" "private_rt" {
#       - id               = "rtb-0d592d6d93b2b0981" -> null
#         tags             = {
#             "Name" = "private-rt"
#         }
#         # (6 unchanged attributes hidden)
#     }
#
#   # aws_route_table.public_rt has been deleted
#   - resource "aws_route_table" "public_rt" {
#       - id               = "rtb-0c35f0d2e95f8b3ee" -> null
#         tags             = {
#             "Name" = "public-rt"
#         }
#         # (6 unchanged attributes hidden)
#     }
#
#   # aws_sagemaker_domain.my_domain has been deleted
#   - resource "aws_sagemaker_domain" "my_domain" {
#       - id                                             = "d-jccm2rxiyrfp" -> null
#         tags                                           = {}
#         # (15 unchanged attributes hidden)
#
#         # (2 unchanged blocks hidden)
#     }
#
#   # aws_sagemaker_user_profile.ai_user has been deleted
#   - resource "aws_sagemaker_user_profile" "ai_user" {
#         id                             = "arn:aws:sagemaker:us-east-1:609009159737:user-profile/d-jccm2rxiyrfp/ai-user"
#         tags                           = {}
#       - user_profile_name              = "ai-user" -> null
#         # (6 unchanged attributes hidden)
#
#         # (1 unchanged block hidden)
#     }
#
#   # aws_security_group.ec2_sg has been deleted
#   - resource "aws_security_group" "ec2_sg" {
#       - id                     = "sg-08d3bc7e3f0057d80" -> null
#         name                   = "ec2-sg"
#         tags                   = {
#             "Name" = "ec2-sg"
#         }
#         # (9 unchanged attributes hidden)
#     }
#
#   # aws_security_group.sagemaker_sg has been deleted
#   - resource "aws_security_group" "sagemaker_sg" {
#       - id                     = "sg-0485562c610ce365f" -> null
#         name                   = "sagemaker-sg"
#         tags                   = {
#             "Name" = "sagemaker-sg"
#         }
#         # (9 unchanged attributes hidden)
#     }
#
#   # aws_subnet.private_subnet_1 has been deleted
#   - resource "aws_subnet" "private_subnet_1" {
#       - id                                             = "subnet-0a9ddef84ff975a4b" -> null
#         tags                                           = {
#             "Name" = "private-subnet-1"
#         }
#         # (20 unchanged attributes hidden)
#     }
#
#   # aws_subnet.private_subnet_2 has been deleted
#   - resource "aws_subnet" "private_subnet_2" {
#       - id                                             = "subnet-0e0f1ec3d6fa55ba1" -> null
#         tags                                           = {
#             "Name" = "private-subnet-2"
#         }
#         # (20 unchanged attributes hidden)
#     }
#
#   # aws_subnet.public_subnet has been deleted
#   - resource "aws_subnet" "public_subnet" {
#       - id                                             = "subnet-0122da2129d691098" -> null
#         tags                                           = {
#             "Name" = "public-subnet"
#         }
#         # (20 unchanged attributes hidden)
#     }
#
#   # aws_vpc.my_vpc has been deleted
#   - resource "aws_vpc" "my_vpc" {
#       - id                                   = "vpc-09d06141d745ce35f" -> null
#         tags                                 = {
#             "Name" = "my-vpc"
#         }
#         # (19 unchanged attributes hidden)
#     }
#
#
# Unless you have made equivalent changes to your configuration, or ignored the
# relevant attributes using ignore_changes, the following plan may include
# actions to undo or respond to these changes.
#
# ───────────────────────────────────────────────────────────────────────────────
#
# Terraform used the selected providers to generate the following execution plan.
# Resource actions are indicated with the following symbols:
#   + create
#
# Terraform will perform the following actions:
#
#   # aws_instance.my_ec2 will be created
#   + resource "aws_instance" "my_ec2" {
#       + ami                                  = "ami-0309908417d7ea2d0"
#       + arn                                  = (known after apply)
#       + associate_public_ip_address          = false
#       + availability_zone                    = (known after apply)
#       + cpu_core_count                       = (known after apply)
#       + cpu_threads_per_core                 = (known after apply)
#       + disable_api_stop                     = (known after apply)
#       + disable_api_termination              = (known after apply)
#       + ebs_optimized                        = (known after apply)
#       + enable_primary_ipv6                  = (known after apply)
#       + get_password_data                    = false
#       + host_id                              = (known after apply)
#       + host_resource_group_arn              = (known after apply)
#       + iam_instance_profile                 = "EC2SSMProfile"
#       + id                                   = (known after apply)
#       + instance_initiated_shutdown_behavior = (known after apply)
#       + instance_lifecycle                   = (known after apply)
#       + instance_state                       = (known after apply)
#       + instance_type                        = "t2.micro"
#       + ipv6_address_count                   = (known after apply)
#       + ipv6_addresses                       = (known after apply)
#       + key_name                             = (known after apply)
#       + monitoring                           = (known after apply)
#       + outpost_arn                          = (known after apply)
#       + password_data                        = (known after apply)
#       + placement_group                      = (known after apply)
#       + placement_partition_number           = (known after apply)
#       + primary_network_interface_id         = (known after apply)
#       + private_dns                          = (known after apply)
#       + private_ip                           = (known after apply)
#       + public_dns                           = (known after apply)
#       + public_ip                            = (known after apply)
#       + secondary_private_ips                = (known after apply)
#       + security_groups                      = (known after apply)
#       + source_dest_check                    = true
#       + spot_instance_request_id             = (known after apply)
#       + subnet_id                            = (known after apply)
#       + tags                                 = {
#           + "Name" = "my-ec2"
#         }
#       + tags_all                             = {
#           + "Name" = "my-ec2"
#         }
#       + tenancy                              = (known after apply)
#       + user_data                            = "4eccd0c8fd4ebe33b7e3f557709750a2c7ff18e9"
#       + user_data_base64                     = (known after apply)
#       + user_data_replace_on_change          = false
#       + vpc_security_group_ids               = (known after apply)
#
#       + capacity_reservation_specification (known after apply)
#
#       + cpu_options (known after apply)
#
#       + ebs_block_device (known after apply)
#
#       + enclave_options (known after apply)
#
#       + ephemeral_block_device (known after apply)
#
#       + instance_market_options (known after apply)
#
#       + maintenance_options (known after apply)
#
#       + metadata_options (known after apply)
#
#       + network_interface (known after apply)
#
#       + private_dns_name_options (known after apply)
#
#       + root_block_device (known after apply)
#     }
#
#   # aws_internet_gateway.my_igw will be created
#   + resource "aws_internet_gateway" "my_igw" {
#       + arn      = (known after apply)
#       + id       = (known after apply)
#       + owner_id = (known after apply)
#       + tags     = {
#           + "Name" = "my-igw"
#         }
#       + tags_all = {
#           + "Name" = "my-igw"
#         }
#       + vpc_id   = (known after apply)
#     }
#
#   # aws_nat_gateway.my_nat will be created
#   + resource "aws_nat_gateway" "my_nat" {
#       + allocation_id                      = "eipalloc-01a7c8f7772f11809"
#       + association_id                     = (known after apply)
#       + connectivity_type                  = "public"
#       + id                                 = (known after apply)
#       + network_interface_id               = (known after apply)
#       + private_ip                         = (known after apply)
#       + public_ip                          = (known after apply)
#       + secondary_private_ip_address_count = (known after apply)
#       + secondary_private_ip_addresses     = (known after apply)
#       + subnet_id                          = (known after apply)
#       + tags                               = {
#           + "Name" = "my-nat"
#         }
#       + tags_all                           = {
#           + "Name" = "my-nat"
#         }
#     }
#
#   # aws_network_acl.my_nacl will be created
#   + resource "aws_network_acl" "my_nacl" {
#       + arn        = (known after apply)
#       + egress     = (known after apply)
#       + id         = (known after apply)
#       + ingress    = (known after apply)
#       + owner_id   = (known after apply)
#       + subnet_ids = (known after apply)
#       + tags       = {
#           + "Name" = "my-nacl"
#         }
#       + tags_all   = {
#           + "Name" = "my-nacl"
#         }
#       + vpc_id     = (known after apply)
#     }
#
#   # aws_network_acl_association.private_1_nacl_assoc will be created
#   + resource "aws_network_acl_association" "private_1_nacl_assoc" {
#       + id             = (known after apply)
#       + network_acl_id = (known after apply)
#       + subnet_id      = (known after apply)
#     }
#
#   # aws_network_acl_association.private_2_nacl_assoc will be created
#   + resource "aws_network_acl_association" "private_2_nacl_assoc" {
#       + id             = (known after apply)
#       + network_acl_id = (known after apply)
#       + subnet_id      = (known after apply)
#     }
#
#   # aws_network_acl_association.public_nacl_assoc will be created
#   + resource "aws_network_acl_association" "public_nacl_assoc" {
#       + id             = (known after apply)
#       + network_acl_id = (known after apply)
#       + subnet_id      = (known after apply)
#     }
#
#   # aws_network_acl_rule.inbound_allow_all will be created
#   + resource "aws_network_acl_rule" "inbound_allow_all" {
#       + cidr_block     = "0.0.0.0/0"
#       + egress         = false
#       + id             = (known after apply)
#       + network_acl_id = (known after apply)
#       + protocol       = "-1"
#       + rule_action    = "allow"
#       + rule_number    = 100
#     }
#
#   # aws_network_acl_rule.outbound_allow_all will be created
#   + resource "aws_network_acl_rule" "outbound_allow_all" {
#       + cidr_block     = "0.0.0.0/0"
#       + egress         = true
#       + id             = (known after apply)
#       + network_acl_id = (known after apply)
#       + protocol       = "-1"
#       + rule_action    = "allow"
#       + rule_number    = 100
#     }
#
#   # aws_route.private_nat will be created
#   + resource "aws_route" "private_nat" {
#       + destination_cidr_block = "0.0.0.0/0"
#       + id                     = (known after apply)
#       + instance_id            = (known after apply)
#       + instance_owner_id      = (known after apply)
#       + nat_gateway_id         = (known after apply)
#       + network_interface_id   = (known after apply)
#       + origin                 = (known after apply)
#       + route_table_id         = (known after apply)
#       + state                  = (known after apply)
#     }
#
#   # aws_route.public_internet will be created
#   + resource "aws_route" "public_internet" {
#       + destination_cidr_block = "0.0.0.0/0"
#       + gateway_id             = (known after apply)
#       + id                     = (known after apply)
#       + instance_id            = (known after apply)
#       + instance_owner_id      = (known after apply)
#       + network_interface_id   = (known after apply)
#       + origin                 = (known after apply)
#       + route_table_id         = (known after apply)
#       + state                  = (known after apply)
#     }
#
#   # aws_route_table.private_rt will be created
#   + resource "aws_route_table" "private_rt" {
#       + arn              = (known after apply)
#       + id               = (known after apply)
#       + owner_id         = (known after apply)
#       + propagating_vgws = (known after apply)
#       + route            = (known after apply)
#       + tags             = {
#           + "Name" = "private-rt"
#         }
#       + tags_all         = {
#           + "Name" = "private-rt"
#         }
#       + vpc_id           = (known after apply)
#     }
#
#   # aws_route_table.public_rt will be created
#   + resource "aws_route_table" "public_rt" {
#       + arn              = (known after apply)
#       + id               = (known after apply)
#       + owner_id         = (known after apply)
#       + propagating_vgws = (known after apply)
#       + route            = (known after apply)
#       + tags             = {
#           + "Name" = "public-rt"
#         }
#       + tags_all         = {
#           + "Name" = "public-rt"
#         }
#       + vpc_id           = (known after apply)
#     }
#
#   # aws_route_table_association.private_assoc_1 will be created
#   + resource "aws_route_table_association" "private_assoc_1" {
#       + id             = (known after apply)
#       + route_table_id = (known after apply)
#       + subnet_id      = (known after apply)
#     }
#
#   # aws_route_table_association.private_assoc_2 will be created
#   + resource "aws_route_table_association" "private_assoc_2" {
#       + id             = (known after apply)
#       + route_table_id = (known after apply)
#       + subnet_id      = (known after apply)
#     }
#
#   # aws_route_table_association.public_assoc will be created
#   + resource "aws_route_table_association" "public_assoc" {
#       + id             = (known after apply)
#       + route_table_id = (known after apply)
#       + subnet_id      = (known after apply)
#     }
#
#   # aws_sagemaker_domain.my_domain will be created
#   + resource "aws_sagemaker_domain" "my_domain" {
#       + app_network_access_type                        = "VpcOnly"
#       + arn                                            = (known after apply)
#       + auth_mode                                      = "IAM"
#       + domain_name                                    = "my-domain"
#       + home_efs_file_system_id                        = (known after apply)
#       + id                                             = (known after apply)
#       + security_group_id_for_domain_boundary          = (known after apply)
#       + single_sign_on_application_arn                 = (known after apply)
#       + single_sign_on_managed_application_instance_id = (known after apply)
#       + subnet_ids                                     = (known after apply)
#       + tag_propagation                                = "DISABLED"
#       + tags_all                                       = (known after apply)
#       + url                                            = (known after apply)
#       + vpc_id                                         = (known after apply)
#
#       + default_space_settings {
#           + execution_role  = "arn:aws:iam::609009159737:role/SageMakerRole"
#           + security_groups = (known after apply)
#
#           + space_storage_settings (known after apply)
#         }
#
#       + default_user_settings {
#           + auto_mount_home_efs = (known after apply)
#           + default_landing_uri = (known after apply)
#           + execution_role      = "arn:aws:iam::609009159737:role/SageMakerRole"
#           + security_groups     = (known after apply)
#           + studio_web_portal   = (known after apply)
#
#           + space_storage_settings (known after apply)
#         }
#     }
#
#   # aws_sagemaker_space.private_space will be created
#   + resource "aws_sagemaker_space" "private_space" {
#       + arn                      = (known after apply)
#       + domain_id                = (known after apply)
#       + home_efs_file_system_uid = (known after apply)
#       + id                       = (known after apply)
#       + space_name               = "private-notebook"
#       + tags_all                 = (known after apply)
#       + url                      = (known after apply)
#
#       + ownership_settings {
#           + owner_user_profile_name = "ai-user"
#         }
#
#       + space_settings {
#           + app_type = "JupyterLab"
#
#           + jupyter_lab_app_settings {
#               + default_resource_spec {
#                   + instance_type = "ml.t3.medium"
#                 }
#             }
#
#           + space_storage_settings (known after apply)
#         }
#
#       + space_sharing_settings {
#           + sharing_type = "Private"
#         }
#     }
#
#   # aws_sagemaker_space.shared_space will be created
#   + resource "aws_sagemaker_space" "shared_space" {
#       + arn                      = (known after apply)
#       + domain_id                = (known after apply)
#       + home_efs_file_system_uid = (known after apply)
#       + id                       = (known after apply)
#       + space_name               = "shared-notebook"
#       + tags_all                 = (known after apply)
#       + url                      = (known after apply)
#
#       + ownership_settings {
#           + owner_user_profile_name = "ai-user"
#         }
#
#       + space_settings {
#           + app_type = "JupyterLab"
#
#           + jupyter_lab_app_settings {
#               + default_resource_spec {
#                   + instance_type = "ml.t3.medium"
#                 }
#             }
#
#           + space_storage_settings (known after apply)
#         }
#
#       + space_sharing_settings {
#           + sharing_type = "Shared"
#         }
#     }
#
#   # aws_sagemaker_user_profile.ai_user will be created
#   + resource "aws_sagemaker_user_profile" "ai_user" {
#       + arn                      = (known after apply)
#       + domain_id                = (known after apply)
#       + home_efs_file_system_uid = (known after apply)
#       + id                       = (known after apply)
#       + tags_all                 = (known after apply)
#       + user_profile_name        = "ai-user"
#
#       + user_settings {
#           + auto_mount_home_efs = (known after apply)
#           + execution_role      = "arn:aws:iam::609009159737:role/SageMakerRole"
#           + security_groups     = (known after apply)
#           + studio_web_portal   = (known after apply)
#
#           + space_storage_settings (known after apply)
#         }
#     }
#
#   # aws_security_group.ec2_sg will be created
#   + resource "aws_security_group" "ec2_sg" {
#       + arn                    = (known after apply)
#       + description            = "For EC2 MongoDB"
#       + egress                 = [
#           + {
#               + cidr_blocks      = [
#                   + "0.0.0.0/0",
#                 ]
#               + from_port        = 0
#               + ipv6_cidr_blocks = []
#               + prefix_list_ids  = []
#               + protocol         = "-1"
#               + security_groups  = []
#               + self             = false
#               + to_port          = 0
#                 # (1 unchanged attribute hidden)
#             },
#         ]
#       + id                     = (known after apply)
#       + ingress                = [
#           + {
#               + cidr_blocks      = []
#               + from_port        = 3307
#               + ipv6_cidr_blocks = []
#               + prefix_list_ids  = []
#               + protocol         = "tcp"
#               + security_groups  = (known after apply)
#               + self             = false
#               + to_port          = 3307
#                 # (1 unchanged attribute hidden)
#             },
#         ]
#       + name                   = "ec2-sg"
#       + name_prefix            = (known after apply)
#       + owner_id               = (known after apply)
#       + revoke_rules_on_delete = false
#       + tags                   = {
#           + "Name" = "ec2-sg"
#         }
#       + tags_all               = {
#           + "Name" = "ec2-sg"
#         }
#       + vpc_id                 = (known after apply)
#     }
#
#   # aws_security_group.sagemaker_sg will be created
#   + resource "aws_security_group" "sagemaker_sg" {
#       + arn                    = (known after apply)
#       + description            = "For SageMaker"
#       + egress                 = [
#           + {
#               + cidr_blocks      = [
#                   + "0.0.0.0/0",
#                 ]
#               + from_port        = 0
#               + ipv6_cidr_blocks = []
#               + prefix_list_ids  = []
#               + protocol         = "-1"
#               + security_groups  = []
#               + self             = false
#               + to_port          = 0
#                 # (1 unchanged attribute hidden)
#             },
#         ]
#       + id                     = (known after apply)
#       + ingress                = (known after apply)
#       + name                   = "sagemaker-sg"
#       + name_prefix            = (known after apply)
#       + owner_id               = (known after apply)
#       + revoke_rules_on_delete = false
#       + tags                   = {
#           + "Name" = "sagemaker-sg"
#         }
#       + tags_all               = {
#           + "Name" = "sagemaker-sg"
#         }
#       + vpc_id                 = (known after apply)
#     }
#
#   # aws_subnet.private_subnet_1 will be created
#   + resource "aws_subnet" "private_subnet_1" {
#       + arn                                            = (known after apply)
#       + assign_ipv6_address_on_creation                = false
#       + availability_zone                              = "us-east-1a"
#       + availability_zone_id                           = (known after apply)
#       + cidr_block                                     = "10.0.1.0/24"
#       + enable_dns64                                   = false
#       + enable_resource_name_dns_a_record_on_launch    = false
#       + enable_resource_name_dns_aaaa_record_on_launch = false
#       + id                                             = (known after apply)
#       + ipv6_cidr_block_association_id                 = (known after apply)
#       + ipv6_native                                    = false
#       + map_public_ip_on_launch                        = false
#       + owner_id                                       = (known after apply)
#       + private_dns_hostname_type_on_launch            = (known after apply)
#       + tags                                           = {
#           + "Name" = "private-subnet-1"
#         }
#       + tags_all                                       = {
#           + "Name" = "private-subnet-1"
#         }
#       + vpc_id                                         = (known after apply)
#     }
#
#   # aws_subnet.private_subnet_2 will be created
#   + resource "aws_subnet" "private_subnet_2" {
#       + arn                                            = (known after apply)
#       + assign_ipv6_address_on_creation                = false
#       + availability_zone                              = "us-east-1b"
#       + availability_zone_id                           = (known after apply)
#       + cidr_block                                     = "10.0.2.0/24"
#       + enable_dns64                                   = false
#       + enable_resource_name_dns_a_record_on_launch    = false
#       + enable_resource_name_dns_aaaa_record_on_launch = false
#       + id                                             = (known after apply)
#       + ipv6_cidr_block_association_id                 = (known after apply)
#       + ipv6_native                                    = false
#       + map_public_ip_on_launch                        = false
#       + owner_id                                       = (known after apply)
#       + private_dns_hostname_type_on_launch            = (known after apply)
#       + tags                                           = {
#           + "Name" = "private-subnet-2"
#         }
#       + tags_all                                       = {
#           + "Name" = "private-subnet-2"
#         }
#       + vpc_id                                         = (known after apply)
#     }
#
#   # aws_subnet.public_subnet will be created
#   + resource "aws_subnet" "public_subnet" {
#       + arn                                            = (known after apply)
#       + assign_ipv6_address_on_creation                = false
#       + availability_zone                              = "us-east-1a"
#       + availability_zone_id                           = (known after apply)
#       + cidr_block                                     = "10.0.0.0/24"
#       + enable_dns64                                   = false
#       + enable_resource_name_dns_a_record_on_launch    = false
#       + enable_resource_name_dns_aaaa_record_on_launch = false
#       + id                                             = (known after apply)
#       + ipv6_cidr_block_association_id                 = (known after apply)
#       + ipv6_native                                    = false
#       + map_public_ip_on_launch                        = false
#       + owner_id                                       = (known after apply)
#       + private_dns_hostname_type_on_launch            = (known after apply)
#       + tags                                           = {
#           + "Name" = "public-subnet"
#         }
#       + tags_all                                       = {
#           + "Name" = "public-subnet"
#         }
#       + vpc_id                                         = (known after apply)
#     }
#
#   # aws_vpc.my_vpc will be created
#   + resource "aws_vpc" "my_vpc" {
#       + arn                                  = (known after apply)
#       + cidr_block                           = "10.0.0.0/16"
#       + default_network_acl_id               = (known after apply)
#       + default_route_table_id               = (known after apply)
#       + default_security_group_id            = (known after apply)
#       + dhcp_options_id                      = (known after apply)
#       + enable_dns_hostnames                 = (known after apply)
#       + enable_dns_support                   = true
#       + enable_network_address_usage_metrics = (known after apply)
#       + id                                   = (known after apply)
#       + instance_tenancy                     = "default"
#       + ipv6_association_id                  = (known after apply)
#       + ipv6_cidr_block                      = (known after apply)
#       + ipv6_cidr_block_network_border_group = (known after apply)
#       + main_route_table_id                  = (known after apply)
#       + owner_id                             = (known after apply)
#       + tags                                 = {
#           + "Name" = "my-vpc"
#         }
#       + tags_all                             = {
#           + "Name" = "my-vpc"
#         }
#     }
#
# Plan: 26 to add, 0 to change, 0 to destroy.
#
# Changes to Outputs:
#   ~ ec2_private_ip      = "10.0.1.12" -> (known after apply)
#   ~ sagemaker_domain_id = "d-jccm2rxiyrfp" -> (known after apply)
#   ~ vpc_id              = "vpc-09d06141d745ce35f" -> (known after apply)
#
# ───────────────────────────────────────────────────────────────────────────────
#
# Note: You didn't use the -out option to save this plan, so Terraform can't
# guarantee to take exactly these actions if you run "terraform apply" now.

# %%
# !terraform apply --auto-approve
# Out:
# data.aws_ami.amazon_linux: Reading...
# aws_iam_role.sagemaker_role: Refreshing state... [id=SageMakerRole]
# aws_iam_role.ec2_ssm_role: Refreshing state... [id=EC2SSMRole]
# aws_eip.nat_eip: Refreshing state... [id=eipalloc-01a7c8f7772f11809]
# aws_vpc.my_vpc: Refreshing state... [id=vpc-09d06141d745ce35f]
# aws_internet_gateway.my_igw: Refreshing state... [id=igw-06334980ce938c2a0]
# aws_network_acl.my_nacl: Refreshing state... [id=acl-044a1c4ecc41bc076]
# aws_iam_role_policy_attachment.sagemaker_full_access: Refreshing state... [id=SageMakerRole-20250825230712552900000001]
# aws_route_table.public_rt: Refreshing state... [id=rtb-0c35f0d2e95f8b3ee]
# aws_subnet.public_subnet: Refreshing state... [id=subnet-0122da2129d691098]
# aws_subnet.private_subnet_2: Refreshing state... [id=subnet-0e0f1ec3d6fa55ba1]
# aws_route_table.private_rt: Refreshing state... [id=rtb-0d592d6d93b2b0981]
# aws_subnet.private_subnet_1: Refreshing state... [id=subnet-0a9ddef84ff975a4b]
# aws_security_group.sagemaker_sg: Refreshing state... [id=sg-0485562c610ce365f]
# aws_iam_instance_profile.ec2_ssm_profile: Refreshing state... [id=EC2SSMProfile]
# aws_iam_role_policy_attachment.ec2_ssm_access: Refreshing state... [id=EC2SSMRole-20250825230712598600000002]
# aws_network_acl_rule.inbound_allow_all: Refreshing state... [id=nacl-1847467266]
# aws_network_acl_rule.outbound_allow_all: Refreshing state... [id=nacl-1970693416]
# aws_network_acl_association.private_1_nacl_assoc: Refreshing state... [id=aclassoc-04ea4662a4bd8450a]
# aws_route_table_association.private_assoc_1: Refreshing state... [id=rtbassoc-09354b98ef22e6b5d]
# aws_route.public_internet: Refreshing state... [id=r-rtb-0c35f0d2e95f8b3ee1080289494]
# aws_route_table_association.public_assoc: Refreshing state... [id=rtbassoc-01f7b02613d758fff]
# aws_network_acl_association.public_nacl_assoc: Refreshing state... [id=aclassoc-033cf7be9b70f2539]
# aws_nat_gateway.my_nat: Refreshing state... [id=nat-07b8255225e45e0b0]
# aws_network_acl_association.private_2_nacl_assoc: Refreshing state... [id=aclassoc-0387ab3f5d00dc778]
# aws_route_table_association.private_assoc_2: Refreshing state... [id=rtbassoc-0369cf17e84ad5dd2]
# aws_security_group.ec2_sg: Refreshing state... [id=sg-08d3bc7e3f0057d80]
# aws_sagemaker_domain.my_domain: Refreshing state... [id=d-jccm2rxiyrfp]
# aws_route.private_nat: Refreshing state... [id=r-rtb-0d592d6d93b2b09811080289494]
# aws_sagemaker_user_profile.ai_user: Refreshing state... [id=arn:aws:sagemaker:us-east-1:609009159737:user-profile/d-jccm2rxiyrfp/ai-user]
# aws_sagemaker_space.private_space: Refreshing state... [id=arn:aws:sagemaker:us-east-1:609009159737:space/d-jccm2rxiyrfp/private-notebook]
# aws_sagemaker_space.shared_space: Refreshing state... [id=arn:aws:sagemaker:us-east-1:609009159737:space/d-jccm2rxiyrfp/shared-notebook]
# data.aws_ami.amazon_linux: Read complete after 0s [id=ami-0309908417d7ea2d0]
# aws_instance.my_ec2: Refreshing state... [id=i-095fa9c0420ad953d]
#
# Note: Objects have changed outside of Terraform
#
# Terraform detected the following changes made outside of Terraform since the
# last "terraform apply" which may have affected this plan:
#
#   # aws_instance.my_ec2 has been deleted
#   - resource "aws_instance" "my_ec2" {
#         id                                   = "i-095fa9c0420ad953d"
#       - private_ip                           = "10.0.1.12" -> null
#         tags                                 = {
#             "Name" = "my-ec2"
#         }
#         # (39 unchanged attributes hidden)
#
#         # (8 unchanged blocks hidden)
#     }
#
#   # aws_internet_gateway.my_igw has been deleted
#   - resource "aws_internet_gateway" "my_igw" {
#       - id       = "igw-06334980ce938c2a0" -> null
#         tags     = {
#             "Name" = "my-igw"
#         }
#         # (4 unchanged attributes hidden)
#     }
#
#   # aws_nat_gateway.my_nat has been deleted
#   - resource "aws_nat_gateway" "my_nat" {
#       - id                                 = "nat-07b8255225e45e0b0" -> null
#         tags                               = {
#             "Name" = "my-nat"
#         }
#         # (11 unchanged attributes hidden)
#     }
#
#   # aws_network_acl.my_nacl has been deleted
#   - resource "aws_network_acl" "my_nacl" {
#       - id         = "acl-044a1c4ecc41bc076" -> null
#         tags       = {
#             "Name" = "my-nacl"
#         }
#         # (7 unchanged attributes hidden)
#     }
#
#   # aws_route_table.private_rt has been deleted
#   - resource "aws_route_table" "private_rt" {
#       - id               = "rtb-0d592d6d93b2b0981" -> null
#         tags             = {
#             "Name" = "private-rt"
#         }
#         # (6 unchanged attributes hidden)
#     }
#
#   # aws_route_table.public_rt has been deleted
#   - resource "aws_route_table" "public_rt" {
#       - id               = "rtb-0c35f0d2e95f8b3ee" -> null
#         tags             = {
#             "Name" = "public-rt"
#         }
#         # (6 unchanged attributes hidden)
#     }
#
#   # aws_sagemaker_domain.my_domain has been deleted
#   - resource "aws_sagemaker_domain" "my_domain" {
#       - id                                             = "d-jccm2rxiyrfp" -> null
#         tags                                           = {}
#         # (15 unchanged attributes hidden)
#
#         # (2 unchanged blocks hidden)
#     }
#
#   # aws_sagemaker_user_profile.ai_user has been deleted
#   - resource "aws_sagemaker_user_profile" "ai_user" {
#         id                             = "arn:aws:sagemaker:us-east-1:609009159737:user-profile/d-jccm2rxiyrfp/ai-user"
#         tags                           = {}
#       - user_profile_name              = "ai-user" -> null
#         # (6 unchanged attributes hidden)
#
#         # (1 unchanged block hidden)
#     }
#
#   # aws_security_group.ec2_sg has been deleted
#   - resource "aws_security_group" "ec2_sg" {
#       - id                     = "sg-08d3bc7e3f0057d80" -> null
#         name                   = "ec2-sg"
#         tags                   = {
#             "Name" = "ec2-sg"
#         }
#         # (9 unchanged attributes hidden)
#     }
#
#   # aws_security_group.sagemaker_sg has been deleted
#   - resource "aws_security_group" "sagemaker_sg" {
#       - id                     = "sg-0485562c610ce365f" -> null
#         name                   = "sagemaker-sg"
#         tags                   = {
#             "Name" = "sagemaker-sg"
#         }
#         # (9 unchanged attributes hidden)
#     }
#
#   # aws_subnet.private_subnet_1 has been deleted
#   - resource "aws_subnet" "private_subnet_1" {
#       - id                                             = "subnet-0a9ddef84ff975a4b" -> null
#         tags                                           = {
#             "Name" = "private-subnet-1"
#         }
#         # (20 unchanged attributes hidden)
#     }
#
#   # aws_subnet.private_subnet_2 has been deleted
#   - resource "aws_subnet" "private_subnet_2" {
#       - id                                             = "subnet-0e0f1ec3d6fa55ba1" -> null
#         tags                                           = {
#             "Name" = "private-subnet-2"
#         }
#         # (20 unchanged attributes hidden)
#     }
#
#   # aws_subnet.public_subnet has been deleted
#   - resource "aws_subnet" "public_subnet" {
#       - id                                             = "subnet-0122da2129d691098" -> null
#         tags                                           = {
#             "Name" = "public-subnet"
#         }
#         # (20 unchanged attributes hidden)
#     }
#
#   # aws_vpc.my_vpc has been deleted
#   - resource "aws_vpc" "my_vpc" {
#       - id                                   = "vpc-09d06141d745ce35f" -> null
#         tags                                 = {
#             "Name" = "my-vpc"
#         }
#         # (19 unchanged attributes hidden)
#     }
#
#
# Unless you have made equivalent changes to your configuration, or ignored the
# relevant attributes using ignore_changes, the following plan may include
# actions to undo or respond to these changes.
#
# ───────────────────────────────────────────────────────────────────────────────
#
# Terraform used the selected providers to generate the following execution plan.
# Resource actions are indicated with the following symbols:
#   + create
#
# Terraform will perform the following actions:
#
#   # aws_instance.my_ec2 will be created
#   + resource "aws_instance" "my_ec2" {
#       + ami                                  = "ami-0309908417d7ea2d0"
#       + arn                                  = (known after apply)
#       + associate_public_ip_address          = false
#       + availability_zone                    = (known after apply)
#       + cpu_core_count                       = (known after apply)
#       + cpu_threads_per_core                 = (known after apply)
#       + disable_api_stop                     = (known after apply)
#       + disable_api_termination              = (known after apply)
#       + ebs_optimized                        = (known after apply)
#       + enable_primary_ipv6                  = (known after apply)
#       + get_password_data                    = false
#       + host_id                              = (known after apply)
#       + host_resource_group_arn              = (known after apply)
#       + iam_instance_profile                 = "EC2SSMProfile"
#       + id                                   = (known after apply)
#       + instance_initiated_shutdown_behavior = (known after apply)
#       + instance_lifecycle                   = (known after apply)
#       + instance_state                       = (known after apply)
#       + instance_type                        = "t2.micro"
#       + ipv6_address_count                   = (known after apply)
#       + ipv6_addresses                       = (known after apply)
#       + key_name                             = (known after apply)
#       + monitoring                           = (known after apply)
#       + outpost_arn                          = (known after apply)
#       + password_data                        = (known after apply)
#       + placement_group                      = (known after apply)
#       + placement_partition_number           = (known after apply)
#       + primary_network_interface_id         = (known after apply)
#       + private_dns                          = (known after apply)
#       + private_ip                           = (known after apply)
#       + public_dns                           = (known after apply)
#       + public_ip                            = (known after apply)
#       + secondary_private_ips                = (known after apply)
#       + security_groups                      = (known after apply)
#       + source_dest_check                    = true
#       + spot_instance_request_id             = (known after apply)
#       + subnet_id                            = (known after apply)
#       + tags                                 = {
#           + "Name" = "my-ec2"
#         }
#       + tags_all                             = {
#           + "Name" = "my-ec2"
#         }
#       + tenancy                              = (known after apply)
#       + user_data                            = "4eccd0c8fd4ebe33b7e3f557709750a2c7ff18e9"
#       + user_data_base64                     = (known after apply)
#       + user_data_replace_on_change          = false
#       + vpc_security_group_ids               = (known after apply)
#
#       + capacity_reservation_specification (known after apply)
#
#       + cpu_options (known after apply)
#
#       + ebs_block_device (known after apply)
#
#       + enclave_options (known after apply)
#
#       + ephemeral_block_device (known after apply)
#
#       + instance_market_options (known after apply)
#
#       + maintenance_options (known after apply)
#
#       + metadata_options (known after apply)
#
#       + network_interface (known after apply)
#
#       + private_dns_name_options (known after apply)
#
#       + root_block_device (known after apply)
#     }
#
#   # aws_internet_gateway.my_igw will be created
#   + resource "aws_internet_gateway" "my_igw" {
#       + arn      = (known after apply)
#       + id       = (known after apply)
#       + owner_id = (known after apply)
#       + tags     = {
#           + "Name" = "my-igw"
#         }
#       + tags_all = {
#           + "Name" = "my-igw"
#         }
#       + vpc_id   = (known after apply)
#     }
#
#   # aws_nat_gateway.my_nat will be created
#   + resource "aws_nat_gateway" "my_nat" {
#       + allocation_id                      = "eipalloc-01a7c8f7772f11809"
#       + association_id                     = (known after apply)
#       + connectivity_type                  = "public"
#       + id                                 = (known after apply)
#       + network_interface_id               = (known after apply)
#       + private_ip                         = (known after apply)
#       + public_ip                          = (known after apply)
#       + secondary_private_ip_address_count = (known after apply)
#       + secondary_private_ip_addresses     = (known after apply)
#       + subnet_id                          = (known after apply)
#       + tags                               = {
#           + "Name" = "my-nat"
#         }
#       + tags_all                           = {
#           + "Name" = "my-nat"
#         }
#     }
#
#   # aws_network_acl.my_nacl will be created
#   + resource "aws_network_acl" "my_nacl" {
#       + arn        = (known after apply)
#       + egress     = (known after apply)
#       + id         = (known after apply)
#       + ingress    = (known after apply)
#       + owner_id   = (known after apply)
#       + subnet_ids = (known after apply)
#       + tags       = {
#           + "Name" = "my-nacl"
#         }
#       + tags_all   = {
#           + "Name" = "my-nacl"
#         }
#       + vpc_id     = (known after apply)
#     }
#
#   # aws_network_acl_association.private_1_nacl_assoc will be created
#   + resource "aws_network_acl_association" "private_1_nacl_assoc" {
#       + id             = (known after apply)
#       + network_acl_id = (known after apply)
#       + subnet_id      = (known after apply)
#     }
#
#   # aws_network_acl_association.private_2_nacl_assoc will be created
#   + resource "aws_network_acl_association" "private_2_nacl_assoc" {
#       + id             = (known after apply)
#       + network_acl_id = (known after apply)
#       + subnet_id      = (known after apply)
#     }
#
#   # aws_network_acl_association.public_nacl_assoc will be created
#   + resource "aws_network_acl_association" "public_nacl_assoc" {
#       + id             = (known after apply)
#       + network_acl_id = (known after apply)
#       + subnet_id      = (known after apply)
#     }
#
#   # aws_network_acl_rule.inbound_allow_all will be created
#   + resource "aws_network_acl_rule" "inbound_allow_all" {
#       + cidr_block     = "0.0.0.0/0"
#       + egress         = false
#       + id             = (known after apply)
#       + network_acl_id = (known after apply)
#       + protocol       = "-1"
#       + rule_action    = "allow"
#       + rule_number    = 100
#     }
#
#   # aws_network_acl_rule.outbound_allow_all will be created
#   + resource "aws_network_acl_rule" "outbound_allow_all" {
#       + cidr_block     = "0.0.0.0/0"
#       + egress         = true
#       + id             = (known after apply)
#       + network_acl_id = (known after apply)
#       + protocol       = "-1"
#       + rule_action    = "allow"
#       + rule_number    = 100
#     }
#
#   # aws_route.private_nat will be created
#   + resource "aws_route" "private_nat" {
#       + destination_cidr_block = "0.0.0.0/0"
#       + id                     = (known after apply)
#       + instance_id            = (known after apply)
#       + instance_owner_id      = (known after apply)
#       + nat_gateway_id         = (known after apply)
#       + network_interface_id   = (known after apply)
#       + origin                 = (known after apply)
#       + route_table_id         = (known after apply)
#       + state                  = (known after apply)
#     }
#
#   # aws_route.public_internet will be created
#   + resource "aws_route" "public_internet" {
#       + destination_cidr_block = "0.0.0.0/0"
#       + gateway_id             = (known after apply)
#       + id                     = (known after apply)
#       + instance_id            = (known after apply)
#       + instance_owner_id      = (known after apply)
#       + network_interface_id   = (known after apply)
#       + origin                 = (known after apply)
#       + route_table_id         = (known after apply)
#       + state                  = (known after apply)
#     }
#
#   # aws_route_table.private_rt will be created
#   + resource "aws_route_table" "private_rt" {
#       + arn              = (known after apply)
#       + id               = (known after apply)
#       + owner_id         = (known after apply)
#       + propagating_vgws = (known after apply)
#       + route            = (known after apply)
#       + tags             = {
#           + "Name" = "private-rt"
#         }
#       + tags_all         = {
#           + "Name" = "private-rt"
#         }
#       + vpc_id           = (known after apply)
#     }
#
#   # aws_route_table.public_rt will be created
#   + resource "aws_route_table" "public_rt" {
#       + arn              = (known after apply)
#       + id               = (known after apply)
#       + owner_id         = (known after apply)
#       + propagating_vgws = (known after apply)
#       + route            = (known after apply)
#       + tags             = {
#           + "Name" = "public-rt"
#         }
#       + tags_all         = {
#           + "Name" = "public-rt"
#         }
#       + vpc_id           = (known after apply)
#     }
#
#   # aws_route_table_association.private_assoc_1 will be created
#   + resource "aws_route_table_association" "private_assoc_1" {
#       + id             = (known after apply)
#       + route_table_id = (known after apply)
#       + subnet_id      = (known after apply)
#     }
#
#   # aws_route_table_association.private_assoc_2 will be created
#   + resource "aws_route_table_association" "private_assoc_2" {
#       + id             = (known after apply)
#       + route_table_id = (known after apply)
#       + subnet_id      = (known after apply)
#     }
#
#   # aws_route_table_association.public_assoc will be created
#   + resource "aws_route_table_association" "public_assoc" {
#       + id             = (known after apply)
#       + route_table_id = (known after apply)
#       + subnet_id      = (known after apply)
#     }
#
#   # aws_sagemaker_domain.my_domain will be created
#   + resource "aws_sagemaker_domain" "my_domain" {
#       + app_network_access_type                        = "VpcOnly"
#       + arn                                            = (known after apply)
#       + auth_mode                                      = "IAM"
#       + domain_name                                    = "my-domain"
#       + home_efs_file_system_id                        = (known after apply)
#       + id                                             = (known after apply)
#       + security_group_id_for_domain_boundary          = (known after apply)
#       + single_sign_on_application_arn                 = (known after apply)
#       + single_sign_on_managed_application_instance_id = (known after apply)
#       + subnet_ids                                     = (known after apply)
#       + tag_propagation                                = "DISABLED"
#       + tags_all                                       = (known after apply)
#       + url                                            = (known after apply)
#       + vpc_id                                         = (known after apply)
#
#       + default_space_settings {
#           + execution_role  = "arn:aws:iam::609009159737:role/SageMakerRole"
#           + security_groups = (known after apply)
#
#           + space_storage_settings (known after apply)
#         }
#
#       + default_user_settings {
#           + auto_mount_home_efs = (known after apply)
#           + default_landing_uri = (known after apply)
#           + execution_role      = "arn:aws:iam::609009159737:role/SageMakerRole"
#           + security_groups     = (known after apply)
#           + studio_web_portal   = (known after apply)
#
#           + space_storage_settings (known after apply)
#         }
#     }
#
#   # aws_sagemaker_space.private_space will be created
#   + resource "aws_sagemaker_space" "private_space" {
#       + arn                      = (known after apply)
#       + domain_id                = (known after apply)
#       + home_efs_file_system_uid = (known after apply)
#       + id                       = (known after apply)
#       + space_name               = "private-notebook"
#       + tags_all                 = (known after apply)
#       + url                      = (known after apply)
#
#       + ownership_settings {
#           + owner_user_profile_name = "ai-user"
#         }
#
#       + space_settings {
#           + app_type = "JupyterLab"
#
#           + jupyter_lab_app_settings {
#               + default_resource_spec {
#                   + instance_type = "ml.t3.medium"
#                 }
#             }
#
#           + space_storage_settings (known after apply)
#         }
#
#       + space_sharing_settings {
#           + sharing_type = "Private"
#         }
#     }
#
#   # aws_sagemaker_space.shared_space will be created
#   + resource "aws_sagemaker_space" "shared_space" {
#       + arn                      = (known after apply)
#       + domain_id                = (known after apply)
#       + home_efs_file_system_uid = (known after apply)
#       + id                       = (known after apply)
#       + space_name               = "shared-notebook"
#       + tags_all                 = (known after apply)
#       + url                      = (known after apply)
#
#       + ownership_settings {
#           + owner_user_profile_name = "ai-user"
#         }
#
#       + space_settings {
#           + app_type = "JupyterLab"
#
#           + jupyter_lab_app_settings {
#               + default_resource_spec {
#                   + instance_type = "ml.t3.medium"
#                 }
#             }
#
#           + space_storage_settings (known after apply)
#         }
#
#       + space_sharing_settings {
#           + sharing_type = "Shared"
#         }
#     }
#
#   # aws_sagemaker_user_profile.ai_user will be created
#   + resource "aws_sagemaker_user_profile" "ai_user" {
#       + arn                      = (known after apply)
#       + domain_id                = (known after apply)
#       + home_efs_file_system_uid = (known after apply)
#       + id                       = (known after apply)
#       + tags_all                 = (known after apply)
#       + user_profile_name        = "ai-user"
#
#       + user_settings {
#           + auto_mount_home_efs = (known after apply)
#           + execution_role      = "arn:aws:iam::609009159737:role/SageMakerRole"
#           + security_groups     = (known after apply)
#           + studio_web_portal   = (known after apply)
#
#           + space_storage_settings (known after apply)
#         }
#     }
#
#   # aws_security_group.ec2_sg will be created
#   + resource "aws_security_group" "ec2_sg" {
#       + arn                    = (known after apply)
#       + description            = "For EC2 MongoDB"
#       + egress                 = [
#           + {
#               + cidr_blocks      = [
#                   + "0.0.0.0/0",
#                 ]
#               + from_port        = 0
#               + ipv6_cidr_blocks = []
#               + prefix_list_ids  = []
#               + protocol         = "-1"
#               + security_groups  = []
#               + self             = false
#               + to_port          = 0
#                 # (1 unchanged attribute hidden)
#             },
#         ]
#       + id                     = (known after apply)
#       + ingress                = [
#           + {
#               + cidr_blocks      = []
#               + from_port        = 3307
#               + ipv6_cidr_blocks = []
#               + prefix_list_ids  = []
#               + protocol         = "tcp"
#               + security_groups  = (known after apply)
#               + self             = false
#               + to_port          = 3307
#                 # (1 unchanged attribute hidden)
#             },
#         ]
#       + name                   = "ec2-sg"
#       + name_prefix            = (known after apply)
#       + owner_id               = (known after apply)
#       + revoke_rules_on_delete = false
#       + tags                   = {
#           + "Name" = "ec2-sg"
#         }
#       + tags_all               = {
#           + "Name" = "ec2-sg"
#         }
#       + vpc_id                 = (known after apply)
#     }
#
#   # aws_security_group.sagemaker_sg will be created
#   + resource "aws_security_group" "sagemaker_sg" {
#       + arn                    = (known after apply)
#       + description            = "For SageMaker"
#       + egress                 = [
#           + {
#               + cidr_blocks      = [
#                   + "0.0.0.0/0",
#                 ]
#               + from_port        = 0
#               + ipv6_cidr_blocks = []
#               + prefix_list_ids  = []
#               + protocol         = "-1"
#               + security_groups  = []
#               + self             = false
#               + to_port          = 0
#                 # (1 unchanged attribute hidden)
#             },
#         ]
#       + id                     = (known after apply)
#       + ingress                = (known after apply)
#       + name                   = "sagemaker-sg"
#       + name_prefix            = (known after apply)
#       + owner_id               = (known after apply)
#       + revoke_rules_on_delete = false
#       + tags                   = {
#           + "Name" = "sagemaker-sg"
#         }
#       + tags_all               = {
#           + "Name" = "sagemaker-sg"
#         }
#       + vpc_id                 = (known after apply)
#     }
#
#   # aws_subnet.private_subnet_1 will be created
#   + resource "aws_subnet" "private_subnet_1" {
#       + arn                                            = (known after apply)
#       + assign_ipv6_address_on_creation                = false
#       + availability_zone                              = "us-east-1a"
#       + availability_zone_id                           = (known after apply)
#       + cidr_block                                     = "10.0.1.0/24"
#       + enable_dns64                                   = false
#       + enable_resource_name_dns_a_record_on_launch    = false
#       + enable_resource_name_dns_aaaa_record_on_launch = false
#       + id                                             = (known after apply)
#       + ipv6_cidr_block_association_id                 = (known after apply)
#       + ipv6_native                                    = false
#       + map_public_ip_on_launch                        = false
#       + owner_id                                       = (known after apply)
#       + private_dns_hostname_type_on_launch            = (known after apply)
#       + tags                                           = {
#           + "Name" = "private-subnet-1"
#         }
#       + tags_all                                       = {
#           + "Name" = "private-subnet-1"
#         }
#       + vpc_id                                         = (known after apply)
#     }
#
#   # aws_subnet.private_subnet_2 will be created
#   + resource "aws_subnet" "private_subnet_2" {
#       + arn                                            = (known after apply)
#       + assign_ipv6_address_on_creation                = false
#       + availability_zone                              = "us-east-1b"
#       + availability_zone_id                           = (known after apply)
#       + cidr_block                                     = "10.0.2.0/24"
#       + enable_dns64                                   = false
#       + enable_resource_name_dns_a_record_on_launch    = false
#       + enable_resource_name_dns_aaaa_record_on_launch = false
#       + id                                             = (known after apply)
#       + ipv6_cidr_block_association_id                 = (known after apply)
#       + ipv6_native                                    = false
#       + map_public_ip_on_launch                        = false
#       + owner_id                                       = (known after apply)
#       + private_dns_hostname_type_on_launch            = (known after apply)
#       + tags                                           = {
#           + "Name" = "private-subnet-2"
#         }
#       + tags_all                                       = {
#           + "Name" = "private-subnet-2"
#         }
#       + vpc_id                                         = (known after apply)
#     }
#
#   # aws_subnet.public_subnet will be created
#   + resource "aws_subnet" "public_subnet" {
#       + arn                                            = (known after apply)
#       + assign_ipv6_address_on_creation                = false
#       + availability_zone                              = "us-east-1a"
#       + availability_zone_id                           = (known after apply)
#       + cidr_block                                     = "10.0.0.0/24"
#       + enable_dns64                                   = false
#       + enable_resource_name_dns_a_record_on_launch    = false
#       + enable_resource_name_dns_aaaa_record_on_launch = false
#       + id                                             = (known after apply)
#       + ipv6_cidr_block_association_id                 = (known after apply)
#       + ipv6_native                                    = false
#       + map_public_ip_on_launch                        = false
#       + owner_id                                       = (known after apply)
#       + private_dns_hostname_type_on_launch            = (known after apply)
#       + tags                                           = {
#           + "Name" = "public-subnet"
#         }
#       + tags_all                                       = {
#           + "Name" = "public-subnet"
#         }
#       + vpc_id                                         = (known after apply)
#     }
#
#   # aws_vpc.my_vpc will be created
#   + resource "aws_vpc" "my_vpc" {
#       + arn                                  = (known after apply)
#       + cidr_block                           = "10.0.0.0/16"
#       + default_network_acl_id               = (known after apply)
#       + default_route_table_id               = (known after apply)
#       + default_security_group_id            = (known after apply)
#       + dhcp_options_id                      = (known after apply)
#       + enable_dns_hostnames                 = (known after apply)
#       + enable_dns_support                   = true
#       + enable_network_address_usage_metrics = (known after apply)
#       + id                                   = (known after apply)
#       + instance_tenancy                     = "default"
#       + ipv6_association_id                  = (known after apply)
#       + ipv6_cidr_block                      = (known after apply)
#       + ipv6_cidr_block_network_border_group = (known after apply)
#       + main_route_table_id                  = (known after apply)
#       + owner_id                             = (known after apply)
#       + tags                                 = {
#           + "Name" = "my-vpc"
#         }
#       + tags_all                             = {
#           + "Name" = "my-vpc"
#         }
#     }
#
# Plan: 26 to add, 0 to change, 0 to destroy.
#
# Changes to Outputs:
#   ~ ec2_private_ip      = "10.0.1.12" -> (known after apply)
#   ~ sagemaker_domain_id = "d-jccm2rxiyrfp" -> (known after apply)
#   ~ vpc_id              = "vpc-09d06141d745ce35f" -> (known after apply)
# aws_vpc.my_vpc: Creating...
# aws_vpc.my_vpc: Creation complete after 1s [id=vpc-04483240d8e8c3b9d]
# aws_security_group.sagemaker_sg: Creating...
# aws_subnet.public_subnet: Creating...
# aws_route_table.private_rt: Creating...
# aws_route_table.public_rt: Creating...
# aws_internet_gateway.my_igw: Creating...
# aws_network_acl.my_nacl: Creating...
# aws_subnet.private_subnet_2: Creating...
# aws_subnet.private_subnet_1: Creating...
# aws_network_acl.my_nacl: Creation complete after 0s [id=acl-0b2099f599d343568]
# aws_network_acl_rule.inbound_allow_all: Creating...
# aws_network_acl_rule.outbound_allow_all: Creating...
# aws_route_table.private_rt: Creation complete after 1s [id=rtb-0190f89f8c378883f]
# aws_route_table.public_rt: Creation complete after 1s [id=rtb-0f1a6f4097b3eaad0]
# aws_subnet.private_subnet_2: Creation complete after 1s [id=subnet-0fd992dc10102211f]
# aws_network_acl_association.private_2_nacl_assoc: Creating...
# aws_route_table_association.private_assoc_2: Creating...
# aws_subnet.private_subnet_1: Creation complete after 1s [id=subnet-0a78c9d873ec73fba]
# aws_network_acl_association.private_1_nacl_assoc: Creating...
# aws_route_table_association.private_assoc_1: Creating...
# aws_internet_gateway.my_igw: Creation complete after 1s [id=igw-0dae499dd73d08f41]
# aws_route.public_internet: Creating...
# aws_network_acl_association.private_1_nacl_assoc: Creation complete after 0s [id=aclassoc-0255ec5a06911d102]
# aws_route_table_association.private_assoc_2: Creation complete after 0s [id=rtbassoc-0eab8dc1cf789f54c]
# aws_route_table_association.private_assoc_1: Creation complete after 0s [id=rtbassoc-003134c855e382e52]
# aws_network_acl_rule.inbound_allow_all: Creation complete after 1s [id=nacl-670859304]
# aws_network_acl_rule.outbound_allow_all: Creation complete after 1s [id=nacl-4272685774]
# aws_route.public_internet: Creation complete after 0s [id=r-rtb-0f1a6f4097b3eaad01080289494]
# aws_network_acl_association.private_2_nacl_assoc: Creation complete after 1s [id=aclassoc-0d0e18746460facac]
# aws_security_group.sagemaker_sg: Creation complete after 2s [id=sg-00238749e8d8b4976]
# aws_security_group.ec2_sg: Creating...
# aws_sagemaker_domain.my_domain: Creating...
# aws_security_group.ec2_sg: Creation complete after 1s [id=sg-07a3548da0fdba141]
# aws_instance.my_ec2: Creating...
# aws_subnet.public_subnet: Creation complete after 4s [id=subnet-04b9595f2b3ab0749]
# aws_network_acl_association.public_nacl_assoc: Creating...
# aws_route_table_association.public_assoc: Creating...
# aws_nat_gateway.my_nat: Creating...
# aws_network_acl_association.public_nacl_assoc: Creation complete after 0s [id=aclassoc-09bfb4be4c8fb0e98]
# aws_route_table_association.public_assoc: Creation complete after 0s [id=rtbassoc-0c379d7504e7b7b09]
# aws_sagemaker_domain.my_domain: Still creating... 10s elapsed]
# aws_instance.my_ec2: Still creating... 10s elapsed]
# aws_nat_gateway.my_nat: Still creating... 10s elapsed]
# aws_instance.my_ec2: Creation complete after 13s [id=i-0f763185886519ecf]
# aws_sagemaker_domain.my_domain: Still creating... 20s elapsed]
# aws_nat_gateway.my_nat: Still creating... 20s elapsed]
# aws_sagemaker_domain.my_domain: Still creating... 30s elapsed]
# aws_nat_gateway.my_nat: Still creating... 30s elapsed]
# aws_sagemaker_domain.my_domain: Still creating... 40s elapsed]
# aws_nat_gateway.my_nat: Still creating... 40s elapsed]
# aws_sagemaker_domain.my_domain: Still creating... 50s elapsed]
# aws_nat_gateway.my_nat: Still creating... 50s elapsed]
# aws_sagemaker_domain.my_domain: Still creating... 00s elapsed]
# aws_nat_gateway.my_nat: Still creating... 00s elapsed]
# aws_sagemaker_domain.my_domain: Still creating... 10s elapsed]
# aws_nat_gateway.my_nat: Still creating... 10s elapsed]
# aws_sagemaker_domain.my_domain: Still creating... 20s elapsed]
# aws_nat_gateway.my_nat: Still creating... 20s elapsed]
# aws_sagemaker_domain.my_domain: Still creating... 30s elapsed]
# aws_nat_gateway.my_nat: Still creating... 30s elapsed]
# aws_sagemaker_domain.my_domain: Still creating... 40s elapsed]
# aws_nat_gateway.my_nat: Still creating... 40s elapsed]
# aws_nat_gateway.my_nat: Creation complete after 1m43s [id=nat-0bab8a7fbfbda5399]
# aws_route.private_nat: Creating...
# aws_sagemaker_domain.my_domain: Still creating... 50s elapsed]
# aws_sagemaker_domain.my_domain: Creation complete after 1m53s [id=d-jkvexsgascai]
# aws_sagemaker_user_profile.ai_user: Creating...
# aws_route.private_nat: Still creating... 10s elapsed]
# aws_sagemaker_user_profile.ai_user: Creation complete after 7s [id=arn:aws:sagemaker:us-east-1:609009159737:user-profile/d-jkvexsgascai/ai-user]
# aws_sagemaker_space.private_space: Creating...
# aws_sagemaker_space.shared_space: Creating...
# aws_route.private_nat: Still creating... 20s elapsed]
# aws_sagemaker_space.private_space: Creation complete after 6s [id=arn:aws:sagemaker:us-east-1:609009159737:space/d-jkvexsgascai/private-notebook]
# aws_sagemaker_space.shared_space: Still creating... 10s elapsed]
# aws_route.private_nat: Still creating... 30s elapsed]
# aws_sagemaker_space.shared_space: Creation complete after 17s [id=arn:aws:sagemaker:us-east-1:609009159737:space/d-jkvexsgascai/shared-notebook]
# aws_route.private_nat: Creation complete after 34s [id=r-rtb-0190f89f8c378883f1080289494]
#
# Apply complete! Resources: 26 added, 0 changed, 0 destroyed.
#
# Outputs:
#
# ec2_private_ip = "10.0.1.52"
# mongodb_port = 3307
# private_space_name = "private-notebook"
# sagemaker_domain_id = "d-jkvexsgascai"
# shared_space_name = "shared-notebook"
# user_profile_name = "ai-user"
# vpc_id = "vpc-04483240d8e8c3b9d"

# %%
#optional
# !terraform plan --destroy
# Out:
# aws_eip.nat_eip: Refreshing state... [id=eipalloc-01a7c8f7772f11809]
# data.aws_ami.amazon_linux: Reading...
# aws_iam_role.sagemaker_role: Refreshing state... [id=SageMakerRole]
# aws_vpc.my_vpc: Refreshing state... [id=vpc-04483240d8e8c3b9d]
# aws_iam_role.ec2_ssm_role: Refreshing state... [id=EC2SSMRole]
# aws_iam_role_policy_attachment.sagemaker_full_access: Refreshing state... [id=SageMakerRole-20250825230712552900000001]
# aws_iam_role_policy_attachment.ec2_ssm_access: Refreshing state... [id=EC2SSMRole-20250825230712598600000002]
# aws_iam_instance_profile.ec2_ssm_profile: Refreshing state... [id=EC2SSMProfile]
# aws_subnet.private_subnet_1: Refreshing state... [id=subnet-0a78c9d873ec73fba]
# aws_subnet.private_subnet_2: Refreshing state... [id=subnet-0fd992dc10102211f]
# aws_route_table.private_rt: Refreshing state... [id=rtb-0190f89f8c378883f]
# aws_internet_gateway.my_igw: Refreshing state... [id=igw-0dae499dd73d08f41]
# aws_security_group.sagemaker_sg: Refreshing state... [id=sg-00238749e8d8b4976]
# aws_subnet.public_subnet: Refreshing state... [id=subnet-04b9595f2b3ab0749]
# aws_route_table.public_rt: Refreshing state... [id=rtb-0f1a6f4097b3eaad0]
# aws_network_acl.my_nacl: Refreshing state... [id=acl-0b2099f599d343568]
# aws_network_acl_rule.inbound_allow_all: Refreshing state... [id=nacl-670859304]
# aws_network_acl_rule.outbound_allow_all: Refreshing state... [id=nacl-4272685774]
# aws_network_acl_association.private_1_nacl_assoc: Refreshing state... [id=aclassoc-0255ec5a06911d102]
# aws_route_table_association.private_assoc_1: Refreshing state... [id=rtbassoc-003134c855e382e52]
# aws_route_table_association.private_assoc_2: Refreshing state... [id=rtbassoc-0eab8dc1cf789f54c]
# aws_network_acl_association.private_2_nacl_assoc: Refreshing state... [id=aclassoc-0d0e18746460facac]
# aws_route.public_internet: Refreshing state... [id=r-rtb-0f1a6f4097b3eaad01080289494]
# aws_security_group.ec2_sg: Refreshing state... [id=sg-07a3548da0fdba141]
# aws_sagemaker_domain.my_domain: Refreshing state... [id=d-jkvexsgascai]
# aws_nat_gateway.my_nat: Refreshing state... [id=nat-0bab8a7fbfbda5399]
# aws_route_table_association.public_assoc: Refreshing state... [id=rtbassoc-0c379d7504e7b7b09]
# aws_network_acl_association.public_nacl_assoc: Refreshing state... [id=aclassoc-09bfb4be4c8fb0e98]
# data.aws_ami.amazon_linux: Read complete after 1s [id=ami-0309908417d7ea2d0]
# aws_instance.my_ec2: Refreshing state... [id=i-0f763185886519ecf]
# aws_route.private_nat: Refreshing state... [id=r-rtb-0190f89f8c378883f1080289494]
# aws_sagemaker_user_profile.ai_user: Refreshing state... [id=arn:aws:sagemaker:us-east-1:609009159737:user-profile/d-jkvexsgascai/ai-user]
# aws_sagemaker_space.private_space: Refreshing state... [id=arn:aws:sagemaker:us-east-1:609009159737:space/d-jkvexsgascai/private-notebook]
# aws_sagemaker_space.shared_space: Refreshing state... [id=arn:aws:sagemaker:us-east-1:609009159737:space/d-jkvexsgascai/shared-notebook]
#
# Terraform used the selected providers to generate the following execution plan.
# Resource actions are indicated with the following symbols:
#   - destroy
#
# Terraform will perform the following actions:
#
#   # aws_eip.nat_eip will be destroyed
#   - resource "aws_eip" "nat_eip" {
#       - allocation_id            = "eipalloc-01a7c8f7772f11809" -> null
#       - arn                      = "arn:aws:ec2:us-east-1:609009159737:elastic-ip/eipalloc-01a7c8f7772f11809" -> null
#       - association_id           = "eipassoc-0fb0b274acc7b258e" -> null
#       - domain                   = "vpc" -> null
#       - id                       = "eipalloc-01a7c8f7772f11809" -> null
#       - network_border_group     = "us-east-1" -> null
#       - network_interface        = "eni-0e91c943450d14a47" -> null
#       - private_dns              = "ip-10-0-0-89.ec2.internal" -> null
#       - private_ip               = "10.0.0.89" -> null
#       - public_dns               = "ec2-44-193-132-177.compute-1.amazonaws.com" -> null
#       - public_ip                = "44.193.132.177" -> null
#       - public_ipv4_pool         = "amazon" -> null
#       - tags                     = {} -> null
#       - tags_all                 = {} -> null
#       - vpc                      = true -> null
#         # (5 unchanged attributes hidden)
#     }
#
#   # aws_iam_instance_profile.ec2_ssm_profile will be destroyed
#   - resource "aws_iam_instance_profile" "ec2_ssm_profile" {
#       - arn         = "arn:aws:iam::609009159737:instance-profile/EC2SSMProfile" -> null
#       - create_date = "2025-08-25T23:07:12Z" -> null
#       - id          = "EC2SSMProfile" -> null
#       - name        = "EC2SSMProfile" -> null
#       - path        = "/" -> null
#       - role        = "EC2SSMRole" -> null
#       - tags        = {} -> null
#       - tags_all    = {} -> null
#       - unique_id   = "AIPAY3S6GJY4Z3OMT5B3L" -> null
#         # (1 unchanged attribute hidden)
#     }
#
#   # aws_iam_role.ec2_ssm_role will be destroyed
#   - resource "aws_iam_role" "ec2_ssm_role" {
#       - arn                   = "arn:aws:iam::609009159737:role/EC2SSMRole" -> null
#       - assume_role_policy    = jsonencode(
#             {
#               - Statement = [
#                   - {
#                       - Action    = "sts:AssumeRole"
#                       - Effect    = "Allow"
#                       - Principal = {
#                           - Service = "ec2.amazonaws.com"
#                         }
#                     },
#                 ]
#               - Version   = "2012-10-17"
#             }
#         ) -> null
#       - create_date           = "2025-08-25T23:07:12Z" -> null
#       - force_detach_policies = false -> null
#       - id                    = "EC2SSMRole" -> null
#       - managed_policy_arns   = [
#           - "arn:aws:iam::aws:policy/AmazonSSMManagedInstanceCore",
#         ] -> null
#       - max_session_duration  = 3600 -> null
#       - name                  = "EC2SSMRole" -> null
#       - path                  = "/" -> null
#       - tags                  = {} -> null
#       - tags_all              = {} -> null
#       - unique_id             = "AROAY3S6GJY4UXSERF2FW" -> null
#         # (3 unchanged attributes hidden)
#     }
#
#   # aws_iam_role.sagemaker_role will be destroyed
#   - resource "aws_iam_role" "sagemaker_role" {
#       - arn                   = "arn:aws:iam::609009159737:role/SageMakerRole" -> null
#       - assume_role_policy    = jsonencode(
#             {
#               - Statement = [
#                   - {
#                       - Action    = "sts:AssumeRole"
#                       - Effect    = "Allow"
#                       - Principal = {
#                           - Service = "sagemaker.amazonaws.com"
#                         }
#                     },
#                 ]
#               - Version   = "2012-10-17"
#             }
#         ) -> null
#       - create_date           = "2025-08-25T23:07:12Z" -> null
#       - force_detach_policies = false -> null
#       - id                    = "SageMakerRole" -> null
#       - managed_policy_arns   = [
#           - "arn:aws:iam::aws:policy/AmazonSageMakerFullAccess",
#         ] -> null
#       - max_session_duration  = 3600 -> null
#       - name                  = "SageMakerRole" -> null
#       - path                  = "/" -> null
#       - tags                  = {} -> null
#       - tags_all              = {} -> null
#       - unique_id             = "AROAY3S6GJY4TEOLB5OLW" -> null
#         # (3 unchanged attributes hidden)
#     }
#
#   # aws_iam_role_policy_attachment.ec2_ssm_access will be destroyed
#   - resource "aws_iam_role_policy_attachment" "ec2_ssm_access" {
#       - id         = "EC2SSMRole-20250825230712598600000002" -> null
#       - policy_arn = "arn:aws:iam::aws:policy/AmazonSSMManagedInstanceCore" -> null
#       - role       = "EC2SSMRole" -> null
#     }
#
#   # aws_iam_role_policy_attachment.sagemaker_full_access will be destroyed
#   - resource "aws_iam_role_policy_attachment" "sagemaker_full_access" {
#       - id         = "SageMakerRole-20250825230712552900000001" -> null
#       - policy_arn = "arn:aws:iam::aws:policy/AmazonSageMakerFullAccess" -> null
#       - role       = "SageMakerRole" -> null
#     }
#
#   # aws_instance.my_ec2 will be destroyed
#   - resource "aws_instance" "my_ec2" {
#       - ami                                  = "ami-0309908417d7ea2d0" -> null
#       - arn                                  = "arn:aws:ec2:us-east-1:609009159737:instance/i-0f763185886519ecf" -> null
#       - associate_public_ip_address          = false -> null
#       - availability_zone                    = "us-east-1a" -> null
#       - cpu_core_count                       = 1 -> null
#       - cpu_threads_per_core                 = 1 -> null
#       - disable_api_stop                     = false -> null
#       - disable_api_termination              = false -> null
#       - ebs_optimized                        = false -> null
#       - get_password_data                    = false -> null
#       - hibernation                          = false -> null
#       - iam_instance_profile                 = "EC2SSMProfile" -> null
#       - id                                   = "i-0f763185886519ecf" -> null
#       - instance_initiated_shutdown_behavior = "stop" -> null
#       - instance_state                       = "running" -> null
#       - instance_type                        = "t2.micro" -> null
#       - ipv6_address_count                   = 0 -> null
#       - ipv6_addresses                       = [] -> null
#       - monitoring                           = false -> null
#       - placement_partition_number           = 0 -> null
#       - primary_network_interface_id         = "eni-059273ae3c47ba2d7" -> null
#       - private_dns                          = "ip-10-0-1-52.ec2.internal" -> null
#       - private_ip                           = "10.0.1.52" -> null
#       - secondary_private_ips                = [] -> null
#       - security_groups                      = [] -> null
#       - source_dest_check                    = true -> null
#       - subnet_id                            = "subnet-0a78c9d873ec73fba" -> null
#       - tags                                 = {
#           - "Name" = "my-ec2"
#         } -> null
#       - tags_all                             = {
#           - "Name" = "my-ec2"
#         } -> null
#       - tenancy                              = "default" -> null
#       - user_data                            = "4eccd0c8fd4ebe33b7e3f557709750a2c7ff18e9" -> null
#       - user_data_replace_on_change          = false -> null
#       - vpc_security_group_ids               = [
#           - "sg-07a3548da0fdba141",
#         ] -> null
#         # (9 unchanged attributes hidden)
#
#       - capacity_reservation_specification {
#           - capacity_reservation_preference = "open" -> null
#         }
#
#       - cpu_options {
#           - core_count       = 1 -> null
#           - threads_per_core = 1 -> null
#             # (1 unchanged attribute hidden)
#         }
#
#       - credit_specification {
#           - cpu_credits = "standard" -> null
#         }
#
#       - enclave_options {
#           - enabled = false -> null
#         }
#
#       - maintenance_options {
#           - auto_recovery = "default" -> null
#         }
#
#       - metadata_options {
#           - http_endpoint               = "enabled" -> null
#           - http_protocol_ipv6          = "disabled" -> null
#           - http_put_response_hop_limit = 2 -> null
#           - http_tokens                 = "required" -> null
#           - instance_metadata_tags      = "disabled" -> null
#         }
#
#       - private_dns_name_options {
#           - enable_resource_name_dns_a_record    = false -> null
#           - enable_resource_name_dns_aaaa_record = false -> null
#           - hostname_type                        = "ip-name" -> null
#         }
#
#       - root_block_device {
#           - delete_on_termination = true -> null
#           - device_name           = "/dev/xvda" -> null
#           - encrypted             = false -> null
#           - iops                  = 3000 -> null
#           - tags                  = {} -> null
#           - tags_all              = {} -> null
#           - throughput            = 125 -> null
#           - volume_id             = "vol-0876072fa981fe10a" -> null
#           - volume_size           = 8 -> null
#           - volume_type           = "gp3" -> null
#             # (1 unchanged attribute hidden)
#         }
#     }
#
#   # aws_internet_gateway.my_igw will be destroyed
#   - resource "aws_internet_gateway" "my_igw" {
#       - arn      = "arn:aws:ec2:us-east-1:609009159737:internet-gateway/igw-0dae499dd73d08f41" -> null
#       - id       = "igw-0dae499dd73d08f41" -> null
#       - owner_id = "609009159737" -> null
#       - tags     = {
#           - "Name" = "my-igw"
#         } -> null
#       - tags_all = {
#           - "Name" = "my-igw"
#         } -> null
#       - vpc_id   = "vpc-04483240d8e8c3b9d" -> null
#     }
#
#   # aws_nat_gateway.my_nat will be destroyed
#   - resource "aws_nat_gateway" "my_nat" {
#       - allocation_id                      = "eipalloc-01a7c8f7772f11809" -> null
#       - association_id                     = "eipassoc-0fb0b274acc7b258e" -> null
#       - connectivity_type                  = "public" -> null
#       - id                                 = "nat-0bab8a7fbfbda5399" -> null
#       - network_interface_id               = "eni-0e91c943450d14a47" -> null
#       - private_ip                         = "10.0.0.89" -> null
#       - public_ip                          = "44.193.132.177" -> null
#       - secondary_allocation_ids           = [] -> null
#       - secondary_private_ip_address_count = 0 -> null
#       - secondary_private_ip_addresses     = [] -> null
#       - subnet_id                          = "subnet-04b9595f2b3ab0749" -> null
#       - tags                               = {
#           - "Name" = "my-nat"
#         } -> null
#       - tags_all                           = {
#           - "Name" = "my-nat"
#         } -> null
#     }
#
#   # aws_network_acl.my_nacl will be destroyed
#   - resource "aws_network_acl" "my_nacl" {
#       - arn        = "arn:aws:ec2:us-east-1:609009159737:network-acl/acl-0b2099f599d343568" -> null
#       - egress     = [
#           - {
#               - action          = "allow"
#               - cidr_block      = "0.0.0.0/0"
#               - from_port       = 0
#               - icmp_code       = 0
#               - icmp_type       = 0
#               - protocol        = "-1"
#               - rule_no         = 100
#               - to_port         = 0
#                 # (1 unchanged attribute hidden)
#             },
#         ] -> null
#       - id         = "acl-0b2099f599d343568" -> null
#       - ingress    = [
#           - {
#               - action          = "allow"
#               - cidr_block      = "0.0.0.0/0"
#               - from_port       = 0
#               - icmp_code       = 0
#               - icmp_type       = 0
#               - protocol        = "-1"
#               - rule_no         = 100
#               - to_port         = 0
#                 # (1 unchanged attribute hidden)
#             },
#         ] -> null
#       - owner_id   = "609009159737" -> null
#       - subnet_ids = [
#           - "subnet-04b9595f2b3ab0749",
#           - "subnet-0a78c9d873ec73fba",
#           - "subnet-0fd992dc10102211f",
#         ] -> null
#       - tags       = {
#           - "Name" = "my-nacl"
#         } -> null
#       - tags_all   = {
#           - "Name" = "my-nacl"
#         } -> null
#       - vpc_id     = "vpc-04483240d8e8c3b9d" -> null
#     }
#
#   # aws_network_acl_association.private_1_nacl_assoc will be destroyed
#   - resource "aws_network_acl_association" "private_1_nacl_assoc" {
#       - id             = "aclassoc-0255ec5a06911d102" -> null
#       - network_acl_id = "acl-0b2099f599d343568" -> null
#       - subnet_id      = "subnet-0a78c9d873ec73fba" -> null
#     }
#
#   # aws_network_acl_association.private_2_nacl_assoc will be destroyed
#   - resource "aws_network_acl_association" "private_2_nacl_assoc" {
#       - id             = "aclassoc-0d0e18746460facac" -> null
#       - network_acl_id = "acl-0b2099f599d343568" -> null
#       - subnet_id      = "subnet-0fd992dc10102211f" -> null
#     }
#
#   # aws_network_acl_association.public_nacl_assoc will be destroyed
#   - resource "aws_network_acl_association" "public_nacl_assoc" {
#       - id             = "aclassoc-09bfb4be4c8fb0e98" -> null
#       - network_acl_id = "acl-0b2099f599d343568" -> null
#       - subnet_id      = "subnet-04b9595f2b3ab0749" -> null
#     }
#
#   # aws_network_acl_rule.inbound_allow_all will be destroyed
#   - resource "aws_network_acl_rule" "inbound_allow_all" {
#       - cidr_block      = "0.0.0.0/0" -> null
#       - egress          = false -> null
#       - id              = "nacl-670859304" -> null
#       - network_acl_id  = "acl-0b2099f599d343568" -> null
#       - protocol        = "-1" -> null
#       - rule_action     = "allow" -> null
#       - rule_number     = 100 -> null
#         # (1 unchanged attribute hidden)
#     }
#
#   # aws_network_acl_rule.outbound_allow_all will be destroyed
#   - resource "aws_network_acl_rule" "outbound_allow_all" {
#       - cidr_block      = "0.0.0.0/0" -> null
#       - egress          = true -> null
#       - id              = "nacl-4272685774" -> null
#       - network_acl_id  = "acl-0b2099f599d343568" -> null
#       - protocol        = "-1" -> null
#       - rule_action     = "allow" -> null
#       - rule_number     = 100 -> null
#         # (1 unchanged attribute hidden)
#     }
#
#   # aws_route.private_nat will be destroyed
#   - resource "aws_route" "private_nat" {
#       - destination_cidr_block      = "0.0.0.0/0" -> null
#       - id                          = "r-rtb-0190f89f8c378883f1080289494" -> null
#       - nat_gateway_id              = "nat-0bab8a7fbfbda5399" -> null
#       - origin                      = "CreateRoute" -> null
#       - route_table_id              = "rtb-0190f89f8c378883f" -> null
#       - state                       = "active" -> null
#         # (13 unchanged attributes hidden)
#     }
#
#   # aws_route.public_internet will be destroyed
#   - resource "aws_route" "public_internet" {
#       - destination_cidr_block      = "0.0.0.0/0" -> null
#       - gateway_id                  = "igw-0dae499dd73d08f41" -> null
#       - id                          = "r-rtb-0f1a6f4097b3eaad01080289494" -> null
#       - origin                      = "CreateRoute" -> null
#       - route_table_id              = "rtb-0f1a6f4097b3eaad0" -> null
#       - state                       = "active" -> null
#         # (13 unchanged attributes hidden)
#     }
#
#   # aws_route_table.private_rt will be destroyed
#   - resource "aws_route_table" "private_rt" {
#       - arn              = "arn:aws:ec2:us-east-1:609009159737:route-table/rtb-0190f89f8c378883f" -> null
#       - id               = "rtb-0190f89f8c378883f" -> null
#       - owner_id         = "609009159737" -> null
#       - propagating_vgws = [] -> null
#       - route            = [
#           - {
#               - cidr_block                 = "0.0.0.0/0"
#               - nat_gateway_id             = "nat-0bab8a7fbfbda5399"
#                 # (11 unchanged attributes hidden)
#             },
#         ] -> null
#       - tags             = {
#           - "Name" = "private-rt"
#         } -> null
#       - tags_all         = {
#           - "Name" = "private-rt"
#         } -> null
#       - vpc_id           = "vpc-04483240d8e8c3b9d" -> null
#     }
#
#   # aws_route_table.public_rt will be destroyed
#   - resource "aws_route_table" "public_rt" {
#       - arn              = "arn:aws:ec2:us-east-1:609009159737:route-table/rtb-0f1a6f4097b3eaad0" -> null
#       - id               = "rtb-0f1a6f4097b3eaad0" -> null
#       - owner_id         = "609009159737" -> null
#       - propagating_vgws = [] -> null
#       - route            = [
#           - {
#               - cidr_block                 = "0.0.0.0/0"
#               - gateway_id                 = "igw-0dae499dd73d08f41"
#                 # (11 unchanged attributes hidden)
#             },
#         ] -> null
#       - tags             = {
#           - "Name" = "public-rt"
#         } -> null
#       - tags_all         = {
#           - "Name" = "public-rt"
#         } -> null
#       - vpc_id           = "vpc-04483240d8e8c3b9d" -> null
#     }
#
#   # aws_route_table_association.private_assoc_1 will be destroyed
#   - resource "aws_route_table_association" "private_assoc_1" {
#       - id             = "rtbassoc-003134c855e382e52" -> null
#       - route_table_id = "rtb-0190f89f8c378883f" -> null
#       - subnet_id      = "subnet-0a78c9d873ec73fba" -> null
#         # (1 unchanged attribute hidden)
#     }
#
#   # aws_route_table_association.private_assoc_2 will be destroyed
#   - resource "aws_route_table_association" "private_assoc_2" {
#       - id             = "rtbassoc-0eab8dc1cf789f54c" -> null
#       - route_table_id = "rtb-0190f89f8c378883f" -> null
#       - subnet_id      = "subnet-0fd992dc10102211f" -> null
#         # (1 unchanged attribute hidden)
#     }
#
#   # aws_route_table_association.public_assoc will be destroyed
#   - resource "aws_route_table_association" "public_assoc" {
#       - id             = "rtbassoc-0c379d7504e7b7b09" -> null
#       - route_table_id = "rtb-0f1a6f4097b3eaad0" -> null
#       - subnet_id      = "subnet-04b9595f2b3ab0749" -> null
#         # (1 unchanged attribute hidden)
#     }
#
#   # aws_sagemaker_domain.my_domain will be destroyed
#   - resource "aws_sagemaker_domain" "my_domain" {
#       - app_network_access_type                        = "VpcOnly" -> null
#       - arn                                            = "arn:aws:sagemaker:us-east-1:609009159737:domain/d-jkvexsgascai" -> null
#       - auth_mode                                      = "IAM" -> null
#       - domain_name                                    = "my-domain" -> null
#       - home_efs_file_system_id                        = "fs-0ef2c9735b0597a8a" -> null
#       - id                                             = "d-jkvexsgascai" -> null
#       - subnet_ids                                     = [
#           - "subnet-0a78c9d873ec73fba",
#           - "subnet-0fd992dc10102211f",
#         ] -> null
#       - tag_propagation                                = "DISABLED" -> null
#       - tags                                           = {} -> null
#       - tags_all                                       = {} -> null
#       - url                                            = "https://d-jkvexsgascai.studio.us-east-1.sagemaker.aws" -> null
#       - vpc_id                                         = "vpc-04483240d8e8c3b9d" -> null
#         # (5 unchanged attributes hidden)
#
#       - default_space_settings {
#           - execution_role  = "arn:aws:iam::609009159737:role/SageMakerRole" -> null
#           - security_groups = [
#               - "sg-00238749e8d8b4976",
#             ] -> null
#         }
#
#       - default_user_settings {
#           - auto_mount_home_efs = "Enabled" -> null
#           - default_landing_uri = "studio::" -> null
#           - execution_role      = "arn:aws:iam::609009159737:role/SageMakerRole" -> null
#           - security_groups     = [
#               - "sg-00238749e8d8b4976",
#             ] -> null
#           - studio_web_portal   = "ENABLED" -> null
#         }
#     }
#
#   # aws_sagemaker_space.private_space will be destroyed
#   - resource "aws_sagemaker_space" "private_space" {
#       - arn                      = "arn:aws:sagemaker:us-east-1:609009159737:space/d-jkvexsgascai/private-notebook" -> null
#       - domain_id                = "d-jkvexsgascai" -> null
#       - id                       = "arn:aws:sagemaker:us-east-1:609009159737:space/d-jkvexsgascai/private-notebook" -> null
#       - space_name               = "private-notebook" -> null
#       - tags                     = {} -> null
#       - tags_all                 = {} -> null
#       - url                      = "https://f3yshxchnnpjpor.studio.us-east-1.sagemaker.aws/jupyterlab/default" -> null
#         # (2 unchanged attributes hidden)
#
#       - ownership_settings {
#           - owner_user_profile_name = "ai-user" -> null
#         }
#
#       - space_settings {
#           - app_type = "JupyterLab" -> null
#
#           - jupyter_lab_app_settings {
#               - default_resource_spec {
#                   - instance_type                 = "ml.t3.medium" -> null
#                     # (4 unchanged attributes hidden)
#                 }
#             }
#
#           - space_storage_settings {
#               - ebs_storage_settings {
#                   - ebs_volume_size_in_gb = 5 -> null
#                 }
#             }
#         }
#
#       - space_sharing_settings {
#           - sharing_type = "Private" -> null
#         }
#     }
#
#   # aws_sagemaker_space.shared_space will be destroyed
#   - resource "aws_sagemaker_space" "shared_space" {
#       - arn                      = "arn:aws:sagemaker:us-east-1:609009159737:space/d-jkvexsgascai/shared-notebook" -> null
#       - domain_id                = "d-jkvexsgascai" -> null
#       - id                       = "arn:aws:sagemaker:us-east-1:609009159737:space/d-jkvexsgascai/shared-notebook" -> null
#       - space_name               = "shared-notebook" -> null
#       - tags                     = {} -> null
#       - tags_all                 = {} -> null
#       - url                      = "https://yze6txriix05kye.studio.us-east-1.sagemaker.aws/jupyterlab/default" -> null
#         # (2 unchanged attributes hidden)
#
#       - ownership_settings {
#           - owner_user_profile_name = "ai-user" -> null
#         }
#
#       - space_settings {
#           - app_type = "JupyterLab" -> null
#
#           - jupyter_lab_app_settings {
#               - default_resource_spec {
#                   - instance_type                 = "ml.t3.medium" -> null
#                   - sagemaker_image_arn           = "arn:aws:sagemaker:us-east-1:885854791233:image/sagemaker-distribution-cpu" -> null
#                   - sagemaker_image_version_alias = "3.4.2" -> null
#                     # (2 unchanged attributes hidden)
#                 }
#             }
#
#           - space_storage_settings {
#               - ebs_storage_settings {
#                   - ebs_volume_size_in_gb = 5 -> null
#                 }
#             }
#         }
#
#       - space_sharing_settings {
#           - sharing_type = "Shared" -> null
#         }
#     }
#
#   # aws_sagemaker_user_profile.ai_user will be destroyed
#   - resource "aws_sagemaker_user_profile" "ai_user" {
#       - arn                            = "arn:aws:sagemaker:us-east-1:609009159737:user-profile/d-jkvexsgascai/ai-user" -> null
#       - domain_id                      = "d-jkvexsgascai" -> null
#       - home_efs_file_system_uid       = "200005" -> null
#       - id                             = "arn:aws:sagemaker:us-east-1:609009159737:user-profile/d-jkvexsgascai/ai-user" -> null
#       - tags                           = {} -> null
#       - tags_all                       = {} -> null
#       - user_profile_name              = "ai-user" -> null
#         # (2 unchanged attributes hidden)
#
#       - user_settings {
#           - auto_mount_home_efs = "DefaultAsDomain" -> null
#           - execution_role      = "arn:aws:iam::609009159737:role/SageMakerRole" -> null
#           - security_groups     = [
#               - "sg-00238749e8d8b4976",
#             ] -> null
#             # (2 unchanged attributes hidden)
#         }
#     }
#
#   # aws_security_group.ec2_sg will be destroyed
#   - resource "aws_security_group" "ec2_sg" {
#       - arn                    = "arn:aws:ec2:us-east-1:609009159737:security-group/sg-07a3548da0fdba141" -> null
#       - description            = "For EC2 MongoDB" -> null
#       - egress                 = [
#           - {
#               - cidr_blocks      = [
#                   - "0.0.0.0/0",
#                 ]
#               - from_port        = 0
#               - ipv6_cidr_blocks = []
#               - prefix_list_ids  = []
#               - protocol         = "-1"
#               - security_groups  = []
#               - self             = false
#               - to_port          = 0
#                 # (1 unchanged attribute hidden)
#             },
#         ] -> null
#       - id                     = "sg-07a3548da0fdba141" -> null
#       - ingress                = [
#           - {
#               - cidr_blocks      = []
#               - from_port        = 3307
#               - ipv6_cidr_blocks = []
#               - prefix_list_ids  = []
#               - protocol         = "tcp"
#               - security_groups  = [
#                   - "sg-00238749e8d8b4976",
#                 ]
#               - self             = false
#               - to_port          = 3307
#                 # (1 unchanged attribute hidden)
#             },
#         ] -> null
#       - name                   = "ec2-sg" -> null
#       - owner_id               = "609009159737" -> null
#       - revoke_rules_on_delete = false -> null
#       - tags                   = {
#           - "Name" = "ec2-sg"
#         } -> null
#       - tags_all               = {
#           - "Name" = "ec2-sg"
#         } -> null
#       - vpc_id                 = "vpc-04483240d8e8c3b9d" -> null
#         # (1 unchanged attribute hidden)
#     }
#
#   # aws_security_group.sagemaker_sg will be destroyed
#   - resource "aws_security_group" "sagemaker_sg" {
#       - arn                    = "arn:aws:ec2:us-east-1:609009159737:security-group/sg-00238749e8d8b4976" -> null
#       - description            = "For SageMaker" -> null
#       - egress                 = [
#           - {
#               - cidr_blocks      = [
#                   - "0.0.0.0/0",
#                 ]
#               - from_port        = 0
#               - ipv6_cidr_blocks = []
#               - prefix_list_ids  = []
#               - protocol         = "-1"
#               - security_groups  = []
#               - self             = false
#               - to_port          = 0
#                 # (1 unchanged attribute hidden)
#             },
#         ] -> null
#       - id                     = "sg-00238749e8d8b4976" -> null
#       - ingress                = [] -> null
#       - name                   = "sagemaker-sg" -> null
#       - owner_id               = "609009159737" -> null
#       - revoke_rules_on_delete = false -> null
#       - tags                   = {
#           - "Name" = "sagemaker-sg"
#         } -> null
#       - tags_all               = {
#           - "Name" = "sagemaker-sg"
#         } -> null
#       - vpc_id                 = "vpc-04483240d8e8c3b9d" -> null
#         # (1 unchanged attribute hidden)
#     }
#
#   # aws_subnet.private_subnet_1 will be destroyed
#   - resource "aws_subnet" "private_subnet_1" {
#       - arn                                            = "arn:aws:ec2:us-east-1:609009159737:subnet/subnet-0a78c9d873ec73fba" -> null
#       - assign_ipv6_address_on_creation                = false -> null
#       - availability_zone                              = "us-east-1a" -> null
#       - availability_zone_id                           = "use1-az4" -> null
#       - cidr_block                                     = "10.0.1.0/24" -> null
#       - enable_dns64                                   = false -> null
#       - enable_lni_at_device_index                     = 0 -> null
#       - enable_resource_name_dns_a_record_on_launch    = false -> null
#       - enable_resource_name_dns_aaaa_record_on_launch = false -> null
#       - id                                             = "subnet-0a78c9d873ec73fba" -> null
#       - ipv6_native                                    = false -> null
#       - map_customer_owned_ip_on_launch                = false -> null
#       - map_public_ip_on_launch                        = false -> null
#       - owner_id                                       = "609009159737" -> null
#       - private_dns_hostname_type_on_launch            = "ip-name" -> null
#       - tags                                           = {
#           - "Name" = "private-subnet-1"
#         } -> null
#       - tags_all                                       = {
#           - "Name" = "private-subnet-1"
#         } -> null
#       - vpc_id                                         = "vpc-04483240d8e8c3b9d" -> null
#         # (4 unchanged attributes hidden)
#     }
#
#   # aws_subnet.private_subnet_2 will be destroyed
#   - resource "aws_subnet" "private_subnet_2" {
#       - arn                                            = "arn:aws:ec2:us-east-1:609009159737:subnet/subnet-0fd992dc10102211f" -> null
#       - assign_ipv6_address_on_creation                = false -> null
#       - availability_zone                              = "us-east-1b" -> null
#       - availability_zone_id                           = "use1-az6" -> null
#       - cidr_block                                     = "10.0.2.0/24" -> null
#       - enable_dns64                                   = false -> null
#       - enable_lni_at_device_index                     = 0 -> null
#       - enable_resource_name_dns_a_record_on_launch    = false -> null
#       - enable_resource_name_dns_aaaa_record_on_launch = false -> null
#       - id                                             = "subnet-0fd992dc10102211f" -> null
#       - ipv6_native                                    = false -> null
#       - map_customer_owned_ip_on_launch                = false -> null
#       - map_public_ip_on_launch                        = false -> null
#       - owner_id                                       = "609009159737" -> null
#       - private_dns_hostname_type_on_launch            = "ip-name" -> null
#       - tags                                           = {
#           - "Name" = "private-subnet-2"
#         } -> null
#       - tags_all                                       = {
#           - "Name" = "private-subnet-2"
#         } -> null
#       - vpc_id                                         = "vpc-04483240d8e8c3b9d" -> null
#         # (4 unchanged attributes hidden)
#     }
#
#   # aws_subnet.public_subnet will be destroyed
#   - resource "aws_subnet" "public_subnet" {
#       - arn                                            = "arn:aws:ec2:us-east-1:609009159737:subnet/subnet-04b9595f2b3ab0749" -> null
#       - assign_ipv6_address_on_creation                = false -> null
#       - availability_zone                              = "us-east-1a" -> null
#       - availability_zone_id                           = "use1-az4" -> null
#       - cidr_block                                     = "10.0.0.0/24" -> null
#       - enable_dns64                                   = false -> null
#       - enable_lni_at_device_index                     = 0 -> null
#       - enable_resource_name_dns_a_record_on_launch    = false -> null
#       - enable_resource_name_dns_aaaa_record_on_launch = false -> null
#       - id                                             = "subnet-04b9595f2b3ab0749" -> null
#       - ipv6_native                                    = false -> null
#       - map_customer_owned_ip_on_launch                = false -> null
#       - map_public_ip_on_launch                        = false -> null
#       - owner_id                                       = "609009159737" -> null
#       - private_dns_hostname_type_on_launch            = "ip-name" -> null
#       - tags                                           = {
#           - "Name" = "public-subnet"
#         } -> null
#       - tags_all                                       = {
#           - "Name" = "public-subnet"
#         } -> null
#       - vpc_id                                         = "vpc-04483240d8e8c3b9d" -> null
#         # (4 unchanged attributes hidden)
#     }
#
#   # aws_vpc.my_vpc will be destroyed
#   - resource "aws_vpc" "my_vpc" {
#       - arn                                  = "arn:aws:ec2:us-east-1:609009159737:vpc/vpc-04483240d8e8c3b9d" -> null
#       - assign_generated_ipv6_cidr_block     = false -> null
#       - cidr_block                           = "10.0.0.0/16" -> null
#       - default_network_acl_id               = "acl-0bc37df63524f5a40" -> null
#       - default_route_table_id               = "rtb-0f003c5f061c7192d" -> null
#       - default_security_group_id            = "sg-01b39077e532bfc93" -> null
#       - dhcp_options_id                      = "dopt-0bf15e3dedd5548e4" -> null
#       - enable_dns_hostnames                 = false -> null
#       - enable_dns_support                   = true -> null
#       - enable_network_address_usage_metrics = false -> null
#       - id                                   = "vpc-04483240d8e8c3b9d" -> null
#       - instance_tenancy                     = "default" -> null
#       - ipv6_netmask_length                  = 0 -> null
#       - main_route_table_id                  = "rtb-0f003c5f061c7192d" -> null
#       - owner_id                             = "609009159737" -> null
#       - tags                                 = {
#           - "Name" = "my-vpc"
#         } -> null
#       - tags_all                             = {
#           - "Name" = "my-vpc"
#         } -> null
#         # (4 unchanged attributes hidden)
#     }
#
# Plan: 0 to add, 0 to change, 32 to destroy.
#
# Changes to Outputs:
#   - ec2_private_ip      = "10.0.1.52" -> null
#   - mongodb_port        = 3307 -> null
#   - private_space_name  = "private-notebook" -> null
#   - sagemaker_domain_id = "d-jkvexsgascai" -> null
#   - shared_space_name   = "shared-notebook" -> null
#   - user_profile_name   = "ai-user" -> null
#   - vpc_id              = "vpc-04483240d8e8c3b9d" -> null
#
# ───────────────────────────────────────────────────────────────────────────────
#
# Note: You didn't use the -out option to save this plan, so Terraform can't
# guarantee to take exactly these actions if you run "terraform apply" now.

# %%
# !terraform destroy --auto-approve
# Out:
# data.aws_ami.amazon_linux: Reading...
# aws_iam_role.sagemaker_role: Refreshing state... [id=SageMakerRole]
# aws_iam_role.ec2_ssm_role: Refreshing state... [id=EC2SSMRole]
# aws_vpc.my_vpc: Refreshing state... [id=vpc-04483240d8e8c3b9d]
# aws_eip.nat_eip: Refreshing state... [id=eipalloc-01a7c8f7772f11809]
# aws_iam_role_policy_attachment.ec2_ssm_access: Refreshing state... [id=EC2SSMRole-20250825230712598600000002]
# aws_iam_instance_profile.ec2_ssm_profile: Refreshing state... [id=EC2SSMProfile]
# aws_iam_role_policy_attachment.sagemaker_full_access: Refreshing state... [id=SageMakerRole-20250825230712552900000001]
# data.aws_ami.amazon_linux: Read complete after 0s [id=ami-0309908417d7ea2d0]
# aws_route_table.private_rt: Refreshing state... [id=rtb-0190f89f8c378883f]
# aws_route_table.public_rt: Refreshing state... [id=rtb-0f1a6f4097b3eaad0]
# aws_subnet.public_subnet: Refreshing state... [id=subnet-04b9595f2b3ab0749]
# aws_internet_gateway.my_igw: Refreshing state... [id=igw-0dae499dd73d08f41]
# aws_subnet.private_subnet_1: Refreshing state... [id=subnet-0a78c9d873ec73fba]
# aws_security_group.sagemaker_sg: Refreshing state... [id=sg-00238749e8d8b4976]
# aws_network_acl.my_nacl: Refreshing state... [id=acl-0b2099f599d343568]
# aws_subnet.private_subnet_2: Refreshing state... [id=subnet-0fd992dc10102211f]
# aws_route_table_association.public_assoc: Refreshing state... [id=rtbassoc-0c379d7504e7b7b09]
# aws_nat_gateway.my_nat: Refreshing state... [id=nat-0bab8a7fbfbda5399]
# aws_route.public_internet: Refreshing state... [id=r-rtb-0f1a6f4097b3eaad01080289494]
# aws_network_acl_association.public_nacl_assoc: Refreshing state... [id=aclassoc-09bfb4be4c8fb0e98]
# aws_network_acl_rule.inbound_allow_all: Refreshing state... [id=nacl-670859304]
# aws_network_acl_rule.outbound_allow_all: Refreshing state... [id=nacl-4272685774]
# aws_network_acl_association.private_2_nacl_assoc: Refreshing state... [id=aclassoc-0d0e18746460facac]
# aws_security_group.ec2_sg: Refreshing state... [id=sg-07a3548da0fdba141]
# aws_network_acl_association.private_1_nacl_assoc: Refreshing state... [id=aclassoc-0255ec5a06911d102]
# aws_route_table_association.private_assoc_2: Refreshing state... [id=rtbassoc-0eab8dc1cf789f54c]
# aws_route_table_association.private_assoc_1: Refreshing state... [id=rtbassoc-003134c855e382e52]
# aws_sagemaker_domain.my_domain: Refreshing state... [id=d-jkvexsgascai]
# aws_route.private_nat: Refreshing state... [id=r-rtb-0190f89f8c378883f1080289494]
# aws_instance.my_ec2: Refreshing state... [id=i-0f763185886519ecf]
# aws_sagemaker_user_profile.ai_user: Refreshing state... [id=arn:aws:sagemaker:us-east-1:609009159737:user-profile/d-jkvexsgascai/ai-user]
# aws_sagemaker_space.private_space: Refreshing state... [id=arn:aws:sagemaker:us-east-1:609009159737:space/d-jkvexsgascai/private-notebook]
# aws_sagemaker_space.shared_space: Refreshing state... [id=arn:aws:sagemaker:us-east-1:609009159737:space/d-jkvexsgascai/shared-notebook]
#
# Terraform used the selected providers to generate the following execution plan.
# Resource actions are indicated with the following symbols:
#   - destroy
#
# Terraform will perform the following actions:
#
#   # aws_eip.nat_eip will be destroyed
#   - resource "aws_eip" "nat_eip" {
#       - allocation_id            = "eipalloc-01a7c8f7772f11809" -> null
#       - arn                      = "arn:aws:ec2:us-east-1:609009159737:elastic-ip/eipalloc-01a7c8f7772f11809" -> null
#       - association_id           = "eipassoc-0fb0b274acc7b258e" -> null
#       - domain                   = "vpc" -> null
#       - id                       = "eipalloc-01a7c8f7772f11809" -> null
#       - network_border_group     = "us-east-1" -> null
#       - network_interface        = "eni-0e91c943450d14a47" -> null
#       - private_dns              = "ip-10-0-0-89.ec2.internal" -> null
#       - private_ip               = "10.0.0.89" -> null
#       - public_dns               = "ec2-44-193-132-177.compute-1.amazonaws.com" -> null
#       - public_ip                = "44.193.132.177" -> null
#       - public_ipv4_pool         = "amazon" -> null
#       - tags                     = {} -> null
#       - tags_all                 = {} -> null
#       - vpc                      = true -> null
#         # (5 unchanged attributes hidden)
#     }
#
#   # aws_iam_instance_profile.ec2_ssm_profile will be destroyed
#   - resource "aws_iam_instance_profile" "ec2_ssm_profile" {
#       - arn         = "arn:aws:iam::609009159737:instance-profile/EC2SSMProfile" -> null
#       - create_date = "2025-08-25T23:07:12Z" -> null
#       - id          = "EC2SSMProfile" -> null
#       - name        = "EC2SSMProfile" -> null
#       - path        = "/" -> null
#       - role        = "EC2SSMRole" -> null
#       - tags        = {} -> null
#       - tags_all    = {} -> null
#       - unique_id   = "AIPAY3S6GJY4Z3OMT5B3L" -> null
#         # (1 unchanged attribute hidden)
#     }
#
#   # aws_iam_role.ec2_ssm_role will be destroyed
#   - resource "aws_iam_role" "ec2_ssm_role" {
#       - arn                   = "arn:aws:iam::609009159737:role/EC2SSMRole" -> null
#       - assume_role_policy    = jsonencode(
#             {
#               - Statement = [
#                   - {
#                       - Action    = "sts:AssumeRole"
#                       - Effect    = "Allow"
#                       - Principal = {
#                           - Service = "ec2.amazonaws.com"
#                         }
#                     },
#                 ]
#               - Version   = "2012-10-17"
#             }
#         ) -> null
#       - create_date           = "2025-08-25T23:07:12Z" -> null
#       - force_detach_policies = false -> null
#       - id                    = "EC2SSMRole" -> null
#       - managed_policy_arns   = [
#           - "arn:aws:iam::aws:policy/AmazonSSMManagedInstanceCore",
#         ] -> null
#       - max_session_duration  = 3600 -> null
#       - name                  = "EC2SSMRole" -> null
#       - path                  = "/" -> null
#       - tags                  = {} -> null
#       - tags_all              = {} -> null
#       - unique_id             = "AROAY3S6GJY4UXSERF2FW" -> null
#         # (3 unchanged attributes hidden)
#     }
#
#   # aws_iam_role.sagemaker_role will be destroyed
#   - resource "aws_iam_role" "sagemaker_role" {
#       - arn                   = "arn:aws:iam::609009159737:role/SageMakerRole" -> null
#       - assume_role_policy    = jsonencode(
#             {
#               - Statement = [
#                   - {
#                       - Action    = "sts:AssumeRole"
#                       - Effect    = "Allow"
#                       - Principal = {
#                           - Service = "sagemaker.amazonaws.com"
#                         }
#                     },
#                 ]
#               - Version   = "2012-10-17"
#             }
#         ) -> null
#       - create_date           = "2025-08-25T23:07:12Z" -> null
#       - force_detach_policies = false -> null
#       - id                    = "SageMakerRole" -> null
#       - managed_policy_arns   = [
#           - "arn:aws:iam::aws:policy/AmazonSageMakerFullAccess",
#         ] -> null
#       - max_session_duration  = 3600 -> null
#       - name                  = "SageMakerRole" -> null
#       - path                  = "/" -> null
#       - tags                  = {} -> null
#       - tags_all              = {} -> null
#       - unique_id             = "AROAY3S6GJY4TEOLB5OLW" -> null
#         # (3 unchanged attributes hidden)
#     }
#
#   # aws_iam_role_policy_attachment.ec2_ssm_access will be destroyed
#   - resource "aws_iam_role_policy_attachment" "ec2_ssm_access" {
#       - id         = "EC2SSMRole-20250825230712598600000002" -> null
#       - policy_arn = "arn:aws:iam::aws:policy/AmazonSSMManagedInstanceCore" -> null
#       - role       = "EC2SSMRole" -> null
#     }
#
#   # aws_iam_role_policy_attachment.sagemaker_full_access will be destroyed
#   - resource "aws_iam_role_policy_attachment" "sagemaker_full_access" {
#       - id         = "SageMakerRole-20250825230712552900000001" -> null
#       - policy_arn = "arn:aws:iam::aws:policy/AmazonSageMakerFullAccess" -> null
#       - role       = "SageMakerRole" -> null
#     }
#
#   # aws_instance.my_ec2 will be destroyed
#   - resource "aws_instance" "my_ec2" {
#       - ami                                  = "ami-0309908417d7ea2d0" -> null
#       - arn                                  = "arn:aws:ec2:us-east-1:609009159737:instance/i-0f763185886519ecf" -> null
#       - associate_public_ip_address          = false -> null
#       - availability_zone                    = "us-east-1a" -> null
#       - cpu_core_count                       = 1 -> null
#       - cpu_threads_per_core                 = 1 -> null
#       - disable_api_stop                     = false -> null
#       - disable_api_termination              = false -> null
#       - ebs_optimized                        = false -> null
#       - get_password_data                    = false -> null
#       - hibernation                          = false -> null
#       - iam_instance_profile                 = "EC2SSMProfile" -> null
#       - id                                   = "i-0f763185886519ecf" -> null
#       - instance_initiated_shutdown_behavior = "stop" -> null
#       - instance_state                       = "running" -> null
#       - instance_type                        = "t2.micro" -> null
#       - ipv6_address_count                   = 0 -> null
#       - ipv6_addresses                       = [] -> null
#       - monitoring                           = false -> null
#       - placement_partition_number           = 0 -> null
#       - primary_network_interface_id         = "eni-059273ae3c47ba2d7" -> null
#       - private_dns                          = "ip-10-0-1-52.ec2.internal" -> null
#       - private_ip                           = "10.0.1.52" -> null
#       - secondary_private_ips                = [] -> null
#       - security_groups                      = [] -> null
#       - source_dest_check                    = true -> null
#       - subnet_id                            = "subnet-0a78c9d873ec73fba" -> null
#       - tags                                 = {
#           - "Name" = "my-ec2"
#         } -> null
#       - tags_all                             = {
#           - "Name" = "my-ec2"
#         } -> null
#       - tenancy                              = "default" -> null
#       - user_data                            = "4eccd0c8fd4ebe33b7e3f557709750a2c7ff18e9" -> null
#       - user_data_replace_on_change          = false -> null
#       - vpc_security_group_ids               = [
#           - "sg-07a3548da0fdba141",
#         ] -> null
#         # (9 unchanged attributes hidden)
#
#       - capacity_reservation_specification {
#           - capacity_reservation_preference = "open" -> null
#         }
#
#       - cpu_options {
#           - core_count       = 1 -> null
#           - threads_per_core = 1 -> null
#             # (1 unchanged attribute hidden)
#         }
#
#       - credit_specification {
#           - cpu_credits = "standard" -> null
#         }
#
#       - enclave_options {
#           - enabled = false -> null
#         }
#
#       - maintenance_options {
#           - auto_recovery = "default" -> null
#         }
#
#       - metadata_options {
#           - http_endpoint               = "enabled" -> null
#           - http_protocol_ipv6          = "disabled" -> null
#           - http_put_response_hop_limit = 2 -> null
#           - http_tokens                 = "required" -> null
#           - instance_metadata_tags      = "disabled" -> null
#         }
#
#       - private_dns_name_options {
#           - enable_resource_name_dns_a_record    = false -> null
#           - enable_resource_name_dns_aaaa_record = false -> null
#           - hostname_type                        = "ip-name" -> null
#         }
#
#       - root_block_device {
#           - delete_on_termination = true -> null
#           - device_name           = "/dev/xvda" -> null
#           - encrypted             = false -> null
#           - iops                  = 3000 -> null
#           - tags                  = {} -> null
#           - tags_all              = {} -> null
#           - throughput            = 125 -> null
#           - volume_id             = "vol-0876072fa981fe10a" -> null
#           - volume_size           = 8 -> null
#           - volume_type           = "gp3" -> null
#             # (1 unchanged attribute hidden)
#         }
#     }
#
#   # aws_internet_gateway.my_igw will be destroyed
#   - resource "aws_internet_gateway" "my_igw" {
#       - arn      = "arn:aws:ec2:us-east-1:609009159737:internet-gateway/igw-0dae499dd73d08f41" -> null
#       - id       = "igw-0dae499dd73d08f41" -> null
#       - owner_id = "609009159737" -> null
#       - tags     = {
#           - "Name" = "my-igw"
#         } -> null
#       - tags_all = {
#           - "Name" = "my-igw"
#         } -> null
#       - vpc_id   = "vpc-04483240d8e8c3b9d" -> null
#     }
#
#   # aws_nat_gateway.my_nat will be destroyed
#   - resource "aws_nat_gateway" "my_nat" {
#       - allocation_id                      = "eipalloc-01a7c8f7772f11809" -> null
#       - association_id                     = "eipassoc-0fb0b274acc7b258e" -> null
#       - connectivity_type                  = "public" -> null
#       - id                                 = "nat-0bab8a7fbfbda5399" -> null
#       - network_interface_id               = "eni-0e91c943450d14a47" -> null
#       - private_ip                         = "10.0.0.89" -> null
#       - public_ip                          = "44.193.132.177" -> null
#       - secondary_allocation_ids           = [] -> null
#       - secondary_private_ip_address_count = 0 -> null
#       - secondary_private_ip_addresses     = [] -> null
#       - subnet_id                          = "subnet-04b9595f2b3ab0749" -> null
#       - tags                               = {
#           - "Name" = "my-nat"
#         } -> null
#       - tags_all                           = {
#           - "Name" = "my-nat"
#         } -> null
#     }
#
#   # aws_network_acl.my_nacl will be destroyed
#   - resource "aws_network_acl" "my_nacl" {
#       - arn        = "arn:aws:ec2:us-east-1:609009159737:network-acl/acl-0b2099f599d343568" -> null
#       - egress     = [
#           - {
#               - action          = "allow"
#               - cidr_block      = "0.0.0.0/0"
#               - from_port       = 0
#               - icmp_code       = 0
#               - icmp_type       = 0
#               - protocol        = "-1"
#               - rule_no         = 100
#               - to_port         = 0
#                 # (1 unchanged attribute hidden)
#             },
#         ] -> null
#       - id         = "acl-0b2099f599d343568" -> null
#       - ingress    = [
#           - {
#               - action          = "allow"
#               - cidr_block      = "0.0.0.0/0"
#               - from_port       = 0
#               - icmp_code       = 0
#               - icmp_type       = 0
#               - protocol        = "-1"
#               - rule_no         = 100
#               - to_port         = 0
#                 # (1 unchanged attribute hidden)
#             },
#         ] -> null
#       - owner_id   = "609009159737" -> null
#       - subnet_ids = [
#           - "subnet-04b9595f2b3ab0749",
#           - "subnet-0a78c9d873ec73fba",
#           - "subnet-0fd992dc10102211f",
#         ] -> null
#       - tags       = {
#           - "Name" = "my-nacl"
#         } -> null
#       - tags_all   = {
#           - "Name" = "my-nacl"
#         } -> null
#       - vpc_id     = "vpc-04483240d8e8c3b9d" -> null
#     }
#
#   # aws_network_acl_association.private_1_nacl_assoc will be destroyed
#   - resource "aws_network_acl_association" "private_1_nacl_assoc" {
#       - id             = "aclassoc-0255ec5a06911d102" -> null
#       - network_acl_id = "acl-0b2099f599d343568" -> null
#       - subnet_id      = "subnet-0a78c9d873ec73fba" -> null
#     }
#
#   # aws_network_acl_association.private_2_nacl_assoc will be destroyed
#   - resource "aws_network_acl_association" "private_2_nacl_assoc" {
#       - id             = "aclassoc-0d0e18746460facac" -> null
#       - network_acl_id = "acl-0b2099f599d343568" -> null
#       - subnet_id      = "subnet-0fd992dc10102211f" -> null
#     }
#
#   # aws_network_acl_association.public_nacl_assoc will be destroyed
#   - resource "aws_network_acl_association" "public_nacl_assoc" {
#       - id             = "aclassoc-09bfb4be4c8fb0e98" -> null
#       - network_acl_id = "acl-0b2099f599d343568" -> null
#       - subnet_id      = "subnet-04b9595f2b3ab0749" -> null
#     }
#
#   # aws_network_acl_rule.inbound_allow_all will be destroyed
#   - resource "aws_network_acl_rule" "inbound_allow_all" {
#       - cidr_block      = "0.0.0.0/0" -> null
#       - egress          = false -> null
#       - id              = "nacl-670859304" -> null
#       - network_acl_id  = "acl-0b2099f599d343568" -> null
#       - protocol        = "-1" -> null
#       - rule_action     = "allow" -> null
#       - rule_number     = 100 -> null
#         # (1 unchanged attribute hidden)
#     }
#
#   # aws_network_acl_rule.outbound_allow_all will be destroyed
#   - resource "aws_network_acl_rule" "outbound_allow_all" {
#       - cidr_block      = "0.0.0.0/0" -> null
#       - egress          = true -> null
#       - id              = "nacl-4272685774" -> null
#       - network_acl_id  = "acl-0b2099f599d343568" -> null
#       - protocol        = "-1" -> null
#       - rule_action     = "allow" -> null
#       - rule_number     = 100 -> null
#         # (1 unchanged attribute hidden)
#     }
#
#   # aws_route.private_nat will be destroyed
#   - resource "aws_route" "private_nat" {
#       - destination_cidr_block      = "0.0.0.0/0" -> null
#       - id                          = "r-rtb-0190f89f8c378883f1080289494" -> null
#       - nat_gateway_id              = "nat-0bab8a7fbfbda5399" -> null
#       - origin                      = "CreateRoute" -> null
#       - route_table_id              = "rtb-0190f89f8c378883f" -> null
#       - state                       = "active" -> null
#         # (13 unchanged attributes hidden)
#     }
#
#   # aws_route.public_internet will be destroyed
#   - resource "aws_route" "public_internet" {
#       - destination_cidr_block      = "0.0.0.0/0" -> null
#       - gateway_id                  = "igw-0dae499dd73d08f41" -> null
#       - id                          = "r-rtb-0f1a6f4097b3eaad01080289494" -> null
#       - origin                      = "CreateRoute" -> null
#       - route_table_id              = "rtb-0f1a6f4097b3eaad0" -> null
#       - state                       = "active" -> null
#         # (13 unchanged attributes hidden)
#     }
#
#   # aws_route_table.private_rt will be destroyed
#   - resource "aws_route_table" "private_rt" {
#       - arn              = "arn:aws:ec2:us-east-1:609009159737:route-table/rtb-0190f89f8c378883f" -> null
#       - id               = "rtb-0190f89f8c378883f" -> null
#       - owner_id         = "609009159737" -> null
#       - propagating_vgws = [] -> null
#       - route            = [
#           - {
#               - cidr_block                 = "0.0.0.0/0"
#               - nat_gateway_id             = "nat-0bab8a7fbfbda5399"
#                 # (11 unchanged attributes hidden)
#             },
#         ] -> null
#       - tags             = {
#           - "Name" = "private-rt"
#         } -> null
#       - tags_all         = {
#           - "Name" = "private-rt"
#         } -> null
#       - vpc_id           = "vpc-04483240d8e8c3b9d" -> null
#     }
#
#   # aws_route_table.public_rt will be destroyed
#   - resource "aws_route_table" "public_rt" {
#       - arn              = "arn:aws:ec2:us-east-1:609009159737:route-table/rtb-0f1a6f4097b3eaad0" -> null
#       - id               = "rtb-0f1a6f4097b3eaad0" -> null
#       - owner_id         = "609009159737" -> null
#       - propagating_vgws = [] -> null
#       - route            = [
#           - {
#               - cidr_block                 = "0.0.0.0/0"
#               - gateway_id                 = "igw-0dae499dd73d08f41"
#                 # (11 unchanged attributes hidden)
#             },
#         ] -> null
#       - tags             = {
#           - "Name" = "public-rt"
#         } -> null
#       - tags_all         = {
#           - "Name" = "public-rt"
#         } -> null
#       - vpc_id           = "vpc-04483240d8e8c3b9d" -> null
#     }
#
#   # aws_route_table_association.private_assoc_1 will be destroyed
#   - resource "aws_route_table_association" "private_assoc_1" {
#       - id             = "rtbassoc-003134c855e382e52" -> null
#       - route_table_id = "rtb-0190f89f8c378883f" -> null
#       - subnet_id      = "subnet-0a78c9d873ec73fba" -> null
#         # (1 unchanged attribute hidden)
#     }
#
#   # aws_route_table_association.private_assoc_2 will be destroyed
#   - resource "aws_route_table_association" "private_assoc_2" {
#       - id             = "rtbassoc-0eab8dc1cf789f54c" -> null
#       - route_table_id = "rtb-0190f89f8c378883f" -> null
#       - subnet_id      = "subnet-0fd992dc10102211f" -> null
#         # (1 unchanged attribute hidden)
#     }
#
#   # aws_route_table_association.public_assoc will be destroyed
#   - resource "aws_route_table_association" "public_assoc" {
#       - id             = "rtbassoc-0c379d7504e7b7b09" -> null
#       - route_table_id = "rtb-0f1a6f4097b3eaad0" -> null
#       - subnet_id      = "subnet-04b9595f2b3ab0749" -> null
#         # (1 unchanged attribute hidden)
#     }
#
#   # aws_sagemaker_domain.my_domain will be destroyed
#   - resource "aws_sagemaker_domain" "my_domain" {
#       - app_network_access_type                        = "VpcOnly" -> null
#       - arn                                            = "arn:aws:sagemaker:us-east-1:609009159737:domain/d-jkvexsgascai" -> null
#       - auth_mode                                      = "IAM" -> null
#       - domain_name                                    = "my-domain" -> null
#       - home_efs_file_system_id                        = "fs-0ef2c9735b0597a8a" -> null
#       - id                                             = "d-jkvexsgascai" -> null
#       - subnet_ids                                     = [
#           - "subnet-0a78c9d873ec73fba",
#           - "subnet-0fd992dc10102211f",
#         ] -> null
#       - tag_propagation                                = "DISABLED" -> null
#       - tags                                           = {} -> null
#       - tags_all                                       = {} -> null
#       - url                                            = "https://d-jkvexsgascai.studio.us-east-1.sagemaker.aws" -> null
#       - vpc_id                                         = "vpc-04483240d8e8c3b9d" -> null
#         # (5 unchanged attributes hidden)
#
#       - default_space_settings {
#           - execution_role  = "arn:aws:iam::609009159737:role/SageMakerRole" -> null
#           - security_groups = [
#               - "sg-00238749e8d8b4976",
#             ] -> null
#         }
#
#       - default_user_settings {
#           - auto_mount_home_efs = "Enabled" -> null
#           - default_landing_uri = "studio::" -> null
#           - execution_role      = "arn:aws:iam::609009159737:role/SageMakerRole" -> null
#           - security_groups     = [
#               - "sg-00238749e8d8b4976",
#             ] -> null
#           - studio_web_portal   = "ENABLED" -> null
#         }
#     }
#
#   # aws_sagemaker_space.private_space will be destroyed
#   - resource "aws_sagemaker_space" "private_space" {
#       - arn                      = "arn:aws:sagemaker:us-east-1:609009159737:space/d-jkvexsgascai/private-notebook" -> null
#       - domain_id                = "d-jkvexsgascai" -> null
#       - id                       = "arn:aws:sagemaker:us-east-1:609009159737:space/d-jkvexsgascai/private-notebook" -> null
#       - space_name               = "private-notebook" -> null
#       - tags                     = {} -> null
#       - tags_all                 = {} -> null
#       - url                      = "https://f3yshxchnnpjpor.studio.us-east-1.sagemaker.aws/jupyterlab/default" -> null
#         # (2 unchanged attributes hidden)
#
#       - ownership_settings {
#           - owner_user_profile_name = "ai-user" -> null
#         }
#
#       - space_settings {
#           - app_type = "JupyterLab" -> null
#
#           - jupyter_lab_app_settings {
#               - default_resource_spec {
#                   - instance_type                 = "ml.t3.medium" -> null
#                     # (4 unchanged attributes hidden)
#                 }
#             }
#
#           - space_storage_settings {
#               - ebs_storage_settings {
#                   - ebs_volume_size_in_gb = 5 -> null
#                 }
#             }
#         }
#
#       - space_sharing_settings {
#           - sharing_type = "Private" -> null
#         }
#     }
#
#   # aws_sagemaker_space.shared_space will be destroyed
#   - resource "aws_sagemaker_space" "shared_space" {
#       - arn                      = "arn:aws:sagemaker:us-east-1:609009159737:space/d-jkvexsgascai/shared-notebook" -> null
#       - domain_id                = "d-jkvexsgascai" -> null
#       - id                       = "arn:aws:sagemaker:us-east-1:609009159737:space/d-jkvexsgascai/shared-notebook" -> null
#       - space_name               = "shared-notebook" -> null
#       - tags                     = {} -> null
#       - tags_all                 = {} -> null
#       - url                      = "https://yze6txriix05kye.studio.us-east-1.sagemaker.aws/jupyterlab/default" -> null
#         # (2 unchanged attributes hidden)
#
#       - ownership_settings {
#           - owner_user_profile_name = "ai-user" -> null
#         }
#
#       - space_settings {
#           - app_type = "JupyterLab" -> null
#
#           - jupyter_lab_app_settings {
#               - default_resource_spec {
#                   - instance_type                 = "ml.t3.medium" -> null
#                   - sagemaker_image_arn           = "arn:aws:sagemaker:us-east-1:885854791233:image/sagemaker-distribution-cpu" -> null
#                   - sagemaker_image_version_alias = "3.4.2" -> null
#                     # (2 unchanged attributes hidden)
#                 }
#             }
#
#           - space_storage_settings {
#               - ebs_storage_settings {
#                   - ebs_volume_size_in_gb = 5 -> null
#                 }
#             }
#         }
#
#       - space_sharing_settings {
#           - sharing_type = "Shared" -> null
#         }
#     }
#
#   # aws_sagemaker_user_profile.ai_user will be destroyed
#   - resource "aws_sagemaker_user_profile" "ai_user" {
#       - arn                            = "arn:aws:sagemaker:us-east-1:609009159737:user-profile/d-jkvexsgascai/ai-user" -> null
#       - domain_id                      = "d-jkvexsgascai" -> null
#       - home_efs_file_system_uid       = "200005" -> null
#       - id                             = "arn:aws:sagemaker:us-east-1:609009159737:user-profile/d-jkvexsgascai/ai-user" -> null
#       - tags                           = {} -> null
#       - tags_all                       = {} -> null
#       - user_profile_name              = "ai-user" -> null
#         # (2 unchanged attributes hidden)
#
#       - user_settings {
#           - auto_mount_home_efs = "DefaultAsDomain" -> null
#           - execution_role      = "arn:aws:iam::609009159737:role/SageMakerRole" -> null
#           - security_groups     = [
#               - "sg-00238749e8d8b4976",
#             ] -> null
#             # (2 unchanged attributes hidden)
#         }
#     }
#
#   # aws_security_group.ec2_sg will be destroyed
#   - resource "aws_security_group" "ec2_sg" {
#       - arn                    = "arn:aws:ec2:us-east-1:609009159737:security-group/sg-07a3548da0fdba141" -> null
#       - description            = "For EC2 MongoDB" -> null
#       - egress                 = [
#           - {
#               - cidr_blocks      = [
#                   - "0.0.0.0/0",
#                 ]
#               - from_port        = 0
#               - ipv6_cidr_blocks = []
#               - prefix_list_ids  = []
#               - protocol         = "-1"
#               - security_groups  = []
#               - self             = false
#               - to_port          = 0
#                 # (1 unchanged attribute hidden)
#             },
#         ] -> null
#       - id                     = "sg-07a3548da0fdba141" -> null
#       - ingress                = [
#           - {
#               - cidr_blocks      = []
#               - from_port        = 3307
#               - ipv6_cidr_blocks = []
#               - prefix_list_ids  = []
#               - protocol         = "tcp"
#               - security_groups  = [
#                   - "sg-00238749e8d8b4976",
#                 ]
#               - self             = false
#               - to_port          = 3307
#                 # (1 unchanged attribute hidden)
#             },
#         ] -> null
#       - name                   = "ec2-sg" -> null
#       - owner_id               = "609009159737" -> null
#       - revoke_rules_on_delete = false -> null
#       - tags                   = {
#           - "Name" = "ec2-sg"
#         } -> null
#       - tags_all               = {
#           - "Name" = "ec2-sg"
#         } -> null
#       - vpc_id                 = "vpc-04483240d8e8c3b9d" -> null
#         # (1 unchanged attribute hidden)
#     }
#
#   # aws_security_group.sagemaker_sg will be destroyed
#   - resource "aws_security_group" "sagemaker_sg" {
#       - arn                    = "arn:aws:ec2:us-east-1:609009159737:security-group/sg-00238749e8d8b4976" -> null
#       - description            = "For SageMaker" -> null
#       - egress                 = [
#           - {
#               - cidr_blocks      = [
#                   - "0.0.0.0/0",
#                 ]
#               - from_port        = 0
#               - ipv6_cidr_blocks = []
#               - prefix_list_ids  = []
#               - protocol         = "-1"
#               - security_groups  = []
#               - self             = false
#               - to_port          = 0
#                 # (1 unchanged attribute hidden)
#             },
#         ] -> null
#       - id                     = "sg-00238749e8d8b4976" -> null
#       - ingress                = [] -> null
#       - name                   = "sagemaker-sg" -> null
#       - owner_id               = "609009159737" -> null
#       - revoke_rules_on_delete = false -> null
#       - tags                   = {
#           - "Name" = "sagemaker-sg"
#         } -> null
#       - tags_all               = {
#           - "Name" = "sagemaker-sg"
#         } -> null
#       - vpc_id                 = "vpc-04483240d8e8c3b9d" -> null
#         # (1 unchanged attribute hidden)
#     }
#
#   # aws_subnet.private_subnet_1 will be destroyed
#   - resource "aws_subnet" "private_subnet_1" {
#       - arn                                            = "arn:aws:ec2:us-east-1:609009159737:subnet/subnet-0a78c9d873ec73fba" -> null
#       - assign_ipv6_address_on_creation                = false -> null
#       - availability_zone                              = "us-east-1a" -> null
#       - availability_zone_id                           = "use1-az4" -> null
#       - cidr_block                                     = "10.0.1.0/24" -> null
#       - enable_dns64                                   = false -> null
#       - enable_lni_at_device_index                     = 0 -> null
#       - enable_resource_name_dns_a_record_on_launch    = false -> null
#       - enable_resource_name_dns_aaaa_record_on_launch = false -> null
#       - id                                             = "subnet-0a78c9d873ec73fba" -> null
#       - ipv6_native                                    = false -> null
#       - map_customer_owned_ip_on_launch                = false -> null
#       - map_public_ip_on_launch                        = false -> null
#       - owner_id                                       = "609009159737" -> null
#       - private_dns_hostname_type_on_launch            = "ip-name" -> null
#       - tags                                           = {
#           - "Name" = "private-subnet-1"
#         } -> null
#       - tags_all                                       = {
#           - "Name" = "private-subnet-1"
#         } -> null
#       - vpc_id                                         = "vpc-04483240d8e8c3b9d" -> null
#         # (4 unchanged attributes hidden)
#     }
#
#   # aws_subnet.private_subnet_2 will be destroyed
#   - resource "aws_subnet" "private_subnet_2" {
#       - arn                                            = "arn:aws:ec2:us-east-1:609009159737:subnet/subnet-0fd992dc10102211f" -> null
#       - assign_ipv6_address_on_creation                = false -> null
#       - availability_zone                              = "us-east-1b" -> null
#       - availability_zone_id                           = "use1-az6" -> null
#       - cidr_block                                     = "10.0.2.0/24" -> null
#       - enable_dns64                                   = false -> null
#       - enable_lni_at_device_index                     = 0 -> null
#       - enable_resource_name_dns_a_record_on_launch    = false -> null
#       - enable_resource_name_dns_aaaa_record_on_launch = false -> null
#       - id                                             = "subnet-0fd992dc10102211f" -> null
#       - ipv6_native                                    = false -> null
#       - map_customer_owned_ip_on_launch                = false -> null
#       - map_public_ip_on_launch                        = false -> null
#       - owner_id                                       = "609009159737" -> null
#       - private_dns_hostname_type_on_launch            = "ip-name" -> null
#       - tags                                           = {
#           - "Name" = "private-subnet-2"
#         } -> null
#       - tags_all                                       = {
#           - "Name" = "private-subnet-2"
#         } -> null
#       - vpc_id                                         = "vpc-04483240d8e8c3b9d" -> null
#         # (4 unchanged attributes hidden)
#     }
#
#   # aws_subnet.public_subnet will be destroyed
#   - resource "aws_subnet" "public_subnet" {
#       - arn                                            = "arn:aws:ec2:us-east-1:609009159737:subnet/subnet-04b9595f2b3ab0749" -> null
#       - assign_ipv6_address_on_creation                = false -> null
#       - availability_zone                              = "us-east-1a" -> null
#       - availability_zone_id                           = "use1-az4" -> null
#       - cidr_block                                     = "10.0.0.0/24" -> null
#       - enable_dns64                                   = false -> null
#       - enable_lni_at_device_index                     = 0 -> null
#       - enable_resource_name_dns_a_record_on_launch    = false -> null
#       - enable_resource_name_dns_aaaa_record_on_launch = false -> null
#       - id                                             = "subnet-04b9595f2b3ab0749" -> null
#       - ipv6_native                                    = false -> null
#       - map_customer_owned_ip_on_launch                = false -> null
#       - map_public_ip_on_launch                        = false -> null
#       - owner_id                                       = "609009159737" -> null
#       - private_dns_hostname_type_on_launch            = "ip-name" -> null
#       - tags                                           = {
#           - "Name" = "public-subnet"
#         } -> null
#       - tags_all                                       = {
#           - "Name" = "public-subnet"
#         } -> null
#       - vpc_id                                         = "vpc-04483240d8e8c3b9d" -> null
#         # (4 unchanged attributes hidden)
#     }
#
#   # aws_vpc.my_vpc will be destroyed
#   - resource "aws_vpc" "my_vpc" {
#       - arn                                  = "arn:aws:ec2:us-east-1:609009159737:vpc/vpc-04483240d8e8c3b9d" -> null
#       - assign_generated_ipv6_cidr_block     = false -> null
#       - cidr_block                           = "10.0.0.0/16" -> null
#       - default_network_acl_id               = "acl-0bc37df63524f5a40" -> null
#       - default_route_table_id               = "rtb-0f003c5f061c7192d" -> null
#       - default_security_group_id            = "sg-01b39077e532bfc93" -> null
#       - dhcp_options_id                      = "dopt-0bf15e3dedd5548e4" -> null
#       - enable_dns_hostnames                 = false -> null
#       - enable_dns_support                   = true -> null
#       - enable_network_address_usage_metrics = false -> null
#       - id                                   = "vpc-04483240d8e8c3b9d" -> null
#       - instance_tenancy                     = "default" -> null
#       - ipv6_netmask_length                  = 0 -> null
#       - main_route_table_id                  = "rtb-0f003c5f061c7192d" -> null
#       - owner_id                             = "609009159737" -> null
#       - tags                                 = {
#           - "Name" = "my-vpc"
#         } -> null
#       - tags_all                             = {
#           - "Name" = "my-vpc"
#         } -> null
#         # (4 unchanged attributes hidden)
#     }
#
# Plan: 0 to add, 0 to change, 32 to destroy.
#
# Changes to Outputs:
#   - ec2_private_ip      = "10.0.1.52" -> null
#   - mongodb_port        = 3307 -> null
#   - private_space_name  = "private-notebook" -> null
#   - sagemaker_domain_id = "d-jkvexsgascai" -> null
#   - shared_space_name   = "shared-notebook" -> null
#   - user_profile_name   = "ai-user" -> null
#   - vpc_id              = "vpc-04483240d8e8c3b9d" -> null
#
# Do you really want to destroy all resources?
#   Terraform will destroy all your managed infrastructure, as shown above.
#   There is no undo. Only 'yes' will be accepted to confirm.
#
#   Enter a value: ^C
#
# Destroy cancelled.
#
# Interrupt received.
# Please wait for Terraform to exit or data loss may occur.
# Gracefully shutting down...

# %%
# run the following command in the notebook
#
#import pymongo
# client = pymongo.MongoClient("mongodb://<ec2-private-ip>:3307/")
# Test: client.server_info()
