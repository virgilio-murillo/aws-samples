# %% [markdown]
# #### Dockerfile creation
# we first create a Dockerfile based on the documentation here https://docs.aws.amazon.com/sagemaker/latest/dg/studio-updated-jl-admin-guide-custom-images.html#studio-updated-jl-custom-images-dockerfile-templates
#
# ```
# FROM public.ecr.aws/sagemaker/sagemaker-distribution:latest-cpu
# ARG NB_USER="sagemaker-user"
# ARG NB_UID=1000
# ARG NB_GID=100
#
# ENV MAMBA_USER=$NB_USER
#
# USER root
#
# RUN apt-get update
# RUN micromamba install sagemaker-inference --freeze-installed --yes --channel conda-forge --name base
#
# USER $MAMBA_USER
#
# ENTRYPOINT ["jupyter-lab"]
# CMD ["--ServerApp.ip=0.0.0.0", "--ServerApp.port=8888", "--ServerApp.allow_origin=*", "--ServerApp.token=''", "--ServerApp.base_url=/jupyterlab/default"]
# ```

# %%
# we create the ECR repository
# !aws ecr create-repository --repository-name smstudio-custom --region us-east-1
# Out:
# An error occurred (AccessDeniedException) when calling the CreateRepository operation: User: arn:aws:sts::794038231401:assumed-role/SageMaker-ExecutionRole-20250401T103257/SageMaker is not authorized to perform: ecr:CreateRepository on resource: arn:aws:ecr:us-east-1:794038231401:repository/smstudio-custom because no identity-based policy allows the ecr:CreateRepository action

# %%
# !aws ecr get-login-password --region us-east-1 | docker login --username AWS --password-stdin 794038231401.dkr.ecr.us-east-1.amazonaws.com
# Out:
# WARNING! Your password will be stored unencrypted in /home/ec2-user/.docker/config.json.
# Configure a credential helper to remove this warning. See
# https://docs.docker.com/engine/reference/commandline/login/#credentials-store
#
# Login Succeeded

# %%
# !pip install sagemaker-studio-image-build
# Out:
# Collecting sagemaker-studio-image-build
#   Downloading sagemaker_studio_image_build-0.6.0.tar.gz (13 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: boto3<2.0,>=1.10.44 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker-studio-image-build) (1.38.35)
# Requirement already satisfied: sagemaker<3.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker-studio-image-build) (2.246.0)
# Requirement already satisfied: botocore<1.39.0,>=1.38.35 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from boto3<2.0,>=1.10.44->sagemaker-studio-image-build) (1.38.35)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from boto3<2.0,>=1.10.44->sagemaker-studio-image-build) (1.0.1)
# Requirement already satisfied: s3transfer<0.14.0,>=0.13.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from boto3<2.0,>=1.10.44->sagemaker-studio-image-build) (0.13.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from botocore<1.39.0,>=1.38.35->boto3<2.0,>=1.10.44->sagemaker-studio-image-build) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from botocore<1.39.0,>=1.38.35->boto3<2.0,>=1.10.44->sagemaker-studio-image-build) (2.4.0)
# Requirement already satisfied: six>=1.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.39.0,>=1.38.35->boto3<2.0,>=1.10.44->sagemaker-studio-image-build) (1.17.0)
# Requirement already satisfied: attrs<26,>=24 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker<3.0->sagemaker-studio-image-build) (25.3.0)
# Requirement already satisfied: cloudpickle>=2.2.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker<3.0->sagemaker-studio-image-build) (3.1.1)
# Requirement already satisfied: docker in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker<3.0->sagemaker-studio-image-build) (7.1.0)
# Requirement already satisfied: fastapi in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker<3.0->sagemaker-studio-image-build) (0.115.12)
# Requirement already satisfied: google-pasta in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker<3.0->sagemaker-studio-image-build) (0.2.0)
# Requirement already satisfied: graphene<4,>=3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker<3.0->sagemaker-studio-image-build) (3.4.3)
# Requirement already satisfied: importlib-metadata<7.0,>=1.4.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker<3.0->sagemaker-studio-image-build) (6.11.0)
# Requirement already satisfied: jsonschema in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker<3.0->sagemaker-studio-image-build) (4.24.0)
# Requirement already satisfied: numpy==1.26.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker<3.0->sagemaker-studio-image-build) (1.26.4)
# Requirement already satisfied: omegaconf<3,>=2.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker<3.0->sagemaker-studio-image-build) (2.3.0)
# Requirement already satisfied: packaging<25,>=23.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker<3.0->sagemaker-studio-image-build) (24.2)
# Requirement already satisfied: pandas in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker<3.0->sagemaker-studio-image-build) (2.2.3)
# Requirement already satisfied: pathos in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker<3.0->sagemaker-studio-image-build) (0.3.4)
# Requirement already satisfied: platformdirs in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker<3.0->sagemaker-studio-image-build) (4.3.8)
# Requirement already satisfied: protobuf<6.0,>=3.12 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker<3.0->sagemaker-studio-image-build) (5.29.5)
# Requirement already satisfied: psutil in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker<3.0->sagemaker-studio-image-build) (6.1.1)
# Requirement already satisfied: pyyaml>=6.0.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker<3.0->sagemaker-studio-image-build) (6.0.2)
# Requirement already satisfied: requests in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker<3.0->sagemaker-studio-image-build) (2.32.3)
# Requirement already satisfied: sagemaker-core<2.0.0,>=1.0.17 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker<3.0->sagemaker-studio-image-build) (1.0.37)
# Requirement already satisfied: schema in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker<3.0->sagemaker-studio-image-build) (0.7.7)
# Requirement already satisfied: smdebug-rulesconfig==1.0.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker<3.0->sagemaker-studio-image-build) (1.0.1)
# Requirement already satisfied: tblib<4,>=1.7.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker<3.0->sagemaker-studio-image-build) (3.1.0)
# Requirement already satisfied: tqdm in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker<3.0->sagemaker-studio-image-build) (4.67.1)
# Requirement already satisfied: uvicorn in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker<3.0->sagemaker-studio-image-build) (0.34.3)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from graphene<4,>=3->sagemaker<3.0->sagemaker-studio-image-build) (3.2.6)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from graphene<4,>=3->sagemaker<3.0->sagemaker-studio-image-build) (3.2.0)
# Requirement already satisfied: typing-extensions<5,>=4.7.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from graphene<4,>=3->sagemaker<3.0->sagemaker-studio-image-build) (4.14.0)
# Requirement already satisfied: zipp>=0.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from importlib-metadata<7.0,>=1.4.0->sagemaker<3.0->sagemaker-studio-image-build) (3.22.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from omegaconf<3,>=2.2->sagemaker<3.0->sagemaker-studio-image-build) (4.9.3)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker-core<2.0.0,>=1.0.17->sagemaker<3.0->sagemaker-studio-image-build) (2.9.2)
# Requirement already satisfied: rich<15.0.0,>=14.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker-core<2.0.0,>=1.0.17->sagemaker<3.0->sagemaker-studio-image-build) (14.0.0)
# Requirement already satisfied: mock<5.0,>4.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from sagemaker-core<2.0.0,>=1.0.17->sagemaker<3.0->sagemaker-studio-image-build) (4.0.3)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from jsonschema->sagemaker<3.0->sagemaker-studio-image-build) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from jsonschema->sagemaker<3.0->sagemaker-studio-image-build) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from jsonschema->sagemaker<3.0->sagemaker-studio-image-build) (0.25.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.0.0->sagemaker-core<2.0.0,>=1.0.17->sagemaker<3.0->sagemaker-studio-image-build) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.0.0->sagemaker-core<2.0.0,>=1.0.17->sagemaker<3.0->sagemaker-studio-image-build) (2.23.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from rich<15.0.0,>=14.0.0->sagemaker-core<2.0.0,>=1.0.17->sagemaker<3.0->sagemaker-studio-image-build) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from rich<15.0.0,>=14.0.0->sagemaker-core<2.0.0,>=1.0.17->sagemaker<3.0->sagemaker-studio-image-build) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich<15.0.0,>=14.0.0->sagemaker-core<2.0.0,>=1.0.17->sagemaker<3.0->sagemaker-studio-image-build) (0.1.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from requests->sagemaker<3.0->sagemaker-studio-image-build) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from requests->sagemaker<3.0->sagemaker-studio-image-build) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from requests->sagemaker<3.0->sagemaker-studio-image-build) (2025.4.26)
# Requirement already satisfied: starlette<0.47.0,>=0.40.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from fastapi->sagemaker<3.0->sagemaker-studio-image-build) (0.46.2)
# Requirement already satisfied: anyio<5,>=3.6.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from starlette<0.47.0,>=0.40.0->fastapi->sagemaker<3.0->sagemaker-studio-image-build) (4.9.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from anyio<5,>=3.6.2->starlette<0.47.0,>=0.40.0->fastapi->sagemaker<3.0->sagemaker-studio-image-build) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from anyio<5,>=3.6.2->starlette<0.47.0,>=0.40.0->fastapi->sagemaker<3.0->sagemaker-studio-image-build) (1.3.1)
# Requirement already satisfied: pytz>=2020.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pandas->sagemaker<3.0->sagemaker-studio-image-build) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pandas->sagemaker<3.0->sagemaker-studio-image-build) (2025.2)
# Requirement already satisfied: ppft>=1.7.7 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pathos->sagemaker<3.0->sagemaker-studio-image-build) (1.7.7)
# Requirement already satisfied: dill>=0.4.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pathos->sagemaker<3.0->sagemaker-studio-image-build) (0.4.0)
# Requirement already satisfied: pox>=0.3.6 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pathos->sagemaker<3.0->sagemaker-studio-image-build) (0.3.6)
# Requirement already satisfied: multiprocess>=0.70.18 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pathos->sagemaker<3.0->sagemaker-studio-image-build) (0.70.18)
# Requirement already satisfied: click>=7.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from uvicorn->sagemaker<3.0->sagemaker-studio-image-build) (8.1.8)
# Requirement already satisfied: h11>=0.8 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from uvicorn->sagemaker<3.0->sagemaker-studio-image-build) (0.16.0)
# Building wheels for collected packages: sagemaker-studio-image-build
#   DEPRECATION: Building 'sagemaker-studio-image-build' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'sagemaker-studio-image-build'. Discussion can be found at https://github.com/pypa/pip/issues/6334
#   Building wheel for sagemaker-studio-image-build (setup.py) ... done
#   Created wheel for sagemaker-studio-image-build: filename=sagemaker_studio_image_build-0.6.0-py3-none-any.whl size=13558 sha256=51873059472ad44a7677e081d40579e6ebe6fcea1d2a0b6740b2f3601e833dba
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/69/7b/d1/1318b1530ee5322c9be00f206badea11b5148626ef58c0e0dc
# Successfully built sagemaker-studio-image-build
# Installing collected packages: sagemaker-studio-image-build
# Successfully installed sagemaker-studio-image-build-0.6.0

# %%
# !sm-docker build -t smstudio-custom:my-jupyterlab-image .
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/ec2-user/.config/sagemaker/config.yaml
# Created ECR repository sagemaker-studio
# ....................[Container] 2025/06/19 00:55:32.671091 Running on CodeBuild On-demand
#
# [Container] 2025/06/19 00:55:32.671139 Waiting for agent ping
# [Container] 2025/06/19 00:55:32.772127 Waiting for DOWNLOAD_SOURCE
# [Container] 2025/06/19 00:55:33.097254 Phase is DOWNLOAD_SOURCE
# [Container] 2025/06/19 00:55:33.098501 CODEBUILD_SRC_DIR=/codebuild/output/src3964233945/src
# [Container] 2025/06/19 00:55:33.099176 YAML location is /codebuild/output/src3964233945/src/buildspec.yml
# [Container] 2025/06/19 00:55:33.103345 Setting HTTP client timeout to higher timeout for S3 source
# [Container] 2025/06/19 00:55:33.103456 Processing environment variables
# [Container] 2025/06/19 00:55:33.181650 No runtime version selected in buildspec.
# [Container] 2025/06/19 00:55:33.199500 Moving to directory /codebuild/output/src3964233945/src
# [Container] 2025/06/19 00:55:33.199523 Cache is not defined in the buildspec
# [Container] 2025/06/19 00:55:33.229621 Skip cache due to: no paths specified to be cached
# [Container] 2025/06/19 00:55:33.230041 Registering with agent
# [Container] 2025/06/19 00:55:33.259828 Phases found in YAML: 3
# [Container] 2025/06/19 00:55:33.259846  PRE_BUILD: 9 commands
# [Container] 2025/06/19 00:55:33.259851  BUILD: 4 commands
# [Container] 2025/06/19 00:55:33.259854  POST_BUILD: 3 commands
# [Container] 2025/06/19 00:55:33.260266 Phase complete: DOWNLOAD_SOURCE State: SUCCEEDED
# [Container] 2025/06/19 00:55:33.260278 Phase context status code:  Message:
# [Container] 2025/06/19 00:55:33.322680 Entering phase INSTALL
# [Container] 2025/06/19 00:55:33.355645 Phase complete: INSTALL State: SUCCEEDED
# [Container] 2025/06/19 00:55:33.355662 Phase context status code:  Message:
# [Container] 2025/06/19 00:55:33.389292 Entering phase PRE_BUILD
# [Container] 2025/06/19 00:55:33.422390 Running command echo Logging in to Amazon ECR...
# Logging in to Amazon ECR...
#
# [Container] 2025/06/19 00:55:33.428489 Running command $(aws ecr get-login --no-include-email --region $AWS_DEFAULT_REGION)
# WARNING! Using --password via the CLI is insecure. Use --password-stdin.
# WARNING! Your password will be stored unencrypted in /root/.docker/config.json.
# Configure a credential helper to remove this warning. See
# https://docs.docker.com/engine/reference/commandline/login/#credentials-store
#
# Login Succeeded
#
# [Container] 2025/06/19 00:55:34.756563 Running command $(aws ecr get-login --no-include-email --region $AWS_DEFAULT_REGION --registry-ids 763104351884)
# WARNING! Using --password via the CLI is insecure. Use --password-stdin.
# WARNING! Your password will be stored unencrypted in /root/.docker/config.json.
# Configure a credential helper to remove this warning. See
# https://docs.docker.com/engine/reference/commandline/login/#credentials-store
#
# Login Succeeded
#
# [Container] 2025/06/19 00:55:35.347035 Running command $(aws ecr get-login --no-include-email --region $AWS_DEFAULT_REGION --registry-ids 217643126080)
# WARNING! Using --password via the CLI is insecure. Use --password-stdin.
# WARNING! Your password will be stored unencrypted in /root/.docker/config.json.
# Configure a credential helper to remove this warning. See
# https://docs.docker.com/engine/reference/commandline/login/#credentials-store
#
# Login Succeeded
#
# [Container] 2025/06/19 00:55:35.943063 Running command $(aws ecr get-login --no-include-email --region $AWS_DEFAULT_REGION --registry-ids 727897471807)
# WARNING! Using --password via the CLI is insecure. Use --password-stdin.
# WARNING! Your password will be stored unencrypted in /root/.docker/config.json.
# Configure a credential helper to remove this warning. See
# https://docs.docker.com/engine/reference/commandline/login/#credentials-store
#
# Login Succeeded
#
# [Container] 2025/06/19 00:55:36.526860 Running command $(aws ecr get-login --no-include-email --region $AWS_DEFAULT_REGION --registry-ids 626614931356)
# WARNING! Using --password via the CLI is insecure. Use --password-stdin.
# WARNING! Your password will be stored unencrypted in /root/.docker/config.json.
# Configure a credential helper to remove this warning. See
# https://docs.docker.com/engine/reference/commandline/login/#credentials-store
#
# Login Succeeded
#
# [Container] 2025/06/19 00:55:37.102729 Running command $(aws ecr get-login --no-include-email --region $AWS_DEFAULT_REGION --registry-ids 683313688378)
# WARNING! Using --password via the CLI is insecure. Use --password-stdin.
# WARNING! Your password will be stored unencrypted in /root/.docker/config.json.
# Configure a credential helper to remove this warning. See
# https://docs.docker.com/engine/reference/commandline/login/#credentials-store
#
# Login Succeeded
#
# [Container] 2025/06/19 00:55:37.661325 Running command $(aws ecr get-login --no-include-email --region $AWS_DEFAULT_REGION --registry-ids 520713654638)
# WARNING! Using --password via the CLI is insecure. Use --password-stdin.
# WARNING! Your password will be stored unencrypted in /root/.docker/config.json.
# Configure a credential helper to remove this warning. See
# https://docs.docker.com/engine/reference/commandline/login/#credentials-store
#
# Login Succeeded
#
# [Container] 2025/06/19 00:55:38.234047 Running command $(aws ecr get-login --no-include-email --region $AWS_DEFAULT_REGION --registry-ids 462105765813)
# WARNING! Using --password via the CLI is insecure. Use --password-stdin.
# WARNING! Your password will be stored unencrypted in /root/.docker/config.json.
# Configure a credential helper to remove this warning. See
# https://docs.docker.com/engine/reference/commandline/login/#credentials-store
#
# Login Succeeded
#
# [Container] 2025/06/19 00:55:38.801789 Phase complete: PRE_BUILD State: SUCCEEDED
# [Container] 2025/06/19 00:55:38.801820 Phase context status code:  Message:
# [Container] 2025/06/19 00:55:38.833007 Entering phase BUILD
# [Container] 2025/06/19 00:55:38.834259 Running command echo Build started on `date`
# Build started on Thu Jun 19 00:55:38 UTC 2025
#
# [Container] 2025/06/19 00:55:38.846098 Running command echo Building the Docker image...
# Building the Docker image...
#
# [Container] 2025/06/19 00:55:38.861948 Running command docker build -t $IMAGE_REPO_NAME:$IMAGE_TAG -t smstudio-custom:my-jupyterlab-image .
# Sending build context to Docker daemon  24.58kB
# Step 1/11 : FROM public.ecr.aws/sagemaker/sagemaker-distribution:latest-cpu
# latest-cpu: Pulling from sagemaker/sagemaker-distribution
# e1a89dea01a6: Pulling fs layer
# c06112568bae: Pulling fs layer
# c0c887af5b0d: Pulling fs layer
# 2598436dd0c6: Pulling fs layer
# 7bf4a0380f99: Pulling fs layer
# f5aa94daada3: Pulling fs layer
# 4f4fb700ef54: Pulling fs layer
# 8085c3c045f7: Pulling fs layer
# 08d4b3e91967: Pulling fs layer
# bde8749b0aa5: Pulling fs layer
# f66d4558076a: Pulling fs layer
# c64710e2dde2: Pulling fs layer
# d627be30fafe: Pulling fs layer
# de0b7f0c3d43: Pulling fs layer
# 7498b68147ea: Pulling fs layer
# 2cd802b28693: Pulling fs layer
# eee5c84ce270: Pulling fs layer
# 48b1409f1173: Pulling fs layer
# a8f2067d390f: Pulling fs layer
# 2598436dd0c6: Waiting
# 7bf4a0380f99: Waiting
# f5aa94daada3: Waiting
# 4f4fb700ef54: Waiting
# 8085c3c045f7: Waiting
# 08d4b3e91967: Waiting
# bde8749b0aa5: Waiting
# f66d4558076a: Waiting
# c64710e2dde2: Waiting
# d627be30fafe: Waiting
# de0b7f0c3d43: Waiting
# 7498b68147ea: Waiting
# 2cd802b28693: Waiting
# eee5c84ce270: Waiting
# 48b1409f1173: Waiting
# a8f2067d390f: Waiting
# c0c887af5b0d: Verifying Checksum
# c0c887af5b0d: Download complete
# c06112568bae: Verifying Checksum
# c06112568bae: Download complete
# 2598436dd0c6: Verifying Checksum
# 2598436dd0c6: Download complete
# 7bf4a0380f99: Verifying Checksum
# 7bf4a0380f99: Download complete
# 4f4fb700ef54: Download complete
# f5aa94daada3: Download complete
# 8085c3c045f7: Verifying Checksum
# 8085c3c045f7: Download complete
# 08d4b3e91967: Verifying Checksum
# 08d4b3e91967: Download complete
# bde8749b0aa5: Verifying Checksum
# bde8749b0aa5: Download complete
# f66d4558076a: Verifying Checksum
# f66d4558076a: Download complete
# d627be30fafe: Download complete
# e1a89dea01a6: Verifying Checksum
# e1a89dea01a6: Download complete
# 7498b68147ea: Verifying Checksum
# 7498b68147ea: Download complete
# e1a89dea01a6: Pull complete
# c06112568bae: Pull complete
# c0c887af5b0d: Pull complete
# 2598436dd0c6: Pull complete
# 7bf4a0380f99: Pull complete
# de0b7f0c3d43: Verifying Checksum
# de0b7f0c3d43: Download complete
# f5aa94daada3: Pull complete
# 4f4fb700ef54: Pull complete
# eee5c84ce270: Verifying Checksum
# eee5c84ce270: Download complete
# 8085c3c045f7: Pull complete
# 48b1409f1173: Verifying Checksum
# 48b1409f1173: Download complete
# 08d4b3e91967: Pull complete
# bde8749b0aa5: Pull complete
# a8f2067d390f: Verifying Checksum
# a8f2067d390f: Download complete
# f66d4558076a: Pull complete
# c64710e2dde2: Verifying Checksum
# c64710e2dde2: Download complete
# c64710e2dde2: Pull complete
# d627be30fafe: Pull complete
# de0b7f0c3d43: Pull complete
# 7498b68147ea: Pull complete
# 2cd802b28693: Verifying Checksum
# 2cd802b28693: Download complete
# 2cd802b28693: Pull complete
# eee5c84ce270: Pull complete
# 48b1409f1173: Pull complete
# a8f2067d390f: Pull complete
# Digest: sha256:92cfd41f9293e3cfbf58f3bf728348fbb298bca0eeea44464968f08622d78ed0
# Status: Downloaded newer image for public.ecr.aws/sagemaker/sagemaker-distribution:latest-cpu
#  ---> 9abc1486da33
# Step 2/11 : ARG NB_USER="sagemaker-user"
#  ---> Running in 668baa301c07
# Removing intermediate container 668baa301c07
#  ---> 21baaf4de765
# Step 3/11 : ARG NB_UID=1000
#  ---> Running in 297ecfe210c4
# Removing intermediate container 297ecfe210c4
#  ---> 0d09d352d183
# Step 4/11 : ARG NB_GID=100
#  ---> Running in 80519a69bea1
# Removing intermediate container 80519a69bea1
#  ---> 3f8f6a802b93
# Step 5/11 : ENV MAMBA_USER=$NB_USER
#  ---> Running in 8eeaa41100fc
# Removing intermediate container 8eeaa41100fc
#  ---> f19f0675fd80
# Step 6/11 : USER root
#  ---> Running in c081ab4f266f
# Removing intermediate container c081ab4f266f
#  ---> a4d8dfe5c174
# Step 7/11 : RUN apt-get update
#  ---> Running in d4f935123511
# Hit:1 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:2 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:4 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [4476 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1561 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [4630 kB]
# Get:8 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [2994 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [3305 kB]
# Get:10 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1253 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy-backports/universe amd64 Packages [35.2 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy-backports/main amd64 Packages [83.2 kB]
# Fetched 18.7 MB in 2s (10.4 MB/s)
# Reading package lists...
# Removing intermediate container d4f935123511
#  ---> ccdf64d86ad1
# Step 8/11 : RUN micromamba install sagemaker-inference --freeze-installed --yes --channel conda-forge --name base
#  ---> Running in ce10ec7c42e3
#
# Pinned packages:
#
#   - python=3.12
#
#
# Transaction
#
#   Prefix: /opt/conda
#
#   Updating specs:
#
#    - sagemaker-inference
#
#
#   Package                Version  Build         Channel         Size
# ──────────────────────────────────────────────────────────────────────
#   Install:
# ──────────────────────────────────────────────────────────────────────
#
#   + sagemaker-inference   1.10.1  pyhd8ed1ab_1  conda-forge     27kB
#
#   Summary:
#
#   Install: 1 packages
#
#   Total download: 27kB
#
# ──────────────────────────────────────────────────────────────────────
#
#
#
# Transaction starting
# Linking sagemaker-inference-1.10.1-pyhd8ed1ab_1
#
# Transaction finished
#
# Removing intermediate container ce10ec7c42e3
#  ---> 3a4959d5a1bc
# Step 9/11 : USER $MAMBA_USER
#  ---> Running in a4447f55bf0d
# Removing intermediate container a4447f55bf0d
#  ---> 0d2f39356f24
# Step 10/11 : ENTRYPOINT ["jupyter-lab"]
#  ---> Running in 2e3cb884db24
# Removing intermediate container 2e3cb884db24
#  ---> 50229109c188
# Step 11/11 : CMD ["--ServerApp.ip=0.0.0.0", "--ServerApp.port=8888", "--ServerApp.allow_origin=*", "--ServerApp.token=''", "--ServerApp.base_url=/jupyterlab/default"]
#  ---> Running in 3b90618ca810
# Removing intermediate container 3b90618ca810
#  ---> 78c2fb7bdfc2
# Successfully built 78c2fb7bdfc2
# Successfully tagged sagemaker-studio:latest
# Successfully tagged smstudio-custom:my-jupyterlab-image
#
# [Container] 2025/06/19 00:59:25.806494 Running command docker tag $IMAGE_REPO_NAME:$IMAGE_TAG $AWS_ACCOUNT_ID.dkr.ecr.$AWS_DEFAULT_REGION.amazonaws.com/$IMAGE_REPO_NAME:$IMAGE_TAG
#
# [Container] 2025/06/19 00:59:25.850238 Phase complete: BUILD State: SUCCEEDED
# [Container] 2025/06/19 00:59:25.850256 Phase context status code:  Message:
# [Container] 2025/06/19 00:59:25.907315 Entering phase POST_BUILD
# [Container] 2025/06/19 00:59:25.908672 Running command echo Build completed on `date`
# Build completed on Thu Jun 19 00:59:25 UTC 2025
#
# [Container] 2025/06/19 00:59:25.917403 Running command echo Pushing the Docker image...
# Pushing the Docker image...
#
# [Container] 2025/06/19 00:59:25.922837 Running command docker push $AWS_ACCOUNT_ID.dkr.ecr.$AWS_DEFAULT_REGION.amazonaws.com/$IMAGE_REPO_NAME:$IMAGE_TAG
# The push refers to repository [794038231401.dkr.ecr.us-east-1.amazonaws.com/sagemaker-studio]
# 55c463bc62d2: Preparing
# 2d7528e550d8: Preparing
# 77bf2079135a: Preparing
# 0f5da0586fd0: Preparing
# 8d2fccdbd5ad: Preparing
# 711e882407a5: Preparing
# 5922b67995fe: Preparing
# 5922b67995fe: Preparing
# dbe74971bc66: Preparing
# 772acccc2860: Preparing
# b9c60f52f5ce: Preparing
# f866f4d6b552: Preparing
# 262be29046b8: Preparing
# 1a7d708d2369: Preparing
# 3b1ef917e583: Preparing
# 5f70bf18a086: Preparing
# 2723e1bcedf2: Preparing
# 9ab234b0f4b9: Preparing
# ce16b3897367: Preparing
# 31f222af711e: Preparing
# e7a5f74988bd: Preparing
# 346f14bf17b9: Preparing
# 1a7d708d2369: Waiting
# 3b1ef917e583: Waiting
# 5f70bf18a086: Waiting
# 2723e1bcedf2: Waiting
# 9ab234b0f4b9: Waiting
# ce16b3897367: Waiting
# 31f222af711e: Waiting
# 711e882407a5: Waiting
# e7a5f74988bd: Waiting
# 346f14bf17b9: Waiting
# 5922b67995fe: Waiting
# dbe74971bc66: Waiting
# 772acccc2860: Waiting
# b9c60f52f5ce: Waiting
# f866f4d6b552: Waiting
# 262be29046b8: Waiting
# 0f5da0586fd0: Pushed
# 8d2fccdbd5ad: Pushed
# 77bf2079135a: Pushed
# 5922b67995fe: Pushed
# 2d7528e550d8: Pushed
# 772acccc2860: Pushed
# f866f4d6b552: Pushed
# dbe74971bc66: Pushed
# 1a7d708d2369: Pushed
# 262be29046b8: Pushed
# 3b1ef917e583: Pushed
# 5f70bf18a086: Pushed
# 9ab234b0f4b9: Pushed
# ce16b3897367: Pushed
# 2723e1bcedf2: Pushed
# 31f222af711e: Pushed
# e7a5f74988bd: Pushed
# 346f14bf17b9: Pushed
# 55c463bc62d2: Pushed
# b9c60f52f5ce: Pushed
#
# 711e882407a5: Pushed
# latest: digest: sha256:68f24b9adc8f5067f380de710f7f262b36351aded39ec5349635af1d4ba1b45a size: 4925
#
# [Container] 2025/06/19 01:05:27.027182 Phase complete: POST_BUILD State: SUCCEEDED
# [Container] 2025/06/19 01:05:27.027204 Phase context status code:  Message:
# [Container] 2025/06/19 01:05:27.097655 Set report auto-discover timeout to 5 seconds
# [Container] 2025/06/19 01:05:27.099761 Expanding base directory path:  .
# [Container] 2025/06/19 01:05:27.101272 Assembling file list
# [Container] 2025/06/19 01:05:27.101285 Expanding .
# [Container] 2025/06/19 01:05:27.103732 Expanding file paths for base directory .
# [Container] 2025/06/19 01:05:27.104399 Assembling file list
# [Container] 2025/06/19 01:05:27.104403 Expanding **/*
# [Container] 2025/06/19 01:05:27.108346 No matching auto-discover report paths found
# [Container] 2025/06/19 01:05:27.108445 Report auto-discover file discovery took 0.010706 seconds
# [Container] 2025/06/19 01:05:27.108461 Phase complete: UPLOAD_ARTIFACTS State: SUCCEEDED
# [Container] 2025/06/19 01:05:27.108488 Phase context status code:  Message:
# Image URI: 794038231401.dkr.ecr.us-east-1.amazonaws.com/sagemaker-studio:latest

# %%
# 794038231401.dkr.ecr.us-east-1.amazonaws.com/sagemaker-studio:latest

# %% [markdown]
# # Create an AppImageConfig:
#
# ```
# {
#   "AppImageConfigName": "my-custom-image-config",
#   "KernelGatewayImageConfig": {
#     "KernelSpecs": [
#       {
#         "Name": "python3",
#         "DisplayName": "Python 3"
#       }
#     ]
#   },
#   "FileSystemConfig": {
#     "MountPath": "/home/sagemaker-user",
#     "DefaultUid": 1000,
#     "DefaultGid": 100
#   }
# }
# ```

# %%
# !aws sagemaker create-app-image-config --cli-input-json file://app-image-config-input.json --region us-east-1
# Out:
# {
#     "AppImageConfigArn": "arn:aws:sagemaker:us-east-1:794038231401:app-image-config/my-custom-image-config"
# }

# %%
# arn:aws:sagemaker:us-east-1:794038231401:app-image-config/my-custom-image-config

# %%
# !aws sagemaker create-image \
  --image-name my-jupyterlab-image \
  --role-arn arn:aws:iam::794038231401:role/service-role/SageMaker-ExecutionRole-20250401T103257 \
  --region us-east-1
# Out:
# {
#     "ImageArn": "arn:aws:sagemaker:us-east-1:794038231401:image/my-jupyterlab-image"
# }

# %%
# arn:aws:sagemaker:us-east-1:794038231401:image/my-jupyterlab-image

# %%
# !aws sagemaker create-image-version \
  --image-name my-jupyterlab-image \
  --base-image 794038231401.dkr.ecr.us-east-1.amazonaws.com/sagemaker-studio:latest \
  --region us-east-1
# Out:
# {
#     "ImageVersionArn": "arn:aws:sagemaker:us-east-1:794038231401:image-version/my-jupyterlab-image/1"
# }

# %%
# arn:aws:sagemaker:us-east-1:794038231401:image-version/my-jupyterlab-image/1

# %%
# !aws sagemaker update-domain \
  --domain-id d-oc09trpafuvq \
  --default-space-settings file://default-space-settings.json \
  --region us-east-1
# Out:
# {
#     "DomainArn": "arn:aws:sagemaker:us-east-1:794038231401:domain/d-oc09trpafuvq"
# }

# %%
# !aws sagemaker describe-domain --domain-id d-oc09trpafuvq
# Out:
# {
#     "DomainArn": "arn:aws:sagemaker:us-east-1:794038231401:domain/d-oc09trpafuvq",
#     "DomainId": "d-oc09trpafuvq",
#     "DomainName": "QuickSetupDomain-20250509T182763",
#     "HomeEfsFileSystemId": "fs-06f60e12721575183",
#     "Status": "InService",
#     "CreationTime": 1746836843.076,
#     "LastModifiedTime": 1750296779.43,
#     "AuthMode": "IAM",
#     "DefaultUserSettings": {
#         "ExecutionRole": "arn:aws:iam::794038231401:role/service-role/AmazonSageMaker-ExecutionRole-20250509T182764",
#         "SharingSettings": {
#             "NotebookOutputOption": "Allowed",
#             "S3OutputPath": "s3://sagemaker-studio-794038231401-bdnwp0hqy1s/sharing"
#         },
#         "JupyterServerAppSettings": {
#             "DefaultResourceSpec": {
#                 "SageMakerImageArn": "arn:aws:sagemaker:us-east-1:081325390199:image/jupyter-server-3",
#                 "InstanceType": "system"
#             }
#         },
#         "CanvasAppSettings": {
#             "TimeSeriesForecastingSettings": {
#                 "Status": "DISABLED"
#             },
#             "ModelRegisterSettings": {
#                 "Status": "ENABLED"
#             },
#             "WorkspaceSettings": {
#                 "S3ArtifactPath": "s3://sagemaker-us-east-1-794038231401"
#             },
#             "DirectDeploySettings": {
#                 "Status": "ENABLED"
#             },
#             "KendraSettings": {
#                 "Status": "DISABLED"
#             },
#             "GenerativeAiSettings": {
#                 "AmazonBedrockRoleArn": "arn:aws:iam::794038231401:role/service-role/AmazonSagemakerCanvasBedrockRole-20250509T182763"
#             },
#             "EmrServerlessSettings": {
#                 "ExecutionRoleArn": "arn:aws:iam::794038231401:role/service-role/AmazonSageMakerCanvasEMRSExecutionAccess-20250512T124237",
#                 "Status": "ENABLED"
#             }
#         },
#         "DefaultLandingUri": "studio::",
#         "StudioWebPortal": "ENABLED",
#         "StudioWebPortalSettings": {
#             "HiddenAppTypes": [
#                 "JupyterServer"
#             ]
#         },
#         "AutoMountHomeEFS": "Enabled"
#     },
#     "AppNetworkAccessType": "PublicInternetOnly",
#     "SubnetIds": [
#         "subnet-0f7591b0aa2bcbad3",
#         "subnet-01231a12e72fe6150",
#         "subnet-0e91f4711dc2f30a5",
#         "subnet-0318cba011a613528",
#         "subnet-03817e6f11eb7bdbc",
#         "subnet-083e7e1ffb62eed6d"
#     ],
#     "Url": "https://d-oc09trpafuvq.studio.us-east-1.sagemaker.aws",
#     "VpcId": "vpc-05a1afb6fbfb393ed",
#     "TagPropagation": "DISABLED",
#     "DefaultSpaceSettings": {
#         "ExecutionRole": "arn:aws:iam::794038231401:role/service-role/SageMaker-ExecutionRole-20250401T103257",
#         "JupyterLabAppSettings": {
#             "CustomImages": [
#                 {
#                     "ImageName": "my-jupyterlab-image",
#                     "ImageVersionNumber": 1,
#                     "AppImageConfigName": "my-jupyterlab-config"
#                 }
#             ]
#         }
#     }
# }
